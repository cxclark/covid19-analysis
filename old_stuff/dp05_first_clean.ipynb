# %%
import pandas as pd

# %%
df = pd.read_csv('data/dp05_with_headers.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Geographic Area Name  \
# 0           1        Austin County, Texas
# 1           2        Kenedy County, Texas
# 2           3        Nueces County, Texas
# 3           4      Colorado County, Texas
# 4           5  San Patricio County, Texas
#
#    Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.6
# 1                                               20.5
# 2                                                0.1
# 3                                                0.1
# 4                                                0.5
#
#    Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               87.0
# 1                                               34.7
# 2                                               79.3
# 3                                               85.6
# ...

# %%
list(df.columns.values)
# Out:
# ['Unnamed: 0',
#  'Geographic Area Name',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Margin of Error!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Percent Margin of Error!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Margin of Error!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Percent Margin of Error!!RACE!!Total population!!One race',
# ...

# %%
df = df.drop(columns = "Unnamed: 0")

# %%
df.head()
# Out:
#          Geographic Area Name  \
# 0        Austin County, Texas
# 1        Kenedy County, Texas
# 2        Nueces County, Texas
# 3      Colorado County, Texas
# 4  San Patricio County, Texas
#
#    Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.6
# 1                                               20.5
# 2                                                0.1
# 3                                                0.1
# 4                                                0.5
#
#    Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               87.0
# 1                                               34.7
# 2                                               79.3
# 3                                               85.6
# 4                                               86.1
#
# ...

# %%
df = df.drop(columns = "Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)")

# %%
df.head()
# Out:
#          Geographic Area Name  \
# 0        Austin County, Texas
# 1        Kenedy County, Texas
# 2        Nueces County, Texas
# 3      Colorado County, Texas
# 4  San Patricio County, Texas
#
#    Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.6
# 1                                               20.5
# 2                                                0.1
# 3                                                0.1
# 4                                                0.5
#
#    Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               87.0
# 1                                               34.7
# 2                                               79.3
# 3                                               85.6
# 4                                               86.1
#
# ...

# %%
df
# Out:
#            Geographic Area Name  \
# 0          Austin County, Texas
# 1          Kenedy County, Texas
# 2          Nueces County, Texas
# 3        Colorado County, Texas
# 4    San Patricio County, Texas
# ..                          ...
# 249     McCulloch County, Texas
# 250           Lee County, Texas
# 251         Ellis County, Texas
# 252          Kerr County, Texas
# 253         Falls County, Texas
#
#      Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                  0.6
# 1                                                 20.5
# 2                                                  0.1
# 3                                                  0.1
# 4                                                  0.5
# ..                                                 ...
# 249                                                2.2
# 250                                                1.3
# ...

# %%
df['Margin of Error!!RACE!!Total population'].value_counts()
# Out:
# -555555555    232
#  193            2
#  188            2
#  181            2
#  153            2
#  137            2
#  128            2
#  125            2
#  118            2
#  187            1
#  186            1
#  146            1
#  119            1
#  69             1
#  47             1
# Name: Margin of Error!!RACE!!Total population, dtype: int64

# %%
df['Estimate!!RACE!!Total population!!One race'].value_counts()
# Out:
# 14334      1
# 5783       1
# 2518190    1
# 35500      1
# 9386       1
#           ..
# 70487      1
# 7510       1
# 65364      1
# 7505       1
# 8195       1
# Name: Estimate!!RACE!!Total population!!One race, Length: 254, dtype: int64

# %%
df = df.drop(columns = "Percent Margin of Error!!RACE!!Total population")

# %%
df = df.drop(columns = "Percent Estimate!!SEX AND AGE!!Total population!!Median age (years)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!Median age (years)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over.1")

# %%
df = df.drop(columns = "Percent Estimate!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over.1")

# %%
df = df.drop(columns = "DP05_0032PEA")

# %%
df = df.drop(columns = "DP05_0032PMA")

# %%
df = df.drop(columns = "DP05_0033PMA")

# %%
df = df.drop(columns = "DP05_0063PMA")

# %%
df = df.drop(columns = "DP05_0070PMA")

# %%
df = df.drop(columns = "DP05_0086PMA")

# %%
df = df.drop(columns = "DP05_0087PMA")

# %%
df = df.drop(columns = "Geographic Area Name.1")

# %%
df = df.drop(columns = "DP05_0001PMA")

# %%
df = df.drop(columns = "DP05_0004PMA")

# %%
df = df.drop(columns = "DP05_0004PEA")

# %%
df = df.drop(columns = "DP05_0018PMA")

# %%
df = df.drop(columns = "DP05_0018PEA")

# %%
df = df.drop(columns = "DP05_0025PMA")

# %%
df = df.drop(columns = "DP05_0028PMA")

# %%
df = df.drop(columns = "DP05_0028PEA")

# %%
df = df.drop(columns = "DP05_0029PMA")

# %%
df = df.drop(columns = "state")

# %%
df.shape
# Out:
# (254, 350)

# %%
df['Percent Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping'].value_counts()
# Out:
# 0.0    252
# 0.1      2
# Name: Percent Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping, dtype: int64

# %%
df = df.drop(columns = "Percent Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping")

# %%
df['Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping'].value_counts()
# Out:
# 0      229
# 5        3
# 12       2
# 13       2
# 110      2
# 19       1
# 3        1
# 4        1
# 10       1
# 14       1
# 16       1
# 162      1
# 27       1
# 31       1
# 34       1
# 40       1
# 41       1
# 63       1
# 81       1
# 83       1
# 20       1
# Name: Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping, dtype: int64

# %%
df['Margin of Error!!Race alone or in combination with one or more other races!!Total population'].value_counts()
# Out:
# -555555555    232
#  193            2
#  188            2
#  181            2
#  153            2
#  137            2
#  128            2
#  125            2
#  118            2
#  187            1
#  186            1
#  146            1
#  119            1
#  69             1
#  47             1
# Name: Margin of Error!!Race alone or in combination with one or more other races!!Total population, dtype: int64

# %%
df = df.drop(columns = "Percent Margin of Error!!Race alone or in combination with one or more other races!!Total population")

# %%
df['Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population'].value_counts()
# Out:
# -555555555    232
#  193            2
#  188            2
#  181            2
#  153            2
#  137            2
#  128            2
#  125            2
#  118            2
#  187            1
#  186            1
#  146            1
#  119            1
#  69             1
#  47             1
# Name: Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population, dtype: int64

# %%
df = df.drop(columns = "Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population")

# %%
df['Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)'].value_counts()
# Out:
# -555555555    205
#  159            3
#  109            2
#  220            2
#  208            2
#  205            2
#  102            2
#  155            2
#  69             2
#  169            2
#  105            1
#  97             1
#  93             1
#  85             1
#  255            1
#  66             1
#  107            1
#  52             1
#  299            1
#  35             1
#  33             1
#  21             1
#  272            1
#  65             1
#  141            1
#  113            1
#  137            1
#  241            1
#  142            1
#  147            1
#  158            1
#  160            1
#  189            1
#  192            1
#  195            1
#  199            1
#  201            1
#  202            1
#  237            1
#  269            1
# Name: Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race), dtype: int64

# %%
df['Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)'].value_counts()
# Out:
# -888888888.0    205
#  4.4              2
#  3.1              2
#  6.5              2
#  4.9              2
#  3.5              2
#  4.2              2
#  3.8              2
#  3.6              2
#  7.1              2
#  4.1              1
#  5.6              1
#  12.2             1
#  13.7             1
#  8.2              1
#  5.4              1
#  11.3             1
#  6.9              1
#  5.9              1
#  9.4              1
#  3.2              1
#  2.8              1
#  2.1              1
#  3.7              1
#  2.7              1
#  6.7              1
#  20.2             1
#  5.7              1
#  14.1             1
#  4.8              1
#  5.3              1
#  2.2              1
#  0.3              1
#  10.6             1
#  9.9              1
#  4.3              1
#  6.8              1
#  4.7              1
#  3.4              1
#  13.8             1
#  6.0              1
# ...

# %%
df['Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino'].value_counts()
# Out:
# -555555555    205
#  109            4
#  159            3
#  189            2
#  169            2
#  116            2
#  220            2
#  111            2
#  208            2
#  205            2
#  155            2
#  105            2
#  112            1
#  255            1
#  85             1
#  123            1
#  66             1
#  65             1
#  61             1
#  59             1
#  45             1
#  117            1
#  146            1
#  124            1
#  141            1
#  142            1
#  248            1
#  158            1
#  160            1
#  172            1
#  199            1
#  202            1
#  210            1
#  217            1
#  241            1
#  262            1
# Name: Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino, dtype: int64

# %%
df['Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino'].value_counts()
# Out:
# -888888888.0    205
#  4.4              2
#  3.1              2
#  6.5              2
#  4.9              2
#  3.5              2
#  4.2              2
#  3.8              2
#  3.6              2
#  7.1              2
#  4.1              1
#  5.6              1
#  12.2             1
#  13.7             1
#  8.2              1
#  5.4              1
#  11.3             1
#  6.9              1
#  5.9              1
#  9.4              1
#  3.2              1
#  2.8              1
#  2.1              1
#  3.7              1
#  2.7              1
#  6.7              1
#  20.2             1
#  5.7              1
#  14.1             1
#  4.8              1
#  5.3              1
#  2.2              1
#  0.3              1
#  10.6             1
#  9.9              1
#  4.3              1
#  6.8              1
#  4.7              1
#  3.4              1
#  13.8             1
#  6.0              1
# ...

# %%
df = df.drop(columns = "Percent Estimate!!Total housing units")

# %%
df = df.drop(columns = "Percent Margin of Error!!Total housing units")

# %%
df = df.drop(columns = "Percent Margin of Error!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population")

# %%
df['Margin of Error!!SEX AND AGE!!Total population'].value_counts()
# Out:
# -555555555    232
#  193            2
#  188            2
#  181            2
#  153            2
#  137            2
#  128            2
#  125            2
#  118            2
#  187            1
#  186            1
#  146            1
#  119            1
#  69             1
#  47             1
# Name: Margin of Error!!SEX AND AGE!!Total population, dtype: int64

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population")

# %%
df = df.drop(columns = "Percent Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)")

# %%
df = df.drop(columns = "Percent Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)")

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female'] == -888888888.0).sum()
# Out:
# 6

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)'] == -555555555.0).sum()
# Out:
# 6

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!Under 18 years'] == -555555555.0).sum()
# Out:
# 63

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!18 years and over'] == -555555555.0).sum()
# Out:
# 63

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!Under 18 years'] == -888888888.0).sum()
# Out:
# 63

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!65 years and over'] == -555555555.0).sum()
# Out:
# 6

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!18 years and over.1'] == -555555555.0).sum()
# Out:
# 63

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Male'] == -555555555.0).sum()
# Out:
# 20

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Sex ratio (males per 100 females)'] == -555555555.0).sum()
# Out:
# 20

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!65 years and over.1'] == -555555555.0).sum()
# Out:
# 6

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Male'] == -555555555.0).sum()
# Out:
# 0

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Male'] == -555555555.0).sum()
# Out:
# 7

# %%
(df['Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female'] == -555555555.0).sum()
# Out:
# 11

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Male'] == -888888888.0).sum()
# Out:
# 6

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Female'] == -888888888.0).sum()
# Out:
# 20

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over!!Male'] == -888888888.0).sum()
# Out:
# 20

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over'] == -888888888.0).sum()
# Out:
# 6

# %%
(df['Percent Margin of Error!!SEX AND AGE!!Total population!!18 years and over'] == -888888888.0).sum()
# Out:
# 63

# %%
(df['Margin of Error!!RACE!!Total population'] == -555555555.0).sum()
# Out:
# 232

# %%
df = df.drop(columns = "Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)")

# %%
df = df.drop(columns = "Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino")

# %%
df = df.drop(columns = "Percent Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Not Hispanic or Latino")

# %%
df = df.drop(columns = "Margin of Error!!RACE!!Total population")

# %%
df = df.drop(columns = "Margin of Error!!Race alone or in combination with one or more other races!!Total population")

# %%
df = df.drop(columns = "Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population")

# %%
df = df.drop(columns = "Margin of Error!!SEX AND AGE!!Total population")

# %%
#df = df.drop(columns = "Margin of Error!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)")

# %%
df.shape
# Out:
# (254, 333)

# %%
#df.to_csv('./data/initial_cleaned_dp05.csv', index = False)

# %%
df.shape
# Out:
# (254, 333)

# %%
df.head()
# Out:
#          Geographic Area Name  \
# 0        Austin County, Texas
# 1        Kenedy County, Texas
# 2        Nueces County, Texas
# 3      Colorado County, Texas
# 4  San Patricio County, Texas
#
#    Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.6
# 1                                               20.5
# 2                                                0.1
# 3                                                0.1
# 4                                                0.5
#
#    Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               87.0
# 1                                               34.7
# 2                                               79.3
# 3                                               85.6
# 4                                               86.1
#
# ...

# %%
#https://stackoverflow.com/questions/41293618/split-city-state-zip-into-three-columns-in-pandas-dataframe
regex = r'(?P<County>[^,]+)\s*,\s*(?P<State>[^\s]+)'
ddf = df['Geographic Area Name'].str.extract(regex)

# %%
ddf
# Out:
#                   County  State
# 0          Austin County  Texas
# 1          Kenedy County  Texas
# 2          Nueces County  Texas
# 3        Colorado County  Texas
# 4    San Patricio County  Texas
# ..                   ...    ...
# 249     McCulloch County  Texas
# 250           Lee County  Texas
# 251         Ellis County  Texas
# 252          Kerr County  Texas
# 253         Falls County  Texas
#
# [254 rows x 2 columns]

# %%
df
# Out:
#            Geographic Area Name  \
# 0          Austin County, Texas
# 1          Kenedy County, Texas
# 2          Nueces County, Texas
# 3        Colorado County, Texas
# 4    San Patricio County, Texas
# ..                          ...
# 249     McCulloch County, Texas
# 250           Lee County, Texas
# 251         Ellis County, Texas
# 252          Kerr County, Texas
# 253         Falls County, Texas
#
#      Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                  0.6
# 1                                                 20.5
# 2                                                  0.1
# 3                                                  0.1
# 4                                                  0.5
# ..                                                 ...
# 249                                                2.2
# 250                                                1.3
# ...

# %%
first_df = pd.concat([ddf, df], axis=1)

# %%
first_df
# Out:
#                   County  State        Geographic Area Name  \
# 0          Austin County  Texas        Austin County, Texas
# 1          Kenedy County  Texas        Kenedy County, Texas
# 2          Nueces County  Texas        Nueces County, Texas
# 3        Colorado County  Texas      Colorado County, Texas
# 4    San Patricio County  Texas  San Patricio County, Texas
# ..                   ...    ...                         ...
# 249     McCulloch County  Texas     McCulloch County, Texas
# 250           Lee County  Texas           Lee County, Texas
# 251         Ellis County  Texas         Ellis County, Texas
# 252          Kerr County  Texas          Kerr County, Texas
# 253         Falls County  Texas         Falls County, Texas
#
#      Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                  0.6
# 1                                                 20.5
# ...

# %%
first_df['County'] = first_df['County'].str.replace(' County', '')

# %%
first_df
# Out:
#            County  State        Geographic Area Name  \
# 0          Austin  Texas        Austin County, Texas
# 1          Kenedy  Texas        Kenedy County, Texas
# 2          Nueces  Texas        Nueces County, Texas
# 3        Colorado  Texas      Colorado County, Texas
# 4    San Patricio  Texas  San Patricio County, Texas
# ..            ...    ...                         ...
# 249     McCulloch  Texas     McCulloch County, Texas
# 250           Lee  Texas           Lee County, Texas
# 251         Ellis  Texas         Ellis County, Texas
# 252          Kerr  Texas          Kerr County, Texas
# 253         Falls  Texas         Falls County, Texas
#
#      Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                  0.6
# 1                                                 20.5
# 2                                                  0.1
# 3                                                  0.1
# ...

# %%
first_df = first_df.drop(columns = 'Geographic Area Name')

# %%
first_df
# Out:
#            County  State  \
# 0          Austin  Texas
# 1          Kenedy  Texas
# 2          Nueces  Texas
# 3        Colorado  Texas
# 4    San Patricio  Texas
# ..            ...    ...
# 249     McCulloch  Texas
# 250           Lee  Texas
# 251         Ellis  Texas
# 252          Kerr  Texas
# 253         Falls  Texas
#
#      Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                  0.6
# 1                                                 20.5
# 2                                                  0.1
# 3                                                  0.1
# 4                                                  0.5
# ..                                                 ...
# 249                                                2.2
# 250                                                1.3
# 251                                                0.2
# 252                                                0.5
# ...

# %%
first_df.to_csv('./data/initial_cleaned_dp05.csv', index = False)
