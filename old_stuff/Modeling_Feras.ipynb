# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/texas_combined_cleaned_WITH_Census_Percentage_FA.csv')

# %%
data.head()
# Out:
#   county_name  total_cases  total_fatalities  death_rate  \
# 0    anderson       2922.0                39    0.013347
# 1     andrews        567.0                10    0.017637
# 2    angelina       2277.0                90    0.039526
# 3     aransas        340.0                18    0.052941
# 4      archer        133.0                 1    0.007519
#
#    sex_age_median_age_in_years  health_ins_noninst_pop_private  \
# 0                         39.1                           27169
# 1                         31.2                           11313
# 2                         37.2                           46576
# 3                         49.6                           13508
# 4                         44.5                            6429
#
#    health_ins_noninst_pop_public  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                          16504                 43355                  55852
# 1                           4332                 74233                  94962
# ...

# %%
counties_live = pd.read_csv('/Users/ferasaltwal/Downloads/covid-19-data-master/live/us-counties.csv')

# %%
counties_live
# Out:
#             date      county    state     fips  cases  deaths  \
# 0     2020-10-25     Autauga  Alabama   1001.0   2059    31.0
# 1     2020-10-25     Baldwin  Alabama   1003.0   6658    69.0
# 2     2020-10-25     Barbour  Alabama   1005.0   1033     9.0
# 3     2020-10-25        Bibb  Alabama   1007.0    840    14.0
# 4     2020-10-25      Blount  Alabama   1009.0   1932    25.0
# ...          ...         ...      ...      ...    ...     ...
# 3240  2020-10-25  Sweetwater  Wyoming  56037.0    462     2.0
# 3241  2020-10-25       Teton  Wyoming  56039.0    747     1.0
# 3242  2020-10-25       Uinta  Wyoming  56041.0    431     3.0
# 3243  2020-10-25    Washakie  Wyoming  56043.0    144     7.0
# 3244  2020-10-25      Weston  Wyoming  56045.0    127     0.0
#
#       confirmed_cases  confirmed_deaths  probable_cases  probable_deaths
# 0              1831.0              29.0           228.0              2.0
# 1              5644.0              65.0          1014.0              4.0
# ...

# %%
counties_live.sample(5)
# Out:
#             date    county       state     fips  cases  deaths  \
# 1576  2020-10-25     Perry    Missouri  29157.0    795     8.0
# 1790  2020-10-25  Atlantic  New Jersey  34001.0   5008   264.0
# 1042  2020-10-25   Grayson    Kentucky  21085.0    498    15.0
# 2885  2020-10-25      Juab        Utah  49023.0    246     3.0
# 814   2020-10-25      Clay        Iowa  19041.0    526     4.0
#
#       confirmed_cases  confirmed_deaths  probable_cases  probable_deaths
# 1576            795.0               8.0             NaN              NaN
# 1790           4997.0             253.0            11.0             11.0
# 1042              NaN               NaN             NaN              NaN
# 2885            246.0               3.0             NaN              NaN
# 814             526.0               4.0             NaN              NaN

# %%
florida_data = counties_live[counties_live['state'] == 'Florida']

# %%
florida_data.head(2)
# Out:
#            date   county    state     fips  cases  deaths  confirmed_cases  \
# 322  2020-10-25  Alachua  Florida  12001.0  10044    74.0              NaN
# 323  2020-10-25    Baker  Florida  12003.0   1750    19.0              NaN
#
#      confirmed_deaths  probable_cases  probable_deaths
# 322              74.0             NaN              NaN
# 323              19.0             NaN              NaN

# %%
counter = 0
for i in florida_data.cases:
    counter += i
print(counter)
# Out:
# 778628

# %%
counties_live['date'].max()
# Out:
# '2020-10-25'

# %%
us_live = pd.read_csv('/Users/ferasaltwal/Downloads/covid-19-data-master/live/us-states.csv')

# %%
us_live
# Out:
#           date                     state  fips   cases  deaths  \
# 0   2020-10-25                   Alabama     1  184355    2866
# 1   2020-10-25                    Alaska     2   13439      64
# 2   2020-10-25                   Arizona     4  238200    5874
# 3   2020-10-25                  Arkansas     5  105318    1797
# 4   2020-10-25                California     6  907597   17345
# 5   2020-10-25                  Colorado     8   94204    2243
# 6   2020-10-25               Connecticut     9   66052    4577
# 7   2020-10-25                  Delaware    10   23961     681
# 8   2020-10-25      District of Columbia    11   16767     642
# 9   2020-10-25                   Florida    12  778628   16428
# 10  2020-10-25                   Georgia    13  360344    7626
# 11  2020-10-25                      Guam    66    5110      70
# 12  2020-10-25                    Hawaii    15   14706     211
# 13  2020-10-25                     Idaho    16   58964     573
# ...
