# %% [markdown]
# ## Resources
# [TX County Obesity Data](https://gis.cdc.gov/grasp/diabetes/DiabetesAtlas.html)
#  Total, Adults Aged 20+ Years, Age-Adjusted Percentage, Texas, 2017
#  US Diabetes Surveillance System
#  www.cdc.gov/diabetes/data
#
# [County Obesity Data](https://www.countyhealthrankings.org/app/texas/2020/measure/factors/11/data)

# %% [markdown]
# # Imports

# %%
# Import the required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the data.
tx_df = pd.read_csv('../data/texas_combined_cleaned_WITH_Census_FA.csv')

tx_ob = pd.read_csv('../data/preprocessing/cleaned_tx_obesity.csv')

# %%
# Display the first few rows of the dataframe.
tx_df.head(3)
# Out:
#   county_name  total_cases  total_fatalities  death_rate  race_pop  \
# 0    anderson       2922.0                39    0.013347     57863
# 1     andrews        567.0                10    0.017637     17818
# 2    angelina       2277.0                90    0.039526     87607
#
#    race_pop_hispanic_or_latino_of_any_race  race_pop_white_alone  \
# 0                                    10142                 34312
# 1                                     9979                  7215
# 2                                    19174                 53216
#
#    race_pop_black_or_african_american_alone  \
# 0                                     12127
# 1                                       321
# 2                                     12834
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                               158                   319
# 1                                                 0                    63
# 2                                               107                   987
#
#    ...  inc_hhlds_100_000_to_149_999  inc_hhlds_150_000_to_199_999  \
# 0  ...                          1432                           422
# 1  ...                          1214                           398
# 2  ...                          3257                           985
#
#    inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                        240                 43355                  55852
# 1                        352                 74233                  94962
# 2                        639                 47714                  61152
#
#    inc_per_capita_inc_dol  inc_med_earn_workers_dol  \
# 0                   16868                     26621
# 1                   31190                     40478
# 2                   22322                     27411
#
#    inc_med_earn_male_full_yr_workers_dol  \
# 0                                  36865
# 1                                  72970
# 2                                  41488
#
#    inc_med_earn_female_full_yr_workers_dol  pop_density
# 0                                    26890    54.452632
# 1                                    35194    11.872960
# 2                                    32622   109.813207
#
# [3 rows x 54 columns]

# %%
# Merge the remainder dataframes on Geographic Area Name.
tx_df = tx_ob.merge(tx_df,on='county_name')
tx_df.head()
# Out:
#   county_name  obes_percent  total_cases  total_fatalities  death_rate  \
# 0    anderson         0.373       2922.0                39    0.013347
# 1     andrews         0.313        567.0                10    0.017637
# 2    angelina         0.396       2277.0                90    0.039526
# 3     aransas         0.377        340.0                18    0.052941
# 4      archer         0.283        133.0                 1    0.007519
#
#    race_pop  race_pop_hispanic_or_latino_of_any_race  race_pop_white_alone  \
# 0     57863                                    10142                 34312
# 1     17818                                     9979                  7215
# 2     87607                                    19174                 53216
# 3     24763                                     6756                 16691
# 4      8789                                      727                  7772
#
#    race_pop_black_or_african_american_alone  \
# 0                                     12127
# 1                                       321
# 2                                     12834
# 3                                       365
# 4                                        76
#
#    race_pop_american_indian_and_alaska_native_alone  ...  \
# 0                                               158  ...
# 1                                                 0  ...
# 2                                               107  ...
# 3                                                14  ...
# 4                                                27  ...
#
#    inc_hhlds_100_000_to_149_999  inc_hhlds_150_000_to_199_999  \
# 0                          1432                           422
# 1                          1214                           398
# 2                          3257                           985
# 3                          1047                           476
# 4                           626                           198
#
#    inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                        240                 43355                  55852
# 1                        352                 74233                  94962
# 2                        639                 47714                  61152
# 3                        496                 44865                  75471
# 4                        145                 64476                  80073
#
#    inc_per_capita_inc_dol  inc_med_earn_workers_dol  \
# 0                   16868                     26621
# 1                   31190                     40478
# 2                   22322                     27411
# 3                   30939                     21567
# 4                   31806                     32469
#
#    inc_med_earn_male_full_yr_workers_dol  \
# 0                                  36865
# 1                                  72970
# 2                                  41488
# 3                                  43182
# 4                                  49105
#
#    inc_med_earn_female_full_yr_workers_dol  pop_density
# 0                                    26890    54.452632
# 1                                    35194    11.872960
# 2                                    32622   109.813207
# 3                                    32005    98.246769
# 4                                    37377     9.729998
#
# [5 rows x 55 columns]

# %% [markdown]
# # Regression Modeling Obsesity + Pop Density

# %%
# Create a subset of columns for modeling.
# Extract columns for obesity-based model.
ob_mod_cols = ['death_rate', 'obes_percent', 'pop_density']

# %%
# Create a dataframe for age groups
tx_obes = tx_df[ob_mod_cols]

# %%
tx_obes
# Out:
#      death_rate  obes_percent  pop_density
# 0      0.013347          37.3    54.452632
# 1      0.017637          31.3    11.872960
# 2      0.039526          39.6   109.813207
# 3      0.052941          37.7    98.246769
# 4      0.007519          28.3     9.729998
# ..          ...           ...          ...
# 249    0.057971          33.1    67.904439
# 250    0.017301          29.5    10.717568
# 251    0.012072          35.9    19.807588
# 252    0.026316          30.2    14.391854
# 253    0.039823          28.6     9.350188
#
# [254 rows x 3 columns]

# %%
X = tx_obes[[
    'obes_percent',
    'pop_density'
]]

y = tx_obes['death_rate']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
ss = StandardScaler()
X_train_ss = ss.fit_transform(X_train)
X_test_ss = ss.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train_ss, y_train)
# Out:
# LinearRegression()

# %%
X_train.shape, y_test.shape
# Out:
# ((190, 2), (64,))

# %%
cross_val_score(lr, X_test_ss, y_test, cv=5).mean()
# Out:
# -0.22716049609446412
