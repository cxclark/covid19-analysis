# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('COVID_Cases_Restricted_detailed_09302020.csv')

# %%
df.head()
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt     sex  \
# 0     White, Non-Hispanic  Laboratory-confirmed case    2020-06-15  Female
# 1     White, Non-Hispanic  Laboratory-confirmed case    2020-07-29  Female
# 2     White, Non-Hispanic  Laboratory-confirmed case    2020-04-20  Female
# 3     White, Non-Hispanic  Laboratory-confirmed case    2020-04-21  Female
# 4     White, Non-Hispanic  Laboratory-confirmed case    2020-04-14  Female
#
#      onset_dt pos_spec_dt hosp_yn   icu_yn death_yn hc_work_yn  ... sob_yn  \
# 0  2020-05-20  2020-06-06      No  Missing       No         No  ...    Yes
# 1  2020-07-04  2020-07-12      No  Missing       No         No  ...    Yes
# 2  2020-02-26  2020-03-26      No  Missing       No         No  ...    Yes
# 3         NaN         NaN      No  Missing       No         No  ...    Yes
# 4  2020-04-08  2020-04-10      No  Missing       No         No  ...    Yes
#
# ...

# %%
#https://stackoverflow.com/questions/49188960/how-to-show-all-of-columns-name-on-pandas-dataframe
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#   race_ethnicity_combined             current_status cdc_report_dt     sex  \
# 0     White, Non-Hispanic  Laboratory-confirmed case    2020-06-15  Female
# 1     White, Non-Hispanic  Laboratory-confirmed case    2020-07-29  Female
# 2     White, Non-Hispanic  Laboratory-confirmed case    2020-04-20  Female
# 3     White, Non-Hispanic  Laboratory-confirmed case    2020-04-21  Female
# 4     White, Non-Hispanic  Laboratory-confirmed case    2020-04-14  Female
#
#      onset_dt pos_spec_dt hosp_yn   icu_yn death_yn hc_work_yn pna_yn  \
# 0  2020-05-20  2020-06-06      No  Missing       No         No     No
# 1  2020-07-04  2020-07-12      No  Missing       No         No     No
# 2  2020-02-26  2020-03-26      No  Missing       No         No     No
# 3         NaN         NaN      No  Missing       No         No     No
# 4  2020-04-08  2020-04-10      No  Missing       No         No     No
#
#   abxchest_yn acuterespdistress_yn mechvent_yn fever_yn sfever_yn chills_yn  \
# ...

# %%
df1 = df[df.res_state == 'TX']

# %%
df1.head()
# Out:
#      race_ethnicity_combined             current_status cdc_report_dt   sex  \
# 1463     White, Non-Hispanic  Laboratory-confirmed case    2020-07-19  Male
# 1464     White, Non-Hispanic  Laboratory-confirmed case    2020-06-04  Male
# 1465     White, Non-Hispanic  Laboratory-confirmed case    2020-07-22  Male
# 1466     White, Non-Hispanic  Laboratory-confirmed case    2020-08-14  Male
# 1467     White, Non-Hispanic  Laboratory-confirmed case    2020-06-21  Male
#
#         onset_dt pos_spec_dt  hosp_yn   icu_yn death_yn hc_work_yn   pna_yn  \
# 1463  2020-06-11         NaN  Missing  Missing  Missing    Missing  Missing
# 1464  2020-04-26         NaN  Missing  Missing  Missing    Missing  Missing
# 1465  2020-06-16         NaN  Missing  Missing  Missing    Missing  Missing
# 1466  2020-06-12         NaN  Missing  Missing  Missing    Missing  Missing
# 1467  2020-05-01         NaN  Missing  Missing  Missing    Missing  Missing
#
# ...

# %%
df1.shape
# Out:
# (35541, 31)

# %%
df1.isnull().sum()
# Out:
# race_ethnicity_combined     5964
# current_status                 0
# cdc_report_dt                  0
# sex                         3080
# onset_dt                   14168
# pos_spec_dt                35476
# hosp_yn                        0
# icu_yn                         0
# death_yn                       0
# hc_work_yn                  5969
# pna_yn                         0
# abxchest_yn                    0
# acuterespdistress_yn           0
# mechvent_yn                    0
# fever_yn                       0
# sfever_yn                      0
# chills_yn                      0
# myalgia_yn                     0
# runnose_yn                     0
# sthroat_yn                     0
# cough_yn                       0
# sob_yn                         0
# nauseavomit_yn                 0
# headache_yn                    0
# abdom_yn                       0
# diarrhea_yn                    0
# medcond_yn                     0
# county_fips_code             539
# ...

# %%
df1.eq('Missing').sum()
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# race_ethnicity_combined        0
# current_status                 0
# cdc_report_dt                  0
# sex                            0
# onset_dt                       0
# pos_spec_dt                    0
# hosp_yn                    35416
# icu_yn                     35468
# death_yn                   35440
# hc_work_yn                 29572
# pna_yn                     35483
# abxchest_yn                35484
# acuterespdistress_yn       35482
# mechvent_yn                35466
# fever_yn                   35478
# sfever_yn                  35463
# chills_yn                  35462
# myalgia_yn                 35463
# runnose_yn                 35462
# sthroat_yn                 35462
# cough_yn                   35450
# sob_yn                     35460
# ...

# %%
df2 = df1[['race_ethnicity_combined', 'current_status', 'cdc_report_dt', 'sex', 'onset_dt', 'pos_spec_dt', 'res_county', 'res_state', 'age_group']].copy()

# %%
df2.head()
# Out:
#      race_ethnicity_combined             current_status cdc_report_dt   sex  \
# 1463     White, Non-Hispanic  Laboratory-confirmed case    2020-07-19  Male
# 1464     White, Non-Hispanic  Laboratory-confirmed case    2020-06-04  Male
# 1465     White, Non-Hispanic  Laboratory-confirmed case    2020-07-22  Male
# 1466     White, Non-Hispanic  Laboratory-confirmed case    2020-08-14  Male
# 1467     White, Non-Hispanic  Laboratory-confirmed case    2020-06-21  Male
#
#         onset_dt pos_spec_dt res_county res_state      age_group
# 1463  2020-06-11         NaN     BRAZOS        TX  10 - 19 Years
# 1464  2020-04-26         NaN     BRAZOS        TX  10 - 19 Years
# 1465  2020-06-16         NaN     BRAZOS        TX  10 - 19 Years
# 1466  2020-06-12         NaN     BRAZOS        TX  10 - 19 Years
# 1467  2020-05-01         NaN     BRAZOS        TX  10 - 19 Years

# %%
df2.isnull().sum()
# Out:
# race_ethnicity_combined     5964
# current_status                 0
# cdc_report_dt                  0
# sex                         3080
# onset_dt                   14168
# pos_spec_dt                35476
# res_county                   516
# res_state                      0
# age_group                   2025
# dtype: int64

# %%
df2.shape
# Out:
# (35541, 9)

# %%
df2.drop(columns = 'pos_spec_dt', inplace = True)

# %%
df2['sex'].value_counts()
# Out:
# Male       21234
# Female     10691
# Unknown      536
# Name: sex, dtype: int64

# %%
df2['age_group'].value_counts()
# Out:
# 30 - 39 Years    7153
# 40 - 49 Years    6612
# 20 - 29 Years    6127
# 50 - 59 Years    5826
# 60 - 69 Years    3790
# 70 - 79 Years    1445
# 10 - 19 Years    1140
# 80+ Years         944
# 0 - 9 Years       479
# Name: age_group, dtype: int64

# %%
df2['current_status'].value_counts()
# Out:
# Laboratory-confirmed case    35537
# Probable Case                    4
# Name: current_status, dtype: int64

# %%
df2['race_ethnicity_combined'].value_counts()
# Out:
# Hispanic/Latino        12784
# Unknown                 6966
# White, Non-Hispanic     6012
# Black, Non-Hispanic     3419
# Asian, Non-Hispanic      396
# Name: race_ethnicity_combined, dtype: int64

# %%
df2.rename(columns={'race_ethnicity_combined': 'race_ethnicity', 'current_status': 'status', 'res_county': 'county', 'res_state': 'state'}, inplace=True)

# %%
df2
# Out:
#               race_ethnicity                     status cdc_report_dt   sex  \
# 1463     White, Non-Hispanic  Laboratory-confirmed case    2020-07-19  Male
# 1464     White, Non-Hispanic  Laboratory-confirmed case    2020-06-04  Male
# 1465     White, Non-Hispanic  Laboratory-confirmed case    2020-07-22  Male
# 1466     White, Non-Hispanic  Laboratory-confirmed case    2020-08-14  Male
# 1467     White, Non-Hispanic  Laboratory-confirmed case    2020-06-21  Male
# ...                      ...                        ...           ...   ...
# 4477350              Unknown  Laboratory-confirmed case    2020-08-14  Male
# 4477351              Unknown  Laboratory-confirmed case    2020-08-14  Male
# 4477352              Unknown  Laboratory-confirmed case    2020-08-14  Male
# 4477353              Unknown  Laboratory-confirmed case    2020-07-31  Male
# 4477354              Unknown  Laboratory-confirmed case    2020-06-05  Male
#
#            onset_dt  county state      age_group
# ...

# %%
df2.to_csv('COVID19_Texas_Cases.csv', index = False)
