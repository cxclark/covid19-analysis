# %% [markdown]
# ## Contents
# - [Data Dictionary](#Data-Dictionary)
# - [Importing and Combining COVID Data](#Importing-and-Combining-COVID-Data)
# - [Importing and Combining Census Number Data](#Importing-and-Combining-Census-Number-Data)
# - [Combining COVID and Census Data](#Combining-COVID-and-Census-Data)
# - [Feature Engineering](#Feature-Engineering)
# - [Dataframe to Hold Both Total Numbers and Percent Values](#Dataframe-to-Hold-Both-Total-Numbers-and-Percent-Values)
# - [Dataframe to Hold Percent Values](#Dataframe-to-Hold-Percent-Values)

# %% [markdown]
# # Data Dictionary
#
# |Column Label|Type|Description
# |------------|----|-----------|
# |health_ins_noninst_pop|int|(Discrete): Total population civilian noninstitutionalized used to calculate yes/no coverage %
# |health_ins_noninst_pop_cov_no|int| (Discrete): Population civilian noninstitutionalized without health insurance coverage
# |health_ins_noninst_pop_cov_yes|int|(Discrete): Population civilian noninstitutionalized with health insurance coverage
# |health_ins_noninst_pop_private|int|(Discrete): Population civilian noninstitutionalized with private health insurance
# |health_ins_noninst_pop_public|int|(Discrete): Population civilian noninstitutionalized with public coverage
# |inc_hhlds|int|(Discrete): Total households used to calculate household income %
# |inc_hhlds_less_than_10_000|int|(Discrete): Households less than 10,000 income
# |inc_hhlds_10_000_to_14_999|int|(Discrete): Households 10,000 to 14,999 income
# |inc_hhlds_15_000_to_24_999|int|(Discrete): Households 15,000 to 24,999 income
# |inc_hhlds_25_000_to_34_999|int|(Discrete): Households 25,000 to 34,999 income
# |inc_hhlds_35_000_to_49_999|int|(Discrete): Households 35,000 to 49,999 income
# |inc_hhlds_50_000_to_74_999|int|(Discrete): Households 50,000 to 74,999 income
# |inc_hhlds_75_000_to_99_999|int|(Discrete): Households 75,000 to 99,999 income
# |inc_hhlds_100_000_to_149_999|int|(Discrete): Households 100,000 to 149,999 income
# |inc_hhlds_150_000_to_199_999|int|(Discrete): Households 150,000 to 199,999 income
# |inc_hhlds_200_000_or_more|int|(Discrete): Households 200,000+ income
# |inc_mean_hhld_inc_dol|int|(Discrete): Mean household income (dollars)
# |inc_med_hhld_inc_dol|int|(Discrete): Median household income (dollars)
# |inc_med_earn_female_full_yr_workers_dol|int|(Discrete): Median earnings for female full-time, year-round workers (dollars)
# |inc_med_earn_male_full_yr_workers_dol|int|(Discrete): Median earnings for male full-time, year-round workers (dollars)
# |inc_per_capita_inc_dol|int|(Discrete): Per capita income (dollars)
# |obes_percent|float|(Continuous): Population obesity percentage
# |pop_density|float|(Continuous): People per square mile
# |race_pop|int|(Discrete): Total population used to calculate race demographic %
# |race_pop_american_indian_and_alaska_native_alone|int|(Discrete): Population American Indian and Alaska Native
# |race_pop_asian_alone|int|(Discrete): Population Asian
# |race_pop_black_or_african_american_alone|int|(Discrete): Population Black or African American
# |race_pop_hispanic_or_latino_of_any_race|int|(Discrete): Population Hispanic or Latino of any race
# |race_pop_native_hawaiian_and_other_pacific_islander_alone|int|(Discrete): Population Native Hawaiian or other Pacific Islander
# |race_pop_some_other_race_alone|int|(Discrete): Population some other race
# |race_pop_two_or_more_races|int|(Discrete): Population two or more races
# |race_pop_white_alone|int|(Discrete): Population White
# |sex_age_median_age_in_years|float|(Continuous): Median age (years)
# |sex_age_pop|int|(Discrete): Total population used to calculate sex/age demographic %
# |sex_age_pop_under_5|int|(Discrete): Population under 5
# |sex_age_pop_5_to_9|int|(Discrete): Population 5-9
# |sex_age_pop_10_to_14|int|(Discrete): Population 10-14
# |sex_age_pop_15_to_19|int|(Discrete): Population 15-19
# |sex_age_pop_20_to_24|int|(Discrete): Population 20-24
# |sex_age_pop_25_to_34|int|(Discrete): Population 25-34
# |sex_age_pop_35_to_44|int|(Discrete): Population 35-44
# |sex_age_pop_45_to_54|int|(Discrete): Population 45-54
# |sex_age_pop_55_to_59|int|(Discrete): Population 55-59
# |sex_age_pop_60_to_64|int|(Discrete): Population 60-64
# |sex_age_pop_65_to_74|int|(Discrete): Population 65-74
# |sex_age_pop_75_to_84|int|(Discrete): Population 75-84
# |sex_age_pop_85_and_over|int|(Discrete): Population 85+
# |sex_age_pop_female|int|(Discrete): Population females
# |sex_age_pop_male|int|(Discrete): Population male
# |sq_mi|float|(Continuous): Square miles

# %%
import pandas as pd

# %% [markdown]
# # Importing and Combining COVID Data

# %%
# Import the relevant dataframes.
ca = pd.read_csv('../data/preprocessing/cleaned_covid_ca.csv')
fl = pd.read_csv('../data/preprocessing/cleaned_covid_fl.csv')
il = pd.read_csv('../data/preprocessing/cleaned_covid_il.csv')
ny = pd.read_csv('../data/preprocessing/cleaned_covid_ny.csv')
tx = pd.read_csv('../data/preprocessing/cleaned_covid_tx.csv')

# %%
# Display the first few rows of data. 
ca.head(2)
# Out:
#              Geographic Area Name  total_cases  total_fatalities  death_rate  \
# 0  Santa Clara County, California      23978.0             388.0    0.016181
# 1    San Mateo County, California      10942.0             159.0    0.014531
#
#    total_tests
# 0       839764
# 1       285657

# %%
# Display the first few rows of data. 
fl.head(2)
# Out:
#       Geographic Area Name  total_cases  total_fatalities  death_rate  \
# 0  Alachua County, Florida        10044                74    0.007368
# 1    Baker County, Florida         1750                19    0.010857
#
#    total_tests
# 0       110327
# 1         9005

# %%
# Display the first few rows of data. 
il.head(2)
# Out:
#          Geographic Area Name  total_cases  total_fatalities  death_rate  \
# 0      Adams County, Illinois         1862                19    0.010204
# 1  Alexander County, Illinois          120                 1    0.008333
#
#    total_tests
# 0        38542
# 1         2350

# %%
# Display the first few rows of data. 
ny.head(2)
# Out:
#         Geographic Area Name  total_cases  total_fatalities  death_rate  \
# 0    Albany County, New York         3577               128    0.035784
# 1  Allegany County, New York          271                 9    0.033210
#
#    total_tests
# 0       176101
# 1        24790

# %%
# Display the first few rows of data. 
tx.head(2)
# Out:
#      Geographic Area Name  total_cases  total_fatalities  death_rate  \
# 0  Anderson County, Texas         2941                39    0.013261
# 1   Andrews County, Texas          584                10    0.017123
#
#    total_tests
# 0        30052
# 1         2127

# %%
covid = pd.concat([ca, fl, il, ny, tx])
covid
# Out:
#                  Geographic Area Name  total_cases  total_fatalities  \
# 0      Santa Clara County, California      23978.0             388.0
# 1        San Mateo County, California      10942.0             159.0
# 2    Santa Barbara County, California       9781.0             120.0
# 3         Tuolumne County, California        269.0               4.0
# 4           Sierra County, California          6.0               0.0
# ..                                ...          ...               ...
# 249                Wood County, Texas        626.0              39.0
# 250              Yoakum County, Texas        289.0               6.0
# 251               Young County, Texas        535.0               8.0
# 252              Zapata County, Texas        345.0               9.0
# 253              Zavala County, Texas        460.0              18.0
#
#      death_rate  total_tests
# 0      0.016181       839764
# 1      0.014531       285657
# 2      0.012269       158693
# 3      0.014870        20986
# 4      0.000000          641
# ..          ...          ...
# 249    0.062300         6844
# 250    0.020761         1531
# 251    0.014953         3363
# 252    0.026087         4355
# 253    0.039130         2520
#
# [543 rows x 5 columns]

# %% [markdown]
# # Importing and Combining Census Number Data

# %%
# Import the relevant dataframes.
race = pd.read_csv('../data/preprocessing/cleaned_dp05_race_five_states.csv')
sa = pd.read_csv('../data/preprocessing/cleaned_dp05_sex_age_five_states.csv')
land = pd.read_csv('../data/preprocessing/cleaned_area_five_states.csv')
ins = pd.read_csv('../data/preprocessing/cleaned_dp03_insurance_five_states.csv')
inc = pd.read_csv('../data/preprocessing/cleaned_dp03_income_five_states.csv')
obes = pd.read_csv('../data/preprocessing/cleaned_obesity_five_states.csv')

# %%
# Display the first few rows of data. 
race.head(2)
# Out:
#    Geographic Area Name  race_pop  race_pop_hispanic_or_latino_of_any_race  \
# 0  Austin County, Texas     29565                                     7819
# 1  Kenedy County, Texas       595                                      522
#
#    race_pop_white_alone  race_pop_black_or_african_american_alone  \
# 0                 18525                                      2576
# 1                    72                                         0
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races
# 0                              52                         456
# 1                               0                           0

# %%
# Display the first few rows of data. 
sa.head(2)
# Out:
#    Geographic Area Name  sex_age_pop  sex_age_pop_male  sex_age_pop_female  \
# 0  Austin County, Texas        29565             14684               14881
# 1  Kenedy County, Texas          595               286                 309
#
#    sex_age_pop_under_5  sex_age_pop_5_to_9  sex_age_pop_10_to_14  \
# 0                 1780                1960                  2118
# 1                   85                  37                    40
#
#    sex_age_pop_15_to_19  sex_age_pop_20_to_24  sex_age_pop_25_to_34  \
# 0                  1861                  1712                  3339
# 1                    10                    10                    95
#
#    sex_age_pop_35_to_44  sex_age_pop_45_to_54  sex_age_pop_55_to_59  \
# 0                  3275                  3821                  2327
# 1                    47                    75                    51
#
#    sex_age_pop_60_to_64  sex_age_pop_65_to_74  sex_age_pop_75_to_84  \
# 0                  1978                  3243                  1532
# 1                     9                    85                    29
#
#    sex_age_pop_85_and_over  sex_age_median_age_in_years
# 0                      619                         40.7
# 1                       22                         39.5

# %%
# Display the first few rows of data. 
land.head(2)
# Out:
#      Geographic Area Name     sq_mi
# 0  Anderson County, Texas  1062.630
# 1   Andrews County, Texas  1500.721

# %%
# Display the first few rows of data. 
ins.head(2)
# Out:
#    Geographic Area Name  health_ins_noninst_pop  \
# 0  Austin County, Texas                   29298
# 1  Kenedy County, Texas                     595
#
#    health_ins_noninst_pop_cov_yes  health_ins_noninst_pop_private  \
# 0                           25749                           20393
# 1                             467                             212
#
#    health_ins_noninst_pop_public  health_ins_noninst_pop_cov_no
# 0                           8863                           3549
# 1                            276                            128

# %%
# Display the first few rows of data. 
inc.head(2)
# Out:
#    Geographic Area Name  inc_hhlds  inc_hhlds_less_than_10_000  \
# 0  Austin County, Texas      11041                         482
# 1  Kenedy County, Texas        209                          25
#
#    inc_hhlds_10_000_to_14_999  inc_hhlds_15_000_to_24_999  \
# 0                         459                        1255
# 1                           4                          49
#
#    inc_hhlds_25_000_to_34_999  inc_hhlds_35_000_to_49_999  \
# 0                         927                        1186
# 1                          13                          71
#
#    inc_hhlds_50_000_to_74_999  inc_hhlds_75_000_to_99_999  \
# 0                        1851                        1651
# 1                          16                          23
#
#    inc_hhlds_100_000_to_149_999  inc_hhlds_150_000_to_199_999  \
# 0                          2150                           551
# 1                             8                             0
#
#    inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                        529                 65365                  80769
# 1                          0                 36125                  40908
#
#    inc_per_capita_inc_dol  inc_med_earn_male_full_yr_workers_dol  \
# 0                   30858                                  55417
# 1                   15820                                  40848
#
#    inc_med_earn_female_full_yr_workers_dol
# 0                                    38603
# 1                                    23295

# %%
# Display the first few rows of data. 
obes.head(2)
# Out:
#      Geographic Area Name  obes_percent
# 0  Anderson County, Texas         0.373
# 1   Andrews County, Texas         0.313

# %%
# Merge the first three dataframes on Geographic Area Name.
# This will be the dataframe for tracking total numbers.
df_num = race.merge(sa,on='Geographic Area Name').merge(land,on='Geographic Area Name').merge(obes,on='Geographic Area Name')
df_num.head(2)
# Out:
#    Geographic Area Name  race_pop  race_pop_hispanic_or_latino_of_any_race  \
# 0  Austin County, Texas     29565                                     7819
# 1  Kenedy County, Texas       595                                      522
#
#    race_pop_white_alone  race_pop_black_or_african_american_alone  \
# 0                 18525                                      2576
# 1                    72                                         0
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races  ...  \
# 0                              52                         456  ...
# 1                               0                           0  ...
#
#    sex_age_pop_35_to_44  sex_age_pop_45_to_54  sex_age_pop_55_to_59  \
# 0                  3275                  3821                  2327
# 1                    47                    75                    51
#
#    sex_age_pop_60_to_64  sex_age_pop_65_to_74  sex_age_pop_75_to_84  \
# 0                  1978                  3243                  1532
# 1                     9                    85                    29
#
#    sex_age_pop_85_and_over  sex_age_median_age_in_years     sq_mi  \
# 0                      619                         40.7   646.492
# 1                       22                         39.5  1458.453
#
#    obes_percent
# 0          0.32
# 1          0.22
#
# [2 rows x 29 columns]

# %%
# Merge the remainder dataframes on Geographic Area Name.
df_num = df_num.merge(ins,on='Geographic Area Name').merge(inc,on='Geographic Area Name')
df_num.head(2)
# Out:
#    Geographic Area Name  race_pop  race_pop_hispanic_or_latino_of_any_race  \
# 0  Austin County, Texas     29565                                     7819
# 1  Kenedy County, Texas       595                                      522
#
#    race_pop_white_alone  race_pop_black_or_african_american_alone  \
# 0                 18525                                      2576
# 1                    72                                         0
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races  ...  \
# 0                              52                         456  ...
# 1                               0                           0  ...
#
#    inc_hhlds_50_000_to_74_999  inc_hhlds_75_000_to_99_999  \
# 0                        1851                        1651
# 1                          16                          23
#
#    inc_hhlds_100_000_to_149_999  inc_hhlds_150_000_to_199_999  \
# 0                          2150                           551
# 1                             8                             0
#
#    inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                        529                 65365                  80769
# 1                          0                 36125                  40908
#
#    inc_per_capita_inc_dol  inc_med_earn_male_full_yr_workers_dol  \
# 0                   30858                                  55417
# 1                   15820                                  40848
#
#    inc_med_earn_female_full_yr_workers_dol
# 0                                    38603
# 1                                    23295
#
# [2 rows x 50 columns]

# %% [markdown]
# # Combining COVID and Census Data

# %%
# Merge the remainder dataframes on Geographic Area Name.
df_num = covid.merge(df_num,on='Geographic Area Name')

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 0 to 542
# Data columns (total 54 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Geographic Area Name                                       543 non-null    object
#  1   total_cases                                                543 non-null    float64
#  2   total_fatalities                                           543 non-null    float64
#  3   death_rate                                                 542 non-null    float64
#  4   total_tests                                                543 non-null    int64
#  5   race_pop                                                   543 non-null    int64
#  6   race_pop_hispanic_or_latino_of_any_race                    543 non-null    int64
#  7   race_pop_white_alone                                       543 non-null    int64
#  8   race_pop_black_or_african_american_alone                   543 non-null    int64
#  9   race_pop_american_indian_and_alaska_native_alone           543 non-null    int64
#  10  race_pop_asian_alone                                       543 non-null    int64
#  11  race_pop_native_hawaiian_and_other_pacific_islander_alone  543 non-null    int64
#  12  race_pop_some_other_race_alone                             543 non-null    int64
#  13  race_pop_two_or_more_races                                 543 non-null    int64
#  14  sex_age_pop                                                543 non-null    int64
#  15  sex_age_pop_male                                           543 non-null    int64
#  16  sex_age_pop_female                                         543 non-null    int64
#  17  sex_age_pop_under_5                                        543 non-null    int64
#  18  sex_age_pop_5_to_9                                         543 non-null    int64
#  19  sex_age_pop_10_to_14                                       543 non-null    int64
#  20  sex_age_pop_15_to_19                                       543 non-null    int64
#  21  sex_age_pop_20_to_24                                       543 non-null    int64
#  22  sex_age_pop_25_to_34                                       543 non-null    int64
#  23  sex_age_pop_35_to_44                                       543 non-null    int64
#  24  sex_age_pop_45_to_54                                       543 non-null    int64
#  25  sex_age_pop_55_to_59                                       543 non-null    int64
#  26  sex_age_pop_60_to_64                                       543 non-null    int64
#  27  sex_age_pop_65_to_74                                       543 non-null    int64
#  28  sex_age_pop_75_to_84                                       543 non-null    int64
#  29  sex_age_pop_85_and_over                                    543 non-null    int64
#  30  sex_age_median_age_in_years                                543 non-null    float64
#  31  sq_mi                                                      543 non-null    float64
#  32  obes_percent                                               543 non-null    float64
#  33  health_ins_noninst_pop                                     543 non-null    int64
#  34  health_ins_noninst_pop_cov_yes                             543 non-null    int64
#  35  health_ins_noninst_pop_private                             543 non-null    int64
#  36  health_ins_noninst_pop_public                              543 non-null    int64
#  37  health_ins_noninst_pop_cov_no                              543 non-null    int64
#  38  inc_hhlds                                                  543 non-null    int64
#  39  inc_hhlds_less_than_10_000                                 543 non-null    int64
#  40  inc_hhlds_10_000_to_14_999                                 543 non-null    int64
#  41  inc_hhlds_15_000_to_24_999                                 543 non-null    int64
#  42  inc_hhlds_25_000_to_34_999                                 543 non-null    int64
#  43  inc_hhlds_35_000_to_49_999                                 543 non-null    int64
#  44  inc_hhlds_50_000_to_74_999                                 543 non-null    int64
#  45  inc_hhlds_75_000_to_99_999                                 543 non-null    int64
#  46  inc_hhlds_100_000_to_149_999                               543 non-null    int64
#  47  inc_hhlds_150_000_to_199_999                               543 non-null    int64
#  48  inc_hhlds_200_000_or_more                                  543 non-null    int64
#  49  inc_med_hhld_inc_dol                                       543 non-null    int64
#  50  inc_mean_hhld_inc_dol                                      543 non-null    int64
#  51  inc_per_capita_inc_dol                                     543 non-null    int64
#  52  inc_med_earn_male_full_yr_workers_dol                      543 non-null    int64
#  53  inc_med_earn_female_full_yr_workers_dol                    543 non-null    int64
# dtypes: float64(6), int64(47), object(1)
# memory usage: 233.3+ KB

# %% [markdown]
# # Feature Engineering

# %%
df_num['deaths_per_100_cases'] = df_num['death_rate'] * 100

# %%
df_num['cases_per_100_people'] =  (df_num['total_cases']/df_num['race_pop']) * 100

# %%
df_num['tests_per_100_people'] = (df_num['total_tests']/df_num['race_pop']) * 100

# %%
# Display the columns.
list(df_num.columns)
# Out:
# ['Geographic Area Name',
#  'total_cases',
#  'total_fatalities',
#  'death_rate',
#  'total_tests',
#  'race_pop',
#  'race_pop_hispanic_or_latino_of_any_race',
#  'race_pop_white_alone',
#  'race_pop_black_or_african_american_alone',
#  'race_pop_american_indian_and_alaska_native_alone',
#  'race_pop_asian_alone',
#  'race_pop_native_hawaiian_and_other_pacific_islander_alone',
#  'race_pop_some_other_race_alone',
#  'race_pop_two_or_more_races',
#  'sex_age_pop',
#  'sex_age_pop_male',
#  'sex_age_pop_female',
#  'sex_age_pop_under_5',
#  'sex_age_pop_5_to_9',
#  'sex_age_pop_10_to_14',
#  'sex_age_pop_15_to_19',
#  'sex_age_pop_20_to_24',
#  'sex_age_pop_25_to_34',
#  'sex_age_pop_35_to_44',
#  'sex_age_pop_45_to_54',
#  'sex_age_pop_55_to_59',
#  'sex_age_pop_60_to_64',
#  'sex_age_pop_65_to_74',
#  'sex_age_pop_75_to_84',
#  'sex_age_pop_85_and_over',
#  'sex_age_median_age_in_years',
#  'sq_mi',
#  'obes_percent',
#  'health_ins_noninst_pop',
#  'health_ins_noninst_pop_cov_yes',
#  'health_ins_noninst_pop_private',
#  'health_ins_noninst_pop_public',
#  'health_ins_noninst_pop_cov_no',
#  'inc_hhlds',
#  'inc_hhlds_less_than_10_000',
#  'inc_hhlds_10_000_to_14_999',
#  'inc_hhlds_15_000_to_24_999',
#  'inc_hhlds_25_000_to_34_999',
#  'inc_hhlds_35_000_to_49_999',
#  'inc_hhlds_50_000_to_74_999',
#  'inc_hhlds_75_000_to_99_999',
#  'inc_hhlds_100_000_to_149_999',
#  'inc_hhlds_150_000_to_199_999',
#  'inc_hhlds_200_000_or_more',
#  'inc_med_hhld_inc_dol',
#  'inc_mean_hhld_inc_dol',
#  'inc_per_capita_inc_dol',
#  'inc_med_earn_male_full_yr_workers_dol',
#  'inc_med_earn_female_full_yr_workers_dol',
#  'deaths_per_100_cases',
#  'cases_per_100_people',
#  'tests_per_100_people']

# %%
# Rename the median age column for the function.
df_num = df_num.rename(columns={'Geographic Area Name': 'county_state'})

# %%
# Set the index to the geography.
df_num = df_num.set_index('county_state')

# %%
# Display the first few rows of the dataframe.
df_num.head(2)
# Out:
#                                 total_cases  total_fatalities  death_rate  \
# county_state
# Santa Clara County, California      23978.0             388.0    0.016181
# San Mateo County, California        10942.0             159.0    0.014531
#
#                                 total_tests  race_pop  \
# county_state
# Santa Clara County, California       839764   1922200
# San Mateo County, California         285657    765935
#
#                                 race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Santa Clara County, California                                   495455
# San Mateo County, California                                     189002
#
#                                 race_pop_white_alone  \
# county_state
# Santa Clara County, California                615912
# San Mateo County, California                  303047
#
#                                 race_pop_black_or_african_american_alone  \
# county_state
# Santa Clara County, California                                     45379
# San Mateo County, California                                       16838
#
#                                 race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Santa Clara County, California                                              3003
# San Mateo County, California                                                1151
#
#                                 race_pop_asian_alone  ...  \
# county_state                                          ...
# Santa Clara County, California                685265  ...
# San Mateo County, California                  212474  ...
#
#                                 inc_hhlds_150_000_to_199_999  \
# county_state
# Santa Clara County, California                         83325
# San Mateo County, California                           32301
#
#                                 inc_hhlds_200_000_or_more  \
# county_state
# Santa Clara County, California                     160340
# San Mateo County, California                        67087
#
#                                 inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# county_state
# Santa Clara County, California                116178                 154183
# San Mateo County, California                  113776                 162639
#
#                                 inc_per_capita_inc_dol  \
# county_state
# Santa Clara County, California                   52451
# San Mateo County, California                     57375
#
#                                 inc_med_earn_male_full_yr_workers_dol  \
# county_state
# Santa Clara County, California                                  90862
# San Mateo County, California                                    79347
#
#                                 inc_med_earn_female_full_yr_workers_dol  \
# county_state
# Santa Clara County, California                                    64739
# San Mateo County, California                                      65524
#
#                                 deaths_per_100_cases  cases_per_100_people  \
# county_state
# Santa Clara County, California              1.618150              1.247425
# San Mateo County, California                1.453116              1.428581
#
#                                 tests_per_100_people
# county_state
# Santa Clara County, California             43.687650
# San Mateo County, California               37.295201
#
# [2 rows x 56 columns]

# %%
# Compare the base populations to be used in calculations.
df_num[['race_pop', 'sex_age_pop', 'health_ins_noninst_pop', 'inc_hhlds']]
# Out:
#                                   race_pop  sex_age_pop  \
# county_state
# Santa Clara County, California     1922200      1922200
# San Mateo County, California        765935       765935
# Santa Barbara County, California    443738       443738
# Tuolumne County, California          53932        53932
# Sierra County, California             2930         2930
# ...                                    ...          ...
# Wood County, Texas                   43815        43815
# Yoakum County, Texas                  8571         8571
# Young County, Texas                  18114        18114
# Zapata County, Texas                 14369        14369
# Zavala County, Texas                 12131        12131
#
#                                   health_ins_noninst_pop  inc_hhlds
# county_state
# Santa Clara County, California                   1912773     635525
# San Mateo County, California                      762101     261969
# Santa Barbara County, California                  436711     144962
# Tuolumne County, California                        50912      22427
# Sierra County, California                           2903       1241
# ...                                                  ...        ...
# Wood County, Texas                                 42880      16531
# Yoakum County, Texas                                8571       2676
# Young County, Texas                                17825       7105
# Zapata County, Texas                               14334       4405
# Zavala County, Texas                               11935       3509
#
# [543 rows x 4 columns]

# %%
# Create a new column for county population density which is the result of
# dividing population by square miles
df_num['pop_density'] = df_num['race_pop'] / df_num['sq_mi']

# %%
df_num.head(2)
# Out:
#                                 total_cases  total_fatalities  death_rate  \
# county_state
# Santa Clara County, California      23978.0             388.0    0.016181
# San Mateo County, California        10942.0             159.0    0.014531
#
#                                 total_tests  race_pop  \
# county_state
# Santa Clara County, California       839764   1922200
# San Mateo County, California         285657    765935
#
#                                 race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Santa Clara County, California                                   495455
# San Mateo County, California                                     189002
#
#                                 race_pop_white_alone  \
# county_state
# Santa Clara County, California                615912
# San Mateo County, California                  303047
#
#                                 race_pop_black_or_african_american_alone  \
# county_state
# Santa Clara County, California                                     45379
# San Mateo County, California                                       16838
#
#                                 race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Santa Clara County, California                                              3003
# San Mateo County, California                                                1151
#
#                                 race_pop_asian_alone  ...  \
# county_state                                          ...
# Santa Clara County, California                685265  ...
# San Mateo County, California                  212474  ...
#
#                                 inc_hhlds_200_000_or_more  \
# county_state
# Santa Clara County, California                     160340
# San Mateo County, California                        67087
#
#                                 inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# county_state
# Santa Clara County, California                116178                 154183
# San Mateo County, California                  113776                 162639
#
#                                 inc_per_capita_inc_dol  \
# county_state
# Santa Clara County, California                   52451
# San Mateo County, California                     57375
#
#                                 inc_med_earn_male_full_yr_workers_dol  \
# county_state
# Santa Clara County, California                                  90862
# San Mateo County, California                                    79347
#
#                                 inc_med_earn_female_full_yr_workers_dol  \
# county_state
# Santa Clara County, California                                    64739
# San Mateo County, California                                      65524
#
#                                 deaths_per_100_cases  cases_per_100_people  \
# county_state
# Santa Clara County, California              1.618150              1.247425
# San Mateo County, California                1.453116              1.428581
#
#                                 tests_per_100_people  pop_density
# county_state
# Santa Clara County, California             43.687650  1488.824137
# San Mateo County, California               37.295201  1707.252650
#
# [2 rows x 57 columns]

# %%
# Export the data.
df_num.to_csv('../data/cleaned_numbers_five_states.csv')

# %% [markdown]
# # Dataframe to Hold Both Total Numbers and Percent Values

# %%
# Make a copy of the dataframe that will hold total numbers AND percentages.
df = df_num.copy()

# %%
for column in df.columns:
    print(column)
# Out:
# total_cases
# total_fatalities
# death_rate
# total_tests
# race_pop
# race_pop_hispanic_or_latino_of_any_race
# race_pop_white_alone
# race_pop_black_or_african_american_alone
# race_pop_american_indian_and_alaska_native_alone
# race_pop_asian_alone
# race_pop_native_hawaiian_and_other_pacific_islander_alone
# race_pop_some_other_race_alone
# race_pop_two_or_more_races
# sex_age_pop
# sex_age_pop_male
# sex_age_pop_female
# sex_age_pop_under_5
# sex_age_pop_5_to_9
# sex_age_pop_10_to_14
# sex_age_pop_15_to_19
# sex_age_pop_20_to_24
# sex_age_pop_25_to_34
# sex_age_pop_35_to_44
# sex_age_pop_45_to_54
# sex_age_pop_55_to_59
# sex_age_pop_60_to_64
# sex_age_pop_65_to_74
# sex_age_pop_75_to_84
# sex_age_pop_85_and_over
# sex_age_median_age_in_years
# sq_mi
# obes_percent
# health_ins_noninst_pop
# health_ins_noninst_pop_cov_yes
# health_ins_noninst_pop_private
# health_ins_noninst_pop_public
# health_ins_noninst_pop_cov_no
# inc_hhlds
# inc_hhlds_less_than_10_000
# inc_hhlds_10_000_to_14_999
# inc_hhlds_15_000_to_24_999
# inc_hhlds_25_000_to_34_999
# inc_hhlds_35_000_to_49_999
# inc_hhlds_50_000_to_74_999
# inc_hhlds_75_000_to_99_999
# inc_hhlds_100_000_to_149_999
# inc_hhlds_150_000_to_199_999
# inc_hhlds_200_000_or_more
# inc_med_hhld_inc_dol
# inc_mean_hhld_inc_dol
# inc_per_capita_inc_dol
# inc_med_earn_male_full_yr_workers_dol
# inc_med_earn_female_full_yr_workers_dol
# deaths_per_100_cases
# cases_per_100_people
# tests_per_100_people
# pop_density

# %% [markdown]
# # Dataframe to Hold Percent Values

# %%
# Define a function to create new columns with percentages.
def to_percentage(dataframe):
    
    for column in dataframe.columns:
        if column.startswith('race_pop_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['race_pop']
        
        elif column.startswith('sex_age_pop_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['sex_age_pop']
            
        elif column.startswith('health_ins_noninst_pop_cov'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['health_ins_noninst_pop']
            
        elif column.startswith('inc_hhlds_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['inc_hhlds']
    
    return

# %%
# Apply the function to the numbers dataframe
to_percentage(df)

# %%
# Display the first few rows of the dataframe. 
df.head(2)
# Out:
#                                 total_cases  total_fatalities  death_rate  \
# county_state
# Santa Clara County, California      23978.0             388.0    0.016181
# San Mateo County, California        10942.0             159.0    0.014531
#
#                                 total_tests  race_pop  \
# county_state
# Santa Clara County, California       839764   1922200
# San Mateo County, California         285657    765935
#
#                                 race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Santa Clara County, California                                   495455
# San Mateo County, California                                     189002
#
#                                 race_pop_white_alone  \
# county_state
# Santa Clara County, California                615912
# San Mateo County, California                  303047
#
#                                 race_pop_black_or_african_american_alone  \
# county_state
# Santa Clara County, California                                     45379
# San Mateo County, California                                       16838
#
#                                 race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Santa Clara County, California                                              3003
# San Mateo County, California                                                1151
#
#                                 race_pop_asian_alone  ...  \
# county_state                                          ...
# Santa Clara County, California                685265  ...
# San Mateo County, California                  212474  ...
#
#                                 percent_inc_hhlds_less_than_10_000  \
# county_state
# Santa Clara County, California                            0.032184
# San Mateo County, California                              0.029114
#
#                                 percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Santa Clara County, California                            0.027568
# San Mateo County, California                              0.023087
#
#                                 percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Santa Clara County, California                            0.045773
# San Mateo County, California                              0.044536
#
#                                 percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Santa Clara County, California                            0.046066
# San Mateo County, California                              0.047429
#
#                                 percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Santa Clara County, California                            0.069604
# San Mateo County, California                              0.069649
#
#                                 percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Santa Clara County, California                            0.112076
# San Mateo County, California                              0.115617
#
#                                 percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Santa Clara County, California                            0.102890
# San Mateo County, California                              0.110609
#
#                                 percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Santa Clara County, California                              0.180432
# San Mateo County, California                                0.180571
#
#                                 percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Santa Clara County, California                              0.131112
# San Mateo County, California                                0.123301
#
#                                 percent_inc_hhlds_200_000_or_more
# county_state
# Santa Clara County, California                           0.252295
# San Mateo County, California                             0.256088
#
# [2 rows x 92 columns]

# %%
# Extract the columns with percentages, save to a new dataframe.
df_percent = df.filter(regex = 'percent', axis = 1)

# %%
# Display the first few rows of the dataframe.
df_percent.head(2)
# Out:
#                                 obes_percent  \
# county_state
# Santa Clara County, California         0.081
# San Mateo County, California           0.071
#
#                                 percent_race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Santa Clara County, California                                         0.257754
# San Mateo County, California                                           0.246760
#
#                                 percent_race_pop_white_alone  \
# county_state
# Santa Clara County, California                      0.320420
# San Mateo County, California                        0.395656
#
#                                 percent_race_pop_black_or_african_american_alone  \
# county_state
# Santa Clara County, California                                          0.023608
# San Mateo County, California                                            0.021984
#
#                                 percent_race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Santa Clara County, California                                           0.001562
# San Mateo County, California                                             0.001503
#
#                                 percent_race_pop_asian_alone  \
# county_state
# Santa Clara County, California                      0.356500
# San Mateo County, California                        0.277405
#
#                                 percent_race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# county_state
# Santa Clara County, California                                           0.003242
# San Mateo County, California                                             0.013411
#
#                                 percent_race_pop_some_other_race_alone  \
# county_state
# Santa Clara County, California                                0.002467
# San Mateo County, California                                  0.003233
#
#                                 percent_race_pop_two_or_more_races  \
# county_state
# Santa Clara County, California                            0.034446
# San Mateo County, California                              0.040049
#
#                                 percent_sex_age_pop_male  ...  \
# county_state                                              ...
# Santa Clara County, California                  0.504874  ...
# San Mateo County, California                    0.493320  ...
#
#                                 percent_inc_hhlds_less_than_10_000  \
# county_state
# Santa Clara County, California                            0.032184
# San Mateo County, California                              0.029114
#
#                                 percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Santa Clara County, California                            0.027568
# San Mateo County, California                              0.023087
#
#                                 percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Santa Clara County, California                            0.045773
# San Mateo County, California                              0.044536
#
#                                 percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Santa Clara County, California                            0.046066
# San Mateo County, California                              0.047429
#
#                                 percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Santa Clara County, California                            0.069604
# San Mateo County, California                              0.069649
#
#                                 percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Santa Clara County, California                            0.112076
# San Mateo County, California                              0.115617
#
#                                 percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Santa Clara County, California                            0.102890
# San Mateo County, California                              0.110609
#
#                                 percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Santa Clara County, California                              0.180432
# San Mateo County, California                                0.180571
#
#                                 percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Santa Clara County, California                              0.131112
# San Mateo County, California                                0.123301
#
#                                 percent_inc_hhlds_200_000_or_more
# county_state
# Santa Clara County, California                           0.252295
# San Mateo County, California                             0.256088
#
# [2 rows x 36 columns]

# %% [markdown]
# ## Combine percent dataframe with other key features

# %%
# Other metrics from the original dataframe to carry over.
# These were not total counts and thus not calculated in percentage step.
df_temp = df[[
    'total_cases',
    'total_fatalities',
    'death_rate',
    'total_tests',
    'sex_age_median_age_in_years', 
    'health_ins_noninst_pop_private',
    'health_ins_noninst_pop_public',
    'inc_med_hhld_inc_dol',
    'inc_mean_hhld_inc_dol',
    'inc_per_capita_inc_dol',
    'inc_med_earn_male_full_yr_workers_dol',
    'inc_med_earn_female_full_yr_workers_dol',
    'deaths_per_100_cases',
    'cases_per_100_people',
    'tests_per_100_people',
    'pop_density'
]]

# %%
# Concatenate the two dataframes to get a complete feature set.
df_percent = pd.concat([df_temp, df_percent], axis=1)

# %%
# Display the dataframe.
df_percent.head(2)
# Out:
#                                 total_cases  total_fatalities  death_rate  \
# county_state
# Santa Clara County, California      23978.0             388.0    0.016181
# San Mateo County, California        10942.0             159.0    0.014531
#
#                                 total_tests  sex_age_median_age_in_years  \
# county_state
# Santa Clara County, California       839764                         37.0
# San Mateo County, California         285657                         39.6
#
#                                 health_ins_noninst_pop_private  \
# county_state
# Santa Clara County, California                         1466921
# San Mateo County, California                            597415
#
#                                 health_ins_noninst_pop_public  \
# county_state
# Santa Clara County, California                         513162
# San Mateo County, California                           211256
#
#                                 inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# county_state
# Santa Clara County, California                116178                 154183
# San Mateo County, California                  113776                 162639
#
#                                 inc_per_capita_inc_dol  ...  \
# county_state                                            ...
# Santa Clara County, California                   52451  ...
# San Mateo County, California                     57375  ...
#
#                                 percent_inc_hhlds_less_than_10_000  \
# county_state
# Santa Clara County, California                            0.032184
# San Mateo County, California                              0.029114
#
#                                 percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Santa Clara County, California                            0.027568
# San Mateo County, California                              0.023087
#
#                                 percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Santa Clara County, California                            0.045773
# San Mateo County, California                              0.044536
#
#                                 percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Santa Clara County, California                            0.046066
# San Mateo County, California                              0.047429
#
#                                 percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Santa Clara County, California                            0.069604
# San Mateo County, California                              0.069649
#
#                                 percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Santa Clara County, California                            0.112076
# San Mateo County, California                              0.115617
#
#                                 percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Santa Clara County, California                            0.102890
# San Mateo County, California                              0.110609
#
#                                 percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Santa Clara County, California                              0.180432
# San Mateo County, California                                0.180571
#
#                                 percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Santa Clara County, California                              0.131112
# San Mateo County, California                                0.123301
#
#                                 percent_inc_hhlds_200_000_or_more
# county_state
# Santa Clara County, California                           0.252295
# San Mateo County, California                             0.256088
#
# [2 rows x 52 columns]

# %%
# Export the data.
df_percent.to_csv('../data/cleaned_percent_five_states.csv')
