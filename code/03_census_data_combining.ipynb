# %% [markdown]
# ## Contents
# - [Data Dictionary](#Data-Dictionary)
# - [Importing and Combining Total Number Data](#Importing-and-Combining-Total-Number-Data)
# - [Feature Engineering](#Feature-Engineering)
# - [Dataframe to Hold Both Total Numbers and Percent Values](#Dataframe-to-Hold-Both-Total-Numbers-and-Percent-Values)
# - [Dataframe to Hold Percent Values](#Dataframe-to-Hold-Percent-Values)

# %% [markdown]
# |Column Label|Type|Description
# |---|---|---|
# inc_hhlds_less_than_10_000|int|(Discrete): Households less than \\$10,000 income
# inc_hhlds_10_000_to_14_999|int|(Discrete): Households \\$10,000 to \\$14,999 income
# inc_hhlds_15_000_to_24_999|int|(Discrete): Households \\$15,000 to \\$24,999 income
# inc_hhlds_25_000_to_34_999|int|(Discrete): Households \\$25,000 to \\$34,999 income
# inc_hhlds_35_000_to_49_999|int|(Discrete): Households \\$35,000 to \\$49,999 income
# inc_hhlds_50_000_to_74_999|int|(Discrete): Households \\$50,000 to \\$74,999 income
# inc_hhlds_75_000_to_99_999|int|(Discrete): Households \\$75,000 to \\$99,999 income
# inc_hhlds_100_000_to_149_999|int|(Discrete): Households \\$100,000 to \\$149,999 income
# inc_hhlds_150_000_to_199_999|int|(Discrete): Households \\$150,000 to \\$199,999 income
# inc_hhlds_200_000_or_more|int|(Discrete): Households \\$200,000+ income

# %% [markdown]
# # Data Dictionary
#
# |Column Label|Type|Description
# |---|---|---|
# health_ins_noninst_pop|int|(Discrete): Total population civilian noninstitutionalized used to calculate yes/no coverage percentages
# health_ins_noninst_pop_cov_no|int| (Discrete): Population civilian noninstitutionalized without health insurance coverage
# health_ins_noninst_pop_cov_yes|int|(Discrete): Population civilian noninstitutionalized with health insurance coverage
# health_ins_noninst_pop_private|int|(Discrete): Population civilian noninstitutionalized with private health insurance
# health_ins_noninst_pop_public|int|(Discrete): Population civilian noninstitutionalized with public coverage
# inc_hhlds|int|(Discrete): Total households used to calculate household income percentages
# inc_mean_hhld_inc_dol|int|(Discrete): Mean household income (dollars)
# inc_med_hhld_inc_dol|int|(Discrete): Median household income (dollars)
# inc_med_earn_female_full_yr_workers_dol|int|(Discrete): Median earnings for female full-time, year-round workers (dollars)
# inc_med_earn_male_full_yr_workers_dol|int|(Discrete): Median earnings for male full-time, year-round workers (dollars)
# inc_med_earn_workers_dol|int|(Discrete): Median earnings for workers (dollars)
# inc_per_capita_inc_dol|int|(Discrete): Per capita income (dollars)
# pop_density|float|(Continuous): People per square mile
# race_pop|int|(Discrete): Total population used to calculate race demographic percentages
# race_pop_american_indian_and_alaska_native_alone|int|(Discrete): Population American Indian and Alaska Native
# race_pop_asian_alone|int|(Discrete): Population Asian
# race_pop_black_or_african_american_alone|int|(Discrete): Population Black or African American
# race_pop_hispanic_or_latino_of_any_race|int|(Discrete): Population Hispanic or Latino of any race
# race_pop_native_hawaiian_and_other_pacific_islander_alone|int|(Discrete): Population Native Hawaiian or other Pacific Islander
# race_pop_some_other_race_alone|int|(Discrete): Population some other race
# race_pop_two_or_more_races|int|(Discrete): Population two or more races
# race_pop_white_alone|int|(Discrete): Population White
# sex_age_median_age_in_years|float|(Continuous): Median age (years)
# sex_age_pop|int|(Discrete): Total population used to calculate sex/age demographic percentages
# sex_age_pop_under_5|int|(Discrete): Population under 5
# sex_age_pop_5_to_9|int|(Discrete): Population 5-9
# sex_age_pop_10_to_14|int|(Discrete): Population 10-14
# sex_age_pop_15_to_19|int|(Discrete): Population 15-19
# sex_age_pop_20_to_24|int|(Discrete): Population 20-24
# sex_age_pop_25_to_34|int|(Discrete): Population 25-34
# sex_age_pop_35_to_44|int|(Discrete): Population 35-44
# sex_age_pop_45_to_54|int|(Discrete): Population 45-54
# sex_age_pop_55_to_59|int|(Discrete): Population 55-59
# sex_age_pop_60_to_64|int|(Discrete): Population 60-64
# sex_age_pop_65_to_74|int|(Discrete): Population 65-74
# sex_age_pop_75_to_84|int|(Discrete): Population 75-84
# sex_age_pop_85_and_over|int|(Discrete): Population 85+
# sex_age_pop_female|int|(Discrete): Population females
# sex_age_pop_male|int|(Discrete): Population male
# sq_mi|float|(Continuous): Square miles

# %% [markdown]
# # Importing and Combining Total Number Data

# %%
import pandas as pd

# %%
# Import the relevant dataframes.
race = pd.read_csv('../data/preprocessing/cleaned_tx_dp05_race.csv')
sa = pd.read_csv('../data/preprocessing/cleaned_tx_dp05_sex_age.csv')
land = pd.read_csv('../data/preprocessing/cleaned_tx_area.csv')
ins = pd.read_csv('../data/preprocessing/cleaned_tx_dp03_insurance.csv')
inc = pd.read_csv('../data/preprocessing/cleaned_tx_dp03_income.csv')

# %%
# Display the first few rows of data. 
race.head(2)
# Out:
#    Geographic Area Name  race_pop  race_pop_hispanic_or_latino_of_any_race  \
# 0  Austin County, Texas     29565                                     7819
# 1  Kenedy County, Texas       595                                      522
#
#    race_pop_white_alone  race_pop_black_or_african_american_alone  \
# 0                 18525                                      2576
# 1                    72                                         0
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races
# 0                              52                         456
# 1                               0                           0

# %%
# Display the first few rows of data. 
sa.head(2)
# Out:
#    Geographic Area Name  sex_age_pop  sex_age_pop_male  sex_age_pop_female  \
# 0  Austin County, Texas        29565             14684               14881
# 1  Kenedy County, Texas          595               286                 309
#
#    sex_age_pop_under_5  sex_age_pop_5_to_9  sex_age_pop_10_to_14  \
# 0                 1780                1960                  2118
# 1                   85                  37                    40
#
#    sex_age_pop_15_to_19  sex_age_pop_20_to_24  sex_age_pop_25_to_34  \
# 0                  1861                  1712                  3339
# 1                    10                    10                    95
#
#    sex_age_pop_35_to_44  sex_age_pop_45_to_54  sex_age_pop_55_to_59  \
# 0                  3275                  3821                  2327
# 1                    47                    75                    51
#
#    sex_age_pop_60_to_64  sex_age_pop_65_to_74  sex_age_pop_75_to_84  \
# 0                  1978                  3243                  1532
# 1                     9                    85                    29
#
#    sex_age_pop_85_and_over  sex_age_median_age_in_years
# 0                      619                         40.7
# 1                       22                         39.5

# %%
# Display the first few rows of data. 
land.head(2)
# Out:
#      Geographic Area Name     sq_mi
# 0  Anderson County, Texas  1062.630
# 1   Andrews County, Texas  1500.721

# %%
# Display the first few rows of data. 
ins.head(2)
# Out:
#    Geographic Area Name  health_ins_noninst_pop  \
# 0  Austin County, Texas                   29298
# 1  Kenedy County, Texas                     595
#
#    health_ins_noninst_pop_cov_yes  health_ins_noninst_pop_private  \
# 0                           25749                           20393
# 1                             467                             212
#
#    health_ins_noninst_pop_public  health_ins_noninst_pop_cov_no
# 0                           8863                           3549
# 1                            276                            128

# %%
# Display the first few rows of data. 
inc.head(2)
# Out:
#    Geographic Area Name  inc_hhlds  inc_hhlds_less_than_10_000  \
# 0  Austin County, Texas      11041                         482
# 1  Kenedy County, Texas        209                          25
#
#    inc_hhlds_10_000_to_14_999  inc_hhlds_15_000_to_24_999  \
# 0                         459                        1255
# 1                           4                          49
#
#    inc_hhlds_25_000_to_34_999  inc_hhlds_35_000_to_49_999  \
# 0                         927                        1186
# 1                          13                          71
#
#    inc_hhlds_50_000_to_74_999  inc_hhlds_75_000_to_99_999  \
# 0                        1851                        1651
# 1                          16                          23
#
#    inc_hhlds_100_000_to_149_999  inc_hhlds_150_000_to_199_999  \
# 0                          2150                           551
# 1                             8                             0
#
#    inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# 0                        529                 65365                  80769
# 1                          0                 36125                  40908
#
#    inc_per_capita_inc_dol  inc_med_earn_workers_dol  \
# 0                   30858                     33993
# 1                   15820                     29453
#
#    inc_med_earn_male_full_yr_workers_dol  \
# 0                                  55417
# 1                                  40848
#
#    inc_med_earn_female_full_yr_workers_dol
# 0                                    38603
# 1                                    23295

# %%
# Merge the first three dataframes on Geographic Area Name.
# This will be the dataframe for tracking total numbers.
df_num = race.merge(sa,on='Geographic Area Name').merge(land,on='Geographic Area Name')
df_num.head()
# Out:
#          Geographic Area Name  race_pop  \
# 0        Austin County, Texas     29565
# 1        Kenedy County, Texas       595
# 2        Nueces County, Texas    360486
# 3      Colorado County, Texas     21022
# 4  San Patricio County, Texas     67046
#
#    race_pop_hispanic_or_latino_of_any_race  race_pop_white_alone  \
# 0                                     7819                 18525
# 1                                      522                    72
# 2                                   228462                107652
# 3                                     6200                 11855
# 4                                    38483                 26032
#
#    race_pop_black_or_african_american_alone  \
# 0                                      2576
# 1                                         0
# 2                                     13071
# 3                                      2655
# 4                                      1003
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
# 2                                               919                  7134
# 3                                                27                     7
# 4                                               101                   671
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
# 2                                                242
# 3                                                  0
# 4                                                 30
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races  ...  \
# 0                              52                         456  ...
# 1                               0                           0  ...
# 2                             226                        2780  ...
# 3                               0                         278  ...
# 4                               7                         719  ...
#
#    sex_age_pop_25_to_34  sex_age_pop_35_to_44  sex_age_pop_45_to_54  \
# 0                  3339                  3275                  3821
# 1                    95                    47                    75
# 2                 52547                 45030                 43503
# 3                  2054                  2233                  2440
# 4                  8923                  8328                  8078
#
#    sex_age_pop_55_to_59  sex_age_pop_60_to_64  sex_age_pop_65_to_74  \
# 0                  2327                  1978                  3243
# 1                    51                     9                    85
# 2                 22563                 21051                 28881
# 3                  1280                  1866                  2467
# 4                  4417                  3367                  5759
#
#    sex_age_pop_75_to_84  sex_age_pop_85_and_over  sex_age_median_age_in_years  \
# 0                  1532                      619                         40.7
# 1                    29                       22                         39.5
# 2                 15165                     5299                         35.3
# 3                  1356                      640                         42.5
# 4                  2935                      929                         35.3
#
#       sq_mi
# 0   646.492
# 1  1458.453
# 2   838.316
# 3   960.284
# 4   693.436
#
# [5 rows x 28 columns]

# %%
# Merge the remainder dataframes on Geographic Area Name.
df_num = df_num.merge(ins,on='Geographic Area Name').merge(inc,on='Geographic Area Name')
df_num.head()
# Out:
#          Geographic Area Name  race_pop  \
# 0        Austin County, Texas     29565
# 1        Kenedy County, Texas       595
# 2        Nueces County, Texas    360486
# 3      Colorado County, Texas     21022
# 4  San Patricio County, Texas     67046
#
#    race_pop_hispanic_or_latino_of_any_race  race_pop_white_alone  \
# 0                                     7819                 18525
# 1                                      522                    72
# 2                                   228462                107652
# 3                                     6200                 11855
# 4                                    38483                 26032
#
#    race_pop_black_or_african_american_alone  \
# 0                                      2576
# 1                                         0
# 2                                     13071
# 3                                      2655
# 4                                      1003
#
#    race_pop_american_indian_and_alaska_native_alone  race_pop_asian_alone  \
# 0                                                48                    89
# 1                                                 0                     1
# 2                                               919                  7134
# 3                                                27                     7
# 4                                               101                   671
#
#    race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# 0                                                  0
# 1                                                  0
# 2                                                242
# 3                                                  0
# 4                                                 30
#
#    race_pop_some_other_race_alone  race_pop_two_or_more_races  ...  \
# 0                              52                         456  ...
# 1                               0                           0  ...
# 2                             226                        2780  ...
# 3                               0                         278  ...
# 4                               7                         719  ...
#
#    inc_hhlds_75_000_to_99_999  inc_hhlds_100_000_to_149_999  \
# 0                        1651                          2150
# 1                          23                             8
# 2                       16265                         18198
# 3                         935                           678
# 4                        2928                          3112
#
#    inc_hhlds_150_000_to_199_999  inc_hhlds_200_000_or_more  \
# 0                           551                        529
# 1                             0                          0
# 2                          6452                       5780
# 3                           428                        329
# 4                          1483                        767
#
#    inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  inc_per_capita_inc_dol  \
# 0                 65365                  80769                   30858
# 1                 36125                  40908                   15820
# 2                 55048                  74820                   27649
# 3                 49504                  70324                   27861
# 4                 55229                  71588                   25281
#
#    inc_med_earn_workers_dol  inc_med_earn_male_full_yr_workers_dol  \
# 0                     33993                                  55417
# 1                     29453                                  40848
# 2                     30869                                  48043
# 3                     30469                                  41853
# 4                     31318                                  50594
#
#    inc_med_earn_female_full_yr_workers_dol
# 0                                    38603
# 1                                    23295
# 2                                    34488
# 3                                    34692
# 4                                    31847
#
# [5 rows x 50 columns]

# %%
# Display the columns.
list(df_num.columns)
# Out:
# ['Geographic Area Name',
#  'race_pop',
#  'race_pop_hispanic_or_latino_of_any_race',
#  'race_pop_white_alone',
#  'race_pop_black_or_african_american_alone',
#  'race_pop_american_indian_and_alaska_native_alone',
#  'race_pop_asian_alone',
#  'race_pop_native_hawaiian_and_other_pacific_islander_alone',
#  'race_pop_some_other_race_alone',
#  'race_pop_two_or_more_races',
#  'sex_age_pop',
#  'sex_age_pop_male',
#  'sex_age_pop_female',
#  'sex_age_pop_under_5',
#  'sex_age_pop_5_to_9',
#  'sex_age_pop_10_to_14',
#  'sex_age_pop_15_to_19',
#  'sex_age_pop_20_to_24',
#  'sex_age_pop_25_to_34',
#  'sex_age_pop_35_to_44',
#  'sex_age_pop_45_to_54',
#  'sex_age_pop_55_to_59',
#  'sex_age_pop_60_to_64',
#  'sex_age_pop_65_to_74',
#  'sex_age_pop_75_to_84',
#  'sex_age_pop_85_and_over',
#  'sex_age_median_age_in_years',
#  'sq_mi',
#  'health_ins_noninst_pop',
#  'health_ins_noninst_pop_cov_yes',
#  'health_ins_noninst_pop_private',
#  'health_ins_noninst_pop_public',
#  'health_ins_noninst_pop_cov_no',
#  'inc_hhlds',
#  'inc_hhlds_less_than_10_000',
#  'inc_hhlds_10_000_to_14_999',
#  'inc_hhlds_15_000_to_24_999',
#  'inc_hhlds_25_000_to_34_999',
#  'inc_hhlds_35_000_to_49_999',
#  'inc_hhlds_50_000_to_74_999',
#  'inc_hhlds_75_000_to_99_999',
#  'inc_hhlds_100_000_to_149_999',
#  'inc_hhlds_150_000_to_199_999',
#  'inc_hhlds_200_000_or_more',
#  'inc_med_hhld_inc_dol',
#  'inc_mean_hhld_inc_dol',
#  'inc_per_capita_inc_dol',
#  'inc_med_earn_workers_dol',
#  'inc_med_earn_male_full_yr_workers_dol',
#  'inc_med_earn_female_full_yr_workers_dol']

# %%
# Rename the median age column for the function.
df_num = df_num.rename(columns={'Geographic Area Name': 'county_state'})

# %%
# Set the index to the geography.
df_num = df_num.set_index('county_state')

# %%
# Display the first few rows of the dataframe.
df_num.head(3)
# Out:
#                       race_pop  race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Austin County, Texas     29565                                     7819
# Kenedy County, Texas       595                                      522
# Nueces County, Texas    360486                                   228462
#
#                       race_pop_white_alone  \
# county_state
# Austin County, Texas                 18525
# Kenedy County, Texas                    72
# Nueces County, Texas                107652
#
#                       race_pop_black_or_african_american_alone  \
# county_state
# Austin County, Texas                                      2576
# Kenedy County, Texas                                         0
# Nueces County, Texas                                     13071
#
#                       race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Austin County, Texas                                                48
# Kenedy County, Texas                                                 0
# Nueces County, Texas                                               919
#
#                       race_pop_asian_alone  \
# county_state
# Austin County, Texas                    89
# Kenedy County, Texas                     1
# Nueces County, Texas                  7134
#
#                       race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# county_state
# Austin County, Texas                                                  0
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                                242
#
#                       race_pop_some_other_race_alone  \
# county_state
# Austin County, Texas                              52
# Kenedy County, Texas                               0
# Nueces County, Texas                             226
#
#                       race_pop_two_or_more_races  sex_age_pop  ...  \
# county_state                                                   ...
# Austin County, Texas                         456        29565  ...
# Kenedy County, Texas                           0          595  ...
# Nueces County, Texas                        2780       360486  ...
#
#                       inc_hhlds_75_000_to_99_999  \
# county_state
# Austin County, Texas                        1651
# Kenedy County, Texas                          23
# Nueces County, Texas                       16265
#
#                       inc_hhlds_100_000_to_149_999  \
# county_state
# Austin County, Texas                          2150
# Kenedy County, Texas                             8
# Nueces County, Texas                         18198
#
#                       inc_hhlds_150_000_to_199_999  inc_hhlds_200_000_or_more  \
# county_state
# Austin County, Texas                           551                        529
# Kenedy County, Texas                             0                          0
# Nueces County, Texas                          6452                       5780
#
#                       inc_med_hhld_inc_dol  inc_mean_hhld_inc_dol  \
# county_state
# Austin County, Texas                 65365                  80769
# Kenedy County, Texas                 36125                  40908
# Nueces County, Texas                 55048                  74820
#
#                       inc_per_capita_inc_dol  inc_med_earn_workers_dol  \
# county_state
# Austin County, Texas                   30858                     33993
# Kenedy County, Texas                   15820                     29453
# Nueces County, Texas                   27649                     30869
#
#                       inc_med_earn_male_full_yr_workers_dol  \
# county_state
# Austin County, Texas                                  55417
# Kenedy County, Texas                                  40848
# Nueces County, Texas                                  48043
#
#                       inc_med_earn_female_full_yr_workers_dol
# county_state
# Austin County, Texas                                    38603
# Kenedy County, Texas                                    23295
# Nueces County, Texas                                    34488
#
# [3 rows x 49 columns]

# %% [markdown]
# # Feature Engineering

# %%
# Compare the base populations to be used in calculations.
df_num[['race_pop', 'sex_age_pop', 'health_ins_noninst_pop', 'inc_hhlds']]
# Out:
#                             race_pop  sex_age_pop  health_ins_noninst_pop  \
# county_state
# Austin County, Texas           29565        29565                   29298
# Kenedy County, Texas             595          595                     595
# Nueces County, Texas          360486       360486                  355767
# Colorado County, Texas         21022        21022                   20703
# San Patricio County, Texas     67046        67046                   66274
# ...                              ...          ...                     ...
# McCulloch County, Texas         8098         8098                    7960
# Lee County, Texas              16952        16952                   16491
# Ellis County, Texas           168838       168838                  167585
# Kerr County, Texas             51365        51365                   50494
# Falls County, Texas            17299        17299                   15531
#
#                             inc_hhlds
# county_state
# Austin County, Texas            11041
# Kenedy County, Texas              209
# Nueces County, Texas           128926
# Colorado County, Texas           7511
# San Patricio County, Texas      23121
# ...                               ...
# McCulloch County, Texas          3255
# Lee County, Texas                6104
# Ellis County, Texas             55840
# Kerr County, Texas              20766
# Falls County, Texas              5237
#
# [254 rows x 4 columns]

# %%
# Create a new column for county population density which is the result of
# dividing population by square miles
df_num['pop_density'] = df_num['race_pop'] / df_num['sq_mi']

# %%
df_num.head()
# Out:
#                             race_pop  race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Austin County, Texas           29565                                     7819
# Kenedy County, Texas             595                                      522
# Nueces County, Texas          360486                                   228462
# Colorado County, Texas         21022                                     6200
# San Patricio County, Texas     67046                                    38483
#
#                             race_pop_white_alone  \
# county_state
# Austin County, Texas                       18525
# Kenedy County, Texas                          72
# Nueces County, Texas                      107652
# Colorado County, Texas                     11855
# San Patricio County, Texas                 26032
#
#                             race_pop_black_or_african_american_alone  \
# county_state
# Austin County, Texas                                            2576
# Kenedy County, Texas                                               0
# Nueces County, Texas                                           13071
# Colorado County, Texas                                          2655
# San Patricio County, Texas                                      1003
#
#                             race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Austin County, Texas                                                      48
# Kenedy County, Texas                                                       0
# Nueces County, Texas                                                     919
# Colorado County, Texas                                                    27
# San Patricio County, Texas                                               101
#
#                             race_pop_asian_alone  \
# county_state
# Austin County, Texas                          89
# Kenedy County, Texas                           1
# Nueces County, Texas                        7134
# Colorado County, Texas                         7
# San Patricio County, Texas                   671
#
#                             race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# county_state
# Austin County, Texas                                                        0
# Kenedy County, Texas                                                        0
# Nueces County, Texas                                                      242
# Colorado County, Texas                                                      0
# San Patricio County, Texas                                                 30
#
#                             race_pop_some_other_race_alone  \
# county_state
# Austin County, Texas                                    52
# Kenedy County, Texas                                     0
# Nueces County, Texas                                   226
# Colorado County, Texas                                   0
# San Patricio County, Texas                               7
#
#                             race_pop_two_or_more_races  sex_age_pop  ...  \
# county_state                                                         ...
# Austin County, Texas                               456        29565  ...
# Kenedy County, Texas                                 0          595  ...
# Nueces County, Texas                              2780       360486  ...
# Colorado County, Texas                             278        21022  ...
# San Patricio County, Texas                         719        67046  ...
#
#                             inc_hhlds_100_000_to_149_999  \
# county_state
# Austin County, Texas                                2150
# Kenedy County, Texas                                   8
# Nueces County, Texas                               18198
# Colorado County, Texas                               678
# San Patricio County, Texas                          3112
#
#                             inc_hhlds_150_000_to_199_999  \
# county_state
# Austin County, Texas                                 551
# Kenedy County, Texas                                   0
# Nueces County, Texas                                6452
# Colorado County, Texas                               428
# San Patricio County, Texas                          1483
#
#                             inc_hhlds_200_000_or_more  inc_med_hhld_inc_dol  \
# county_state
# Austin County, Texas                              529                 65365
# Kenedy County, Texas                                0                 36125
# Nueces County, Texas                             5780                 55048
# Colorado County, Texas                            329                 49504
# San Patricio County, Texas                        767                 55229
#
#                             inc_mean_hhld_inc_dol  inc_per_capita_inc_dol  \
# county_state
# Austin County, Texas                        80769                   30858
# Kenedy County, Texas                        40908                   15820
# Nueces County, Texas                        74820                   27649
# Colorado County, Texas                      70324                   27861
# San Patricio County, Texas                  71588                   25281
#
#                             inc_med_earn_workers_dol  \
# county_state
# Austin County, Texas                           33993
# Kenedy County, Texas                           29453
# Nueces County, Texas                           30869
# Colorado County, Texas                         30469
# San Patricio County, Texas                     31318
#
#                             inc_med_earn_male_full_yr_workers_dol  \
# county_state
# Austin County, Texas                                        55417
# Kenedy County, Texas                                        40848
# Nueces County, Texas                                        48043
# Colorado County, Texas                                      41853
# San Patricio County, Texas                                  50594
#
#                             inc_med_earn_female_full_yr_workers_dol  \
# county_state
# Austin County, Texas                                          38603
# Kenedy County, Texas                                          23295
# Nueces County, Texas                                          34488
# Colorado County, Texas                                        34692
# San Patricio County, Texas                                    31847
#
#                             pop_density
# county_state
# Austin County, Texas          45.731424
# Kenedy County, Texas           0.407967
# Nueces County, Texas         430.012072
# Colorado County, Texas        21.891440
# San Patricio County, Texas    96.686644
#
# [5 rows x 50 columns]

# %%
# Export the data.
df_num.to_csv('../data/tx_cleaned_numbers.csv')

# %% [markdown]
# # Dataframe to Hold Both Total Numbers and Percent Values

# %%
# Make a copy of the dataframe that will hold total numbers AND percentages.
df = df_num.copy()

# %%
for column in df.columns:
    print(column)
# Out:
# race_pop
# race_pop_hispanic_or_latino_of_any_race
# race_pop_white_alone
# race_pop_black_or_african_american_alone
# race_pop_american_indian_and_alaska_native_alone
# race_pop_asian_alone
# race_pop_native_hawaiian_and_other_pacific_islander_alone
# race_pop_some_other_race_alone
# race_pop_two_or_more_races
# sex_age_pop
# sex_age_pop_male
# sex_age_pop_female
# sex_age_pop_under_5
# sex_age_pop_5_to_9
# sex_age_pop_10_to_14
# sex_age_pop_15_to_19
# sex_age_pop_20_to_24
# sex_age_pop_25_to_34
# sex_age_pop_35_to_44
# sex_age_pop_45_to_54
# sex_age_pop_55_to_59
# sex_age_pop_60_to_64
# sex_age_pop_65_to_74
# sex_age_pop_75_to_84
# sex_age_pop_85_and_over
# sex_age_median_age_in_years
# sq_mi
# health_ins_noninst_pop
# health_ins_noninst_pop_cov_yes
# health_ins_noninst_pop_private
# health_ins_noninst_pop_public
# health_ins_noninst_pop_cov_no
# inc_hhlds
# inc_hhlds_less_than_10_000
# inc_hhlds_10_000_to_14_999
# inc_hhlds_15_000_to_24_999
# inc_hhlds_25_000_to_34_999
# inc_hhlds_35_000_to_49_999
# inc_hhlds_50_000_to_74_999
# inc_hhlds_75_000_to_99_999
# inc_hhlds_100_000_to_149_999
# inc_hhlds_150_000_to_199_999
# inc_hhlds_200_000_or_more
# inc_med_hhld_inc_dol
# inc_mean_hhld_inc_dol
# inc_per_capita_inc_dol
# inc_med_earn_workers_dol
# inc_med_earn_male_full_yr_workers_dol
# inc_med_earn_female_full_yr_workers_dol
# pop_density

# %% [markdown]
# # Dataframe to Hold Percent Values

# %%
# Define a function to create new columns with percentages.
def to_percentage(dataframe):
    
    for column in dataframe.columns:
        if column.startswith('race_pop_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['race_pop']
        
        elif column.startswith('sex_age_pop_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['race_pop']
            
        elif column.startswith('health_ins_noninst_pop_cov'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['health_ins_noninst_pop']
            
        elif column.startswith('inc_hhlds_'):
            dataframe['percent_' + column] = dataframe[column] / dataframe['inc_hhlds']
    
    return

# %%
# Apply the function to the numbers dataframe
to_percentage(df)

# %%
# Display the 
df.head(3)
# Out:
#                       race_pop  race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Austin County, Texas     29565                                     7819
# Kenedy County, Texas       595                                      522
# Nueces County, Texas    360486                                   228462
#
#                       race_pop_white_alone  \
# county_state
# Austin County, Texas                 18525
# Kenedy County, Texas                    72
# Nueces County, Texas                107652
#
#                       race_pop_black_or_african_american_alone  \
# county_state
# Austin County, Texas                                      2576
# Kenedy County, Texas                                         0
# Nueces County, Texas                                     13071
#
#                       race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Austin County, Texas                                                48
# Kenedy County, Texas                                                 0
# Nueces County, Texas                                               919
#
#                       race_pop_asian_alone  \
# county_state
# Austin County, Texas                    89
# Kenedy County, Texas                     1
# Nueces County, Texas                  7134
#
#                       race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# county_state
# Austin County, Texas                                                  0
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                                242
#
#                       race_pop_some_other_race_alone  \
# county_state
# Austin County, Texas                              52
# Kenedy County, Texas                               0
# Nueces County, Texas                             226
#
#                       race_pop_two_or_more_races  sex_age_pop  ...  \
# county_state                                                   ...
# Austin County, Texas                         456        29565  ...
# Kenedy County, Texas                           0          595  ...
# Nueces County, Texas                        2780       360486  ...
#
#                       percent_inc_hhlds_less_than_10_000  \
# county_state
# Austin County, Texas                            0.043655
# Kenedy County, Texas                            0.119617
# Nueces County, Texas                            0.069179
#
#                       percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Austin County, Texas                            0.041572
# Kenedy County, Texas                            0.019139
# Nueces County, Texas                            0.053853
#
#                       percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Austin County, Texas                            0.113667
# Kenedy County, Texas                            0.234450
# Nueces County, Texas                            0.102229
#
#                       percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Austin County, Texas                            0.083960
# Kenedy County, Texas                            0.062201
# Nueces County, Texas                            0.100228
#
#                       percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Austin County, Texas                            0.107418
# Kenedy County, Texas                            0.339713
# Nueces County, Texas                            0.130897
#
#                       percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Austin County, Texas                            0.167648
# Kenedy County, Texas                            0.076555
# Nueces County, Texas                            0.181430
#
#                       percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Austin County, Texas                            0.149534
# Kenedy County, Texas                            0.110048
# Nueces County, Texas                            0.126158
#
#                       percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Austin County, Texas                              0.194729
# Kenedy County, Texas                              0.038278
# Nueces County, Texas                              0.141151
#
#                       percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Austin County, Texas                              0.049905
# Kenedy County, Texas                              0.000000
# Nueces County, Texas                              0.050044
#
#                       percent_inc_hhlds_200_000_or_more
# county_state
# Austin County, Texas                           0.047912
# Kenedy County, Texas                           0.000000
# Nueces County, Texas                           0.044832
#
# [3 rows x 85 columns]

# %%
# Extract the columns with percentages, save to a new dataframe.
df_percent = df.filter(regex = 'percent', axis = 1)

# %%
# Display the first few rows of the dataframe.
df_percent.head(3)
# Out:
#                       percent_race_pop_hispanic_or_latino_of_any_race  \
# county_state
# Austin County, Texas                                         0.264468
# Kenedy County, Texas                                         0.877311
# Nueces County, Texas                                         0.633761
#
#                       percent_race_pop_white_alone  \
# county_state
# Austin County, Texas                      0.626585
# Kenedy County, Texas                      0.121008
# Nueces County, Texas                      0.298630
#
#                       percent_race_pop_black_or_african_american_alone  \
# county_state
# Austin County, Texas                                          0.087130
# Kenedy County, Texas                                          0.000000
# Nueces County, Texas                                          0.036259
#
#                       percent_race_pop_american_indian_and_alaska_native_alone  \
# county_state
# Austin County, Texas                                           0.001624
# Kenedy County, Texas                                           0.000000
# Nueces County, Texas                                           0.002549
#
#                       percent_race_pop_asian_alone  \
# county_state
# Austin County, Texas                      0.003010
# Kenedy County, Texas                      0.001681
# Nueces County, Texas                      0.019790
#
#                       percent_race_pop_native_hawaiian_and_other_pacific_islander_alone  \
# county_state
# Austin County, Texas                                           0.000000
# Kenedy County, Texas                                           0.000000
# Nueces County, Texas                                           0.000671
#
#                       percent_race_pop_some_other_race_alone  \
# county_state
# Austin County, Texas                                0.001759
# Kenedy County, Texas                                0.000000
# Nueces County, Texas                                0.000627
#
#                       percent_race_pop_two_or_more_races  \
# county_state
# Austin County, Texas                            0.015424
# Kenedy County, Texas                            0.000000
# Nueces County, Texas                            0.007712
#
#                       percent_sex_age_pop_male  percent_sex_age_pop_female  \
# county_state
# Austin County, Texas                  0.496668                    0.503332
# Kenedy County, Texas                  0.480672                    0.519328
# Nueces County, Texas                  0.493833                    0.506167
#
#                       ...  percent_inc_hhlds_less_than_10_000  \
# county_state          ...
# Austin County, Texas  ...                            0.043655
# Kenedy County, Texas  ...                            0.119617
# Nueces County, Texas  ...                            0.069179
#
#                       percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Austin County, Texas                            0.041572
# Kenedy County, Texas                            0.019139
# Nueces County, Texas                            0.053853
#
#                       percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Austin County, Texas                            0.113667
# Kenedy County, Texas                            0.234450
# Nueces County, Texas                            0.102229
#
#                       percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Austin County, Texas                            0.083960
# Kenedy County, Texas                            0.062201
# Nueces County, Texas                            0.100228
#
#                       percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Austin County, Texas                            0.107418
# Kenedy County, Texas                            0.339713
# Nueces County, Texas                            0.130897
#
#                       percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Austin County, Texas                            0.167648
# Kenedy County, Texas                            0.076555
# Nueces County, Texas                            0.181430
#
#                       percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Austin County, Texas                            0.149534
# Kenedy County, Texas                            0.110048
# Nueces County, Texas                            0.126158
#
#                       percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Austin County, Texas                              0.194729
# Kenedy County, Texas                              0.038278
# Nueces County, Texas                              0.141151
#
#                       percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Austin County, Texas                              0.049905
# Kenedy County, Texas                              0.000000
# Nueces County, Texas                              0.050044
#
#                       percent_inc_hhlds_200_000_or_more
# county_state
# Austin County, Texas                           0.047912
# Kenedy County, Texas                           0.000000
# Nueces County, Texas                           0.044832
#
# [3 rows x 35 columns]

# %% [markdown]
# ## Combine percent dataframe with other key features

# %%
# Display the columns.
df_percent.columns
# Out:
# Index(['percent_race_pop_hispanic_or_latino_of_any_race',
#        'percent_race_pop_white_alone',
#        'percent_race_pop_black_or_african_american_alone',
#        'percent_race_pop_american_indian_and_alaska_native_alone',
#        'percent_race_pop_asian_alone',
#        'percent_race_pop_native_hawaiian_and_other_pacific_islander_alone',
#        'percent_race_pop_some_other_race_alone',
#        'percent_race_pop_two_or_more_races', 'percent_sex_age_pop_male',
#        'percent_sex_age_pop_female', 'percent_sex_age_pop_under_5',
#        'percent_sex_age_pop_5_to_9', 'percent_sex_age_pop_10_to_14',
#        'percent_sex_age_pop_15_to_19', 'percent_sex_age_pop_20_to_24',
#        'percent_sex_age_pop_25_to_34', 'percent_sex_age_pop_35_to_44',
#        'percent_sex_age_pop_45_to_54', 'percent_sex_age_pop_55_to_59',
#        'percent_sex_age_pop_60_to_64', 'percent_sex_age_pop_65_to_74',
#        'percent_sex_age_pop_75_to_84', 'percent_sex_age_pop_85_and_over',
#        'percent_health_ins_noninst_pop_cov_yes',
#        'percent_health_ins_noninst_pop_cov_no',
#        'percent_inc_hhlds_less_than_10_000',
#        'percent_inc_hhlds_10_000_to_14_999',
#        'percent_inc_hhlds_15_000_to_24_999',
#        'percent_inc_hhlds_25_000_to_34_999',
#        'percent_inc_hhlds_35_000_to_49_999',
#        'percent_inc_hhlds_50_000_to_74_999',
#        'percent_inc_hhlds_75_000_to_99_999',
#        'percent_inc_hhlds_100_000_to_149_999',
#        'percent_inc_hhlds_150_000_to_199_999',
#        'percent_inc_hhlds_200_000_or_more'],
#       dtype='object')

# %%
# Other metrics from the original dataframe to carry over.
# These were not total counts and thus not calculated in percentage step.
df_temp = df[[
    'sex_age_median_age_in_years', 
    'health_ins_noninst_pop_private',
    'health_ins_noninst_pop_public',
    'inc_med_hhld_inc_dol',
    'inc_mean_hhld_inc_dol',
    'inc_per_capita_inc_dol',
    'inc_med_earn_workers_dol',
    'inc_med_earn_male_full_yr_workers_dol',
    'inc_med_earn_female_full_yr_workers_dol',
    'pop_density',
]]

# %%
# Concatenate the two dataframes to get a complete feature set.
df_percent = pd.concat([df_temp, df_percent], axis=1)

# %%
# Display the dataframe.
df_percent.head(3)
# Out:
#                       sex_age_median_age_in_years  \
# county_state
# Austin County, Texas                         40.7
# Kenedy County, Texas                         39.5
# Nueces County, Texas                         35.3
#
#                       health_ins_noninst_pop_private  \
# county_state
# Austin County, Texas                           20393
# Kenedy County, Texas                             212
# Nueces County, Texas                          208747
#
#                       health_ins_noninst_pop_public  inc_med_hhld_inc_dol  \
# county_state
# Austin County, Texas                           8863                 65365
# Kenedy County, Texas                            276                 36125
# Nueces County, Texas                         119691                 55048
#
#                       inc_mean_hhld_inc_dol  inc_per_capita_inc_dol  \
# county_state
# Austin County, Texas                  80769                   30858
# Kenedy County, Texas                  40908                   15820
# Nueces County, Texas                  74820                   27649
#
#                       inc_med_earn_workers_dol  \
# county_state
# Austin County, Texas                     33993
# Kenedy County, Texas                     29453
# Nueces County, Texas                     30869
#
#                       inc_med_earn_male_full_yr_workers_dol  \
# county_state
# Austin County, Texas                                  55417
# Kenedy County, Texas                                  40848
# Nueces County, Texas                                  48043
#
#                       inc_med_earn_female_full_yr_workers_dol  pop_density  \
# county_state
# Austin County, Texas                                    38603    45.731424
# Kenedy County, Texas                                    23295     0.407967
# Nueces County, Texas                                    34488   430.012072
#
#                       ...  percent_inc_hhlds_less_than_10_000  \
# county_state          ...
# Austin County, Texas  ...                            0.043655
# Kenedy County, Texas  ...                            0.119617
# Nueces County, Texas  ...                            0.069179
#
#                       percent_inc_hhlds_10_000_to_14_999  \
# county_state
# Austin County, Texas                            0.041572
# Kenedy County, Texas                            0.019139
# Nueces County, Texas                            0.053853
#
#                       percent_inc_hhlds_15_000_to_24_999  \
# county_state
# Austin County, Texas                            0.113667
# Kenedy County, Texas                            0.234450
# Nueces County, Texas                            0.102229
#
#                       percent_inc_hhlds_25_000_to_34_999  \
# county_state
# Austin County, Texas                            0.083960
# Kenedy County, Texas                            0.062201
# Nueces County, Texas                            0.100228
#
#                       percent_inc_hhlds_35_000_to_49_999  \
# county_state
# Austin County, Texas                            0.107418
# Kenedy County, Texas                            0.339713
# Nueces County, Texas                            0.130897
#
#                       percent_inc_hhlds_50_000_to_74_999  \
# county_state
# Austin County, Texas                            0.167648
# Kenedy County, Texas                            0.076555
# Nueces County, Texas                            0.181430
#
#                       percent_inc_hhlds_75_000_to_99_999  \
# county_state
# Austin County, Texas                            0.149534
# Kenedy County, Texas                            0.110048
# Nueces County, Texas                            0.126158
#
#                       percent_inc_hhlds_100_000_to_149_999  \
# county_state
# Austin County, Texas                              0.194729
# Kenedy County, Texas                              0.038278
# Nueces County, Texas                              0.141151
#
#                       percent_inc_hhlds_150_000_to_199_999  \
# county_state
# Austin County, Texas                              0.049905
# Kenedy County, Texas                              0.000000
# Nueces County, Texas                              0.050044
#
#                       percent_inc_hhlds_200_000_or_more
# county_state
# Austin County, Texas                           0.047912
# Kenedy County, Texas                           0.000000
# Nueces County, Texas                           0.044832
#
# [3 rows x 45 columns]

# %%
# Export the data.
df_percent.to_csv('../data/tx_cleaned_percent.csv')
