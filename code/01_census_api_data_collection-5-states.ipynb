# %% [markdown]
# ## Resources
# - [FIPS codes](https://www2.census.gov/geo/docs/reference/codes/files/)
# - [Census API: Datasets in /data/2018/acs/acs5/profile and its descendants](https://api.census.gov/data/2018/acs/acs5/profile.html)
# - [American Community Survey 5-Year Data (2009-2018)](https://www.census.gov/data/developers/data-sets/acs-5year.html)
# - [Census Datasets](https://api.census.gov/data.html)
# - [Notes on ACS Estimate and Annotation Values (weird values)](https://www.census.gov/data/developers/data-sets/acs-1year/notes-on-acs-estimate-and-annotation-values.html)
# - [Getting Census Data in 5 Easy Steps (towards data science)](https://towardsdatascience.com/getting-census-data-in-5-easy-steps-a08eeb63995d)
# - [Using the Census Bureau's API (medium)](https://medium.com/@shep.nathan.d/using-the-u-s-census-bureaus-api-af113337f478)
# - [Census Burearu YouTube tutorial (youtube)](https://www.youtube.com/watch?v=K0-ifZS0mQI&feature=emb_title&ab_channel=U.S.CensusBureau)
# - [DATA GEMS: How to Extract Data from the Census API (youtube)](https://www.youtube.com/watch?v=0DVdHquaRiU)
# - [Python Tutorial: Using the Census API (datacamp video)](https://www.youtube.com/watch?v=l47HptzM7ao)
#
#
# - [Land Area and Persons per Square Mile](https://www.census.gov/quickfacts/fact/note/US/LND110210)
# - [Gazetteer 2018 Geographic Data](https://www.census.gov/geographies/reference-files/time-series/geo/gazetteer-files.2018.html)

# %% [markdown]
# ## Contents
# - [Pulling DP05 From Census API](#Pulling-DP05-From-Census-API)
# - [Pulling DP03 From Census API](#Pulling-DP03-From-Census-API)

# %%
import pandas as pd
import requests

# %% [markdown]
# # Pulling DP05 From Census API
# ## States: TX (48), NY (36), CA (06), FL(12), IL(17)
#
# Table: https://data.census.gov/cedsci/table?q=ACSDP1Y2019.DP05&tid=ACSDP5Y2018.DP05&hidePreview=false
# ACS 5-YEAR DEMOGRAPHIC AND HOUSING ESTIMATES
# Survey/Program: American Community Survey
# 2018: ACS 5-Year Estimates Data Profiles
# TableID: DP05

# %%
# Reference: Census YT tutorial: https://www.youtube.com/watch?v=K0-ifZS0mQI&feature=emb_title&ab_channel=U.S.CensusBureau
# Added in 'NAME' parameter
# Edit 'DP05' table
# add in state:XX for desired state

# %% [markdown]
# #### Format URL should be in

# %%
example_url = 'https://api.census.gov/data/2018/acs/acs5/profile?get=group(DP05),NAME&for=county:*&in=state:48&key=abaab7067d6de5d6a0216fca0b8fca4e9015a87f'

# %% [markdown]
# ## Texas: 48

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params = {
    'get': 'group(DP05),NAME',
    'for': 'county:*',
    'in': 'state:48',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res = requests.get(url,params)
res
# Out:
# <Response [200]>

# %%
df_tx = pd.DataFrame(res.json())
df_tx.head(2)
# Out:
#                     0            1           2           3            4    \
# 0                  NAME  DP05_0031PM  DP05_0032E  DP05_0032M  DP05_0032PE
# 1  Austin County, Texas          0.6        87.0         1.9   -888888888
#
#            5           6           7            8            9    ...  \
# 0  DP05_0032PM  DP05_0033E  DP05_0033M  DP05_0033PE  DP05_0033PM  ...
# 1   -888888888       29565  -555555555        29565   -888888888  ...
#
#             707          708          709           710           711  \
# 0  DP05_0029PEA  DP05_0030MA  DP05_0030EA  DP05_0030PMA  DP05_0030PEA
# 1          None         None         None          None          None
#
#            712          713           714    715     716
# 0  DP05_0031MA  DP05_0031EA  DP05_0031PEA  state  county
# 1         None         None          None     48     015
#
# [2 rows x 717 columns]

# %%
# Set the values in the first row to the columns
df_tx.columns = df_tx.iloc[0]

# %%
# Drop the first row
df_tx = df_tx.iloc[1:, :]

df_tx.head(2)
# Out:
# 0                  NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1  Austin County, Texas         0.6       87.0        1.9  -888888888
# 2  Kenedy County, Texas        20.5       34.7       38.9  -888888888
#
# 0 DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1  -888888888      29565  -555555555       29565  -888888888  ...
# 2  -888888888        595         181         595  -888888888  ...
#
# 0 DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA  \
# 1         None        None        None         None         None        None
# 2         None        None        None         None         None        None
#
# 0 DP05_0031EA DP05_0031PEA state county
# 1        None         None    48    015
# 2        None         None    48    261
#
# [2 rows x 717 columns]

# %%
df_tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 1.4+ MB

# %%
df_tx.to_csv('../data/preprocessing/raw_dp05_tx.csv', index=False)

# %% [markdown]
# ## New York: 36

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params = {
    'get': 'group(DP05),NAME',
    'for': 'county:*',
    'in': 'state:36',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res = requests.get(url,params)
res
# Out:
# <Response [200]>

# %%
df_ny = pd.DataFrame(res.json())
df_ny.head(2)
# Out:
#                           0            1           2           3    \
# 0                        NAME  DP05_0031PM  DP05_0032E  DP05_0032M
# 1  Schoharie County, New York          0.3        93.7         1.2
#
#            4            5           6           7            8            9    \
# 0  DP05_0032PE  DP05_0032PM  DP05_0033E  DP05_0033M  DP05_0033PE  DP05_0033PM
# 1   -888888888   -888888888       31364  -555555555        31364   -888888888
#
#    ...           707          708          709           710           711  \
# 0  ...  DP05_0029PEA  DP05_0030MA  DP05_0030EA  DP05_0030PMA  DP05_0030PEA
# 1  ...          None         None         None          None          None
#
#            712          713           714    715     716
# 0  DP05_0031MA  DP05_0031EA  DP05_0031PEA  state  county
# 1         None         None          None     36     095
#
# [2 rows x 717 columns]

# %%
# Set the values in the first row to the columns
df_ny.columns = df_ny.iloc[0]

# %%
# Drop the first row
df_ny = df_ny.iloc[1:, :]

df_ny.head(2)
# Out:
# 0                        NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1  Schoharie County, New York         0.3       93.7        1.2  -888888888
# 2   Onondaga County, New York         0.1       75.6        0.1  -888888888
#
# 0 DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1  -888888888      31364  -555555555       31364  -888888888  ...
# 2  -888888888     464242  -555555555      464242  -888888888  ...
#
# 0 DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA  \
# 1         None        None        None         None         None        None
# 2         None        None        None         None         None        None
#
# 0 DP05_0031EA DP05_0031PEA state county
# 1        None         None    36    095
# 2        None         None    36    067
#
# [2 rows x 717 columns]

# %%
df_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 1 to 62
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 347.4+ KB

# %%
df_ny.to_csv('../data/preprocessing/raw_dp05_ny.csv', index=False)

# %% [markdown]
# ## California: 06

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params = {
    'get': 'group(DP05),NAME',
    'for': 'county:*',
    'in': 'state:06',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res = requests.get(url,params)
res
# Out:
# <Response [200]>

# %%
df_ca = pd.DataFrame(res.json())
df_ca.head(2)
# Out:
#                        0            1           2           3            4    \
# 0                     NAME  DP05_0031PM  DP05_0032E  DP05_0032M  DP05_0032PE
# 1  Lake County, California          0.3        94.1         1.1   -888888888
#
#            5           6           7            8            9    ...  \
# 0  DP05_0032PM  DP05_0033E  DP05_0033M  DP05_0033PE  DP05_0033PM  ...
# 1   -888888888       64148  -555555555        64148   -888888888  ...
#
#             707          708          709           710           711  \
# 0  DP05_0029PEA  DP05_0030MA  DP05_0030EA  DP05_0030PMA  DP05_0030PEA
# 1          None         None         None          None          None
#
#            712          713           714    715     716
# 0  DP05_0031MA  DP05_0031EA  DP05_0031PEA  state  county
# 1         None         None          None     06     033
#
# [2 rows x 717 columns]

# %%
# Set the values in the first row to the columns
df_ca.columns = df_ca.iloc[0]

# %%
# Drop the first row
df_ca = df_ca.iloc[1:, :]

df_ca.head(2)
# Out:
# 0                         NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1      Lake County, California         0.3       94.1        1.1  -888888888
# 2  Mariposa County, California         1.1       98.1        4.2  -888888888
#
# 0 DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1  -888888888      64148  -555555555       64148  -888888888  ...
# 2  -888888888      17540  -555555555       17540  -888888888  ...
#
# 0 DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA  \
# 1         None        None        None         None         None        None
# 2         None        None        None         None         None        None
#
# 0 DP05_0031EA DP05_0031PEA state county
# 1        None         None    06    033
# 2        None         None    06    043
#
# [2 rows x 717 columns]

# %%
df_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 1 to 58
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 325.0+ KB

# %%
df_ca.to_csv('../data/preprocessing/raw_dp05_ca.csv', index=False)

# %% [markdown]
# ## Florida: 12

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params = {
    'get': 'group(DP05),NAME',
    'for': 'county:*',
    'in': 'state:12',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res = requests.get(url,params)
res
# Out:
# <Response [200]>

# %%
df_fl = pd.DataFrame(res.json())
df_fl.head(2)
# Out:
#                         0            1           2           3            4    \
# 0                      NAME  DP05_0031PM  DP05_0032E  DP05_0032M  DP05_0032PE
# 1  Okaloosa County, Florida          0.1        83.2         0.3   -888888888
#
#            5           6           7            8            9    ...  \
# 0  DP05_0032PM  DP05_0033E  DP05_0033M  DP05_0033PE  DP05_0033PM  ...
# 1   -888888888      200737  -555555555       200737   -888888888  ...
#
#             707          708          709           710           711  \
# 0  DP05_0029PEA  DP05_0030MA  DP05_0030EA  DP05_0030PMA  DP05_0030PEA
# 1          None         None         None          None          None
#
#            712          713           714    715     716
# 0  DP05_0031MA  DP05_0031EA  DP05_0031PEA  state  county
# 1         None         None          None     12     091
#
# [2 rows x 717 columns]

# %%
# Set the values in the first row to the columns
df_fl.columns = df_fl.iloc[0]

# %%
# Drop the first row
df_fl = df_fl.iloc[1:, :]

df_fl.head(2)
# Out:
# 0                      NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1  Okaloosa County, Florida         0.1       83.2        0.3  -888888888
# 2    Taylor County, Florida         0.5       88.1        1.8  -888888888
#
# 0 DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1  -888888888     200737  -555555555      200737  -888888888  ...
# 2  -888888888      22098  -555555555       22098  -888888888  ...
#
# 0 DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA  \
# 1         None        None        None         None         None        None
# 2         None        None        None         None         None        None
#
# 0 DP05_0031EA DP05_0031PEA state county
# 1        None         None    12    091
# 2        None         None    12    123
#
# [2 rows x 717 columns]

# %%
df_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 1 to 67
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 375.4+ KB

# %%
df_fl.to_csv('../data/preprocessing/raw_dp05_fl.csv', index=False)

# %% [markdown]
# ## Illinois: 17

# %%
# Set base url
url = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params = {
    'get': 'group(DP05),NAME',
    'for': 'county:*',
    'in': 'state:17',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res = requests.get(url,params)
res
# Out:
# <Response [200]>

# %%
df_il = pd.DataFrame(res.json())
df_il.head(2)
# Out:
#                        0            1           2           3            4    \
# 0                     NAME  DP05_0031PM  DP05_0032E  DP05_0032M  DP05_0032PE
# 1  Jersey County, Illinois          1.0        81.3         3.2   -888888888
#
#            5           6           7            8            9    ...  \
# 0  DP05_0032PM  DP05_0033E  DP05_0033M  DP05_0033PE  DP05_0033PM  ...
# 1   -888888888       22069  -555555555        22069   -888888888  ...
#
#             707          708          709           710           711  \
# 0  DP05_0029PEA  DP05_0030MA  DP05_0030EA  DP05_0030PMA  DP05_0030PEA
# 1          None         None         None          None          None
#
#            712          713           714    715     716
# 0  DP05_0031MA  DP05_0031EA  DP05_0031PEA  state  county
# 1         None         None          None     17     083
#
# [2 rows x 717 columns]

# %%
# Set the values in the first row to the columns
df_il.columns = df_il.iloc[0]

# %%
# Drop the first row
df_il = df_il.iloc[1:, :]

df_il.head(2)
# Out:
# 0                     NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1  Jersey County, Illinois         1.0       81.3        3.2  -888888888
# 2  Putnam County, Illinois         1.2       92.6        4.6  -888888888
#
# 0 DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1  -888888888      22069  -555555555       22069  -888888888  ...
# 2  -888888888       5746  -555555555        5746  -888888888  ...
#
# 0 DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA DP05_0031MA  \
# 1         None        None        None         None         None        None
# 2         None        None        None         None         None        None
#
# 0 DP05_0031EA DP05_0031PEA state county
# 1        None         None    17    083
# 2        None         None    17    155
#
# [2 rows x 717 columns]

# %%
df_il.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 1 to 102
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 571.5+ KB

# %%
df_il.to_csv('../data/preprocessing/raw_dp05_il.csv', index=False)

# %% [markdown]
# ## Combining States

# %%
df = pd.concat([df_tx, df_ny, df_ca, df_fl, df_il])
df
# Out:
# 0                          NAME DP05_0031PM DP05_0032E DP05_0032M DP05_0032PE  \
# 1          Austin County, Texas         0.6       87.0        1.9  -888888888
# 2          Kenedy County, Texas        20.5       34.7       38.9  -888888888
# 3          Nueces County, Texas         0.1       79.3        0.3  -888888888
# 4        Colorado County, Texas         0.1       85.6        0.3  -888888888
# 5    San Patricio County, Texas         0.5       86.1        1.6  -888888888
# ..                          ...         ...        ...        ...         ...
# 98   Champaign County, Illinois         0.2       78.4        0.8  -888888888
# 99        Ford County, Illinois         0.5       73.3        1.4  -888888888
# 100    Kendall County, Illinois         0.5       80.9        1.8  -888888888
# 101     Marion County, Illinois         0.4       81.3        1.4  -888888888
# 102      Mason County, Illinois         0.5       83.4        1.6  -888888888
#
# 0   DP05_0032PM DP05_0033E  DP05_0033M DP05_0033PE DP05_0033PM  ...  \
# 1    -888888888      29565  -555555555       29565  -888888888  ...
# 2    -888888888        595         181         595  -888888888  ...
# 3    -888888888     360486  -555555555      360486  -888888888  ...
# 4    -888888888      21022  -555555555       21022  -888888888  ...
# 5    -888888888      67046  -555555555       67046  -888888888  ...
# ..          ...        ...         ...         ...         ...  ...
# 98   -888888888     209448  -555555555      209448  -888888888  ...
# 99   -888888888      13398  -555555555       13398  -888888888  ...
# 100  -888888888     124626  -555555555      124626  -888888888  ...
# 101  -888888888      38084  -555555555       38084  -888888888  ...
# 102  -888888888      13778  -555555555       13778  -888888888  ...
#
# 0   DP05_0029PEA DP05_0030MA DP05_0030EA DP05_0030PMA DP05_0030PEA  \
# 1           None        None        None         None         None
# 2           None        None        None         None         None
# 3           None        None        None         None         None
# 4           None        None        None         None         None
# 5           None        None        None         None         None
# ..           ...         ...         ...          ...          ...
# 98          None        None        None         None         None
# 99          None        None        None         None         None
# 100         None        None        None         None         None
# 101         None        None        None         None         None
# 102         None        None        None         None         None
#
# 0   DP05_0031MA DP05_0031EA DP05_0031PEA state county
# 1          None        None         None    48    015
# 2          None        None         None    48    261
# 3          None        None         None    48    355
# 4          None        None         None    48    089
# 5          None        None         None    48    409
# ..          ...         ...          ...   ...    ...
# 98         None        None         None    17    019
# 99         None        None         None    17    053
# 100        None        None         None    17    093
# 101        None        None         None    17    121
# 102        None        None         None    17    125
#
# [543 rows x 717 columns]

# %%
# Export data to .csv
df.to_csv('../data/preprocessing/raw_dp05_five_states.csv', index=False)

# %% [markdown]
# ## Pulling DP05 Headers

# %%
# Per directions in tutorial at https://www.youtube.com/watch?v=K0-ifZS0mQI&feature=emb_title&ab_channel=U.S.CensusBureau,
# downloaded table and saved csv data with overlays
# These headers correspond to the codes in the previous table

header_df = pd.read_csv('../data/preprocessing/acs5y2018_dp05_data_with_overlays.csv')
header_df
# Out:
#       GEO_ID                  NAME  \
# 0         id  Geographic Area Name
# 1  0100000US         United States
#
#                                          DP05_0031PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                0.1
#
#                                           DP05_0032E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                               79.3
#
#                                           DP05_0032M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                0.1
#
#                                          DP05_0032PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                (X)
#
#                                          DP05_0032PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                          DP05_0033E                               DP05_0033M  \
# 0  Estimate!!RACE!!Total population  Margin of Error!!RACE!!Total population
# 1                         322903030                                    *****
#
#                                 DP05_0033PE  ...  \
# 0  Percent Estimate!!RACE!!Total population  ...
# 1                                 322903030  ...
#
#                                           DP05_0029M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               5463
#
#                                          DP05_0029PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                           49238581
#
#                                          DP05_0029PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                                           DP05_0030E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                           21781300
#
#                                           DP05_0030M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               3215
#
#                                          DP05_0030PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               44.2
#
#                                          DP05_0030PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                0.1
#
#                                           DP05_0031E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                           27457281
#
#                                           DP05_0031M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               3635
#
#                                          DP05_0031PE
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               55.8
#
# [2 rows x 358 columns]

# %%
# Get rid of geo ID column
header_df = header_df.iloc[:, 1:]

header_df
# Out:
#                    NAME                                        DP05_0031PM  \
# 0  Geographic Area Name  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1         United States                                                0.1
#
#                                           DP05_0032E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                               79.3
#
#                                           DP05_0032M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                                0.1
#
#                                          DP05_0032PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                                (X)
#
#                                          DP05_0032PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                          DP05_0033E                               DP05_0033M  \
# 0  Estimate!!RACE!!Total population  Margin of Error!!RACE!!Total population
# 1                         322903030                                    *****
#
#                                 DP05_0033PE  \
# 0  Percent Estimate!!RACE!!Total population
# 1                                 322903030
#
#                                        DP05_0033PM  ...  \
# 0  Percent Margin of Error!!RACE!!Total population  ...
# 1                                              (X)  ...
#
#                                           DP05_0029M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               5463
#
#                                          DP05_0029PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                           49238581
#
#                                          DP05_0029PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                (X)
#
#                                           DP05_0030E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                           21781300
#
#                                           DP05_0030M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               3215
#
#                                          DP05_0030PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               44.2
#
#                                          DP05_0030PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
# 1                                                0.1
#
#                                           DP05_0031E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
# 1                                           27457281
#
#                                           DP05_0031M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
# 1                                               3635
#
#                                          DP05_0031PE
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
# 1                                               55.8
#
# [2 rows x 357 columns]

# %%
header_df.to_csv('../data/preprocessing/dp05_headers.csv')

# %% [markdown]
# ### Examine the columns

# %%
api_cols = list(df.columns)

# %%
header_cols = list(header_df.columns)

# %%
len(api_cols), len(header_cols)
# Out:
# (717, 357)

# %%
# Examine the difference in columns
difference = set(api_cols) - set(header_cols)

print(len(difference))

list(difference)[:10]
# Out:
# 359
# ['DP05_0017PEA',
#  'DP05_0049PMA',
#  'DP05_0046PEA',
#  'DP05_0089PEA',
#  'DP05_0048EA',
#  'DP05_0051MA',
#  'DP05_0070EA',
#  'DP05_0045PEA',
#  'DP05_0033PEA',
#  'DP05_0013MA']

# %%
# By looking some of these up in the .csv, it appears at least some are blank

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 1 to 102
# Columns: 717 entries, NAME to county
# dtypes: object(717)
# memory usage: 3.0+ MB

# %%
df.isna().sum()
# Out:
# 0
# NAME              0
# DP05_0031PM       0
# DP05_0032E        0
# DP05_0032M        0
# DP05_0032PE       0
#                ...
# DP05_0031MA     512
# DP05_0031EA     543
# DP05_0031PEA    543
# state             0
# county            0
# Length: 717, dtype: int64

# %%
# Save the null values to a new dataframe.
nan_df = pd.DataFrame(df.isna().sum(), columns=['NaN Counts'])

# Display the entries with NaN counts for every one of 254 counties.
nan_df[nan_df['NaN Counts'] > 500]
# Out:
#               NaN Counts
# 0
# DP05_0031PMA         523
# DP05_0032MA          523
# DP05_0032EA          543
# DP05_0033EA          543
# DP05_0033PEA         543
# ...                  ...
# DP05_0030PMA         523
# DP05_0030PEA         543
# DP05_0031MA          512
# DP05_0031EA          543
# DP05_0031PEA         543
#
# [321 rows x 1 columns]

# %% [markdown]
# ## Create a dictionary of the columns and their identifiers

# %%
row_one_df = header_df.iloc[:1, :]

row_one_df
# Out:
#                    NAME                                        DP05_0031PM  \
# 0  Geographic Area Name  Percent Margin of Error!!SEX AND AGE!!Total po...
#
#                                           DP05_0032E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
#
#                                           DP05_0032M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
#
#                                          DP05_0032PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
#
#                                          DP05_0032PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
#
#                          DP05_0033E                               DP05_0033M  \
# 0  Estimate!!RACE!!Total population  Margin of Error!!RACE!!Total population
#
#                                 DP05_0033PE  \
# 0  Percent Estimate!!RACE!!Total population
#
#                                        DP05_0033PM  ...  \
# 0  Percent Margin of Error!!RACE!!Total population  ...
#
#                                           DP05_0029M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
#
#                                          DP05_0029PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
#
#                                          DP05_0029PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
#
#                                           DP05_0030E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
#
#                                           DP05_0030M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
#
#                                          DP05_0030PE  \
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
#
#                                          DP05_0030PM  \
# 0  Percent Margin of Error!!SEX AND AGE!!Total po...
#
#                                           DP05_0031E  \
# 0  Estimate!!SEX AND AGE!!Total population!!65 ye...
#
#                                           DP05_0031M  \
# 0  Margin of Error!!SEX AND AGE!!Total population...
#
#                                          DP05_0031PE
# 0  Percent Estimate!!SEX AND AGE!!Total populatio...
#
# [1 rows x 357 columns]

# %%
# Convert the row of the dataframe into a list
descriptions = row_one_df.values.tolist()

# The output is a nested list so convert it to a regular list
descriptions = descriptions[0]

# View the first five entries
descriptions[:5]
# Out:
# ['Geographic Area Name',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)']

# %%
# Check the length of the headers and their descriptions
len(header_cols), len(descriptions)
# Out:
# (357, 357)

# %%
# Create a dictionary from a zipped list of the header columns and descriptions
header_dict = dict(zip(header_cols, descriptions))

# View the first five entries in the dictionary
list(header_dict.items())[:5]
# Out:
# [('NAME', 'Geographic Area Name'),
#  ('DP05_0031PM',
#   'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female'),
#  ('DP05_0032E',
#   'Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)'),
#  ('DP05_0032M',
#   'Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)'),
#  ('DP05_0032PE',
#   'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)')]

# %%
# Rename the colums in the original dataframe according to the dictionary
df.rename(columns = header_dict, inplace=True)

# %%
# Drop columns with NaN values
df.dropna(axis=1, inplace=True)

# %%
# Display the dataframe
df
# Out:
# 0          Geographic Area Name  \
# 1          Austin County, Texas
# 2          Kenedy County, Texas
# 3          Nueces County, Texas
# 4        Colorado County, Texas
# 5    San Patricio County, Texas
# ..                          ...
# 98   Champaign County, Illinois
# 99        Ford County, Illinois
# 100    Kendall County, Illinois
# 101     Marion County, Illinois
# 102      Mason County, Illinois
#
# 0   Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 1                                                  0.6
# 2                                                 20.5
# 3                                                  0.1
# 4                                                  0.1
# 5                                                  0.5
# ..                                                 ...
# 98                                                 0.2
# 99                                                 0.5
# 100                                                0.5
# 101                                                0.4
# 102                                                0.5
#
# 0   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 1                                                 87.0
# 2                                                 34.7
# 3                                                 79.3
# 4                                                 85.6
# 5                                                 86.1
# ..                                                 ...
# 98                                                78.4
# 99                                                73.3
# 100                                               80.9
# 101                                               81.3
# 102                                               83.4
#
# 0   Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 1                                                  1.9
# 2                                                 38.9
# 3                                                  0.3
# 4                                                  0.3
# 5                                                  1.6
# ..                                                 ...
# 98                                                 0.8
# 99                                                 1.4
# 100                                                1.8
# 101                                                1.4
# 102                                                1.6
#
# 0   Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 1                                           -888888888
# 2                                           -888888888
# 3                                           -888888888
# 4                                           -888888888
# 5                                           -888888888
# ..                                                 ...
# 98                                          -888888888
# 99                                          -888888888
# 100                                         -888888888
# 101                                         -888888888
# 102                                         -888888888
#
# 0   Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 1                                           -888888888
# 2                                           -888888888
# 3                                           -888888888
# 4                                           -888888888
# 5                                           -888888888
# ..                                                 ...
# 98                                          -888888888
# 99                                          -888888888
# 100                                         -888888888
# 101                                         -888888888
# 102                                         -888888888
#
# 0   Estimate!!RACE!!Total population Margin of Error!!RACE!!Total population  \
# 1                              29565                              -555555555
# 2                                595                                     181
# 3                             360486                              -555555555
# 4                              21022                              -555555555
# 5                              67046                              -555555555
# ..                               ...                                     ...
# 98                            209448                              -555555555
# 99                             13398                              -555555555
# 100                           124626                              -555555555
# 101                            38084                              -555555555
# 102                            13778                              -555555555
#
# 0   Percent Estimate!!RACE!!Total population  \
# 1                                      29565
# 2                                        595
# 3                                     360486
# 4                                      21022
# 5                                      67046
# ..                                       ...
# 98                                    209448
# 99                                     13398
# 100                                   124626
# 101                                    38084
# 102                                    13778
#
# 0   Percent Margin of Error!!RACE!!Total population  ... DP05_0004PMA  \
# 1                                        -888888888  ...          (X)
# 2                                        -888888888  ...          (X)
# 3                                        -888888888  ...          (X)
# 4                                        -888888888  ...          (X)
# 5                                        -888888888  ...          (X)
# ..                                              ...  ...          ...
# 98                                       -888888888  ...          (X)
# 99                                       -888888888  ...          (X)
# 100                                      -888888888  ...          (X)
# 101                                      -888888888  ...          (X)
# 102                                      -888888888  ...          (X)
#
# 0   DP05_0004PEA DP05_0018PMA DP05_0018PEA DP05_0025PMA DP05_0028PMA  \
# 1            (X)          (X)          (X)          (X)          (X)
# 2            (X)          (X)          (X)          (X)          (X)
# 3            (X)          (X)          (X)          (X)          (X)
# 4            (X)          (X)          (X)          (X)          (X)
# 5            (X)          (X)          (X)          (X)          (X)
# ..           ...          ...          ...          ...          ...
# 98           (X)          (X)          (X)          (X)          (X)
# 99           (X)          (X)          (X)          (X)          (X)
# 100          (X)          (X)          (X)          (X)          (X)
# 101          (X)          (X)          (X)          (X)          (X)
# 102          (X)          (X)          (X)          (X)          (X)
#
# 0   DP05_0028PEA DP05_0029PMA state county
# 1            (X)          (X)    48    015
# 2            (X)          (X)    48    261
# 3            (X)          (X)    48    355
# 4            (X)          (X)    48    089
# 5            (X)          (X)    48    409
# ..           ...          ...   ...    ...
# 98           (X)          (X)    17    019
# 99           (X)          (X)    17    053
# 100          (X)          (X)    17    093
# 101          (X)          (X)    17    121
# 102          (X)          (X)    17    125
#
# [543 rows x 378 columns]

# %%
df.to_csv('../data/preprocessing/raw_dp05_with_headers_five_states.csv', index=False)

# %% [markdown]
# # Pulling DP03 From Census API
# ## States: TX (48), NY (36), CA (06), FL(12), IL(17)
#
# Table: https://data.census.gov/cedsci/table?q=ACSDP1Y2019.DP03&tid=ACSDP1Y2019.DP03&hidePreview=true
# SELECTED ECONOMIC CHARACTERISTICS
# Survey/Program: American Community Survey
# 2018: ACS 5-Year Estimates Data Profiles
# TableID: DP03

# %% [markdown]
# ### Format URL should be in

# %%
example_url = 'https://api.census.gov/data/2018/acs/acs5/profile?get=group(DP03),NAME&for=county:*&in=state:481&key=abaab7067d6de5d6a0216fca0b8fca4e9015a87f'

# %% [markdown]
# ## Texas: 48

# %%
# Set base url
url03 = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params03 = {
    'get': 'group(DP03),NAME',
    'for': 'county:*',
    'in': 'state:48',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res03 = requests.get(url03,params03)
res03
# Out:
# <Response [200]>

# %%
df03_tx = pd.DataFrame(res03.json())
df03_tx.head(3)
# Out:
#                    0               1           2           3            4     \
# 0                  NAME          GEO_ID  DP03_0001E  DP03_0001M  DP03_0001PE
# 1  Austin County, Texas  0500000US48015       23354         108        23354
# 2  Kenedy County, Texas  0500000US48261         428         122          428
#
#           5           6           7            8            9     ...  \
# 0  DP03_0001PM  DP03_0002E  DP03_0002M  DP03_0002PE  DP03_0002PM  ...
# 1   -888888888       14475         413         62.0          1.8  ...
# 2   -888888888         220          83         51.4         13.4  ...
#
#           1091         1092          1093          1094         1095  \
# 0  DP03_0136EA  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  DP03_0137MA
# 1          (X)          (X)          None          None          (X)
# 2          (X)          (X)          None          None          (X)
#
#           1096          1097          1098   1099    1100
# 0  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county
# 1          (X)          None          None     48     015
# 2          (X)          None          None     48     261
#
# [3 rows x 1101 columns]

# %%
# Set the values in the first row to the columns
df03_tx.columns = df03_tx.iloc[0]

# %%
# Drop the first row
df03_tx = df03_tx.iloc[1:, :]

df03_tx.head(3)
# Out:
# 0                  NAME          GEO_ID DP03_0001E DP03_0001M DP03_0001PE  \
# 1  Austin County, Texas  0500000US48015      23354        108       23354
# 2  Kenedy County, Texas  0500000US48261        428        122         428
# 3  Nueces County, Texas  0500000US48355     280990        413      280990
#
# 0 DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ... DP03_0136EA  \
# 1  -888888888      14475        413        62.0         1.8  ...         (X)
# 2  -888888888        220         83        51.4        13.4  ...         (X)
# 3  -888888888     177352       1636        63.1         0.6  ...         (X)
#
# 0 DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA DP03_0137PEA  \
# 1         (X)         None         None         (X)         (X)         None
# 2         (X)         None         None         (X)         (X)         None
# 3         (X)         None         None         (X)         (X)         None
#
# 0 DP03_0137PMA state county
# 1         None    48    015
# 2         None    48    261
# 3         None    48    355
#
# [3 rows x 1101 columns]

# %%
# Display information about the dataframe.
df03_tx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Columns: 1101 entries, NAME to county
# dtypes: object(1101)
# memory usage: 2.1+ MB

# %%
# Export the dataframe as a csv.
df03_tx.to_csv('../data/preprocessing/raw_dp03_tx.csv', index=False)

# %% [markdown]
# ## New York: 36

# %%
# Set base url
url03 = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params03 = {
    'get': 'group(DP03),NAME',
    'for': 'county:*',
    'in': 'state:36',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res03 = requests.get(url03,params03)
res03
# Out:
# <Response [200]>

# %%
df03_ny = pd.DataFrame(res03.json())
df03_ny.head(3)
# Out:
#                          0               1           2           3     \
# 0                        NAME          GEO_ID  DP03_0001E  DP03_0001M
# 1  Schoharie County, New York  0500000US36095       26508          75
# 2   Onondaga County, New York  0500000US36067      376244         342
#
#           4            5           6           7            8            9     \
# 0  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M  DP03_0002PE  DP03_0002PM
# 1        26508   -888888888       15390         382         58.1          1.5
# 2       376244   -888888888      235381        1621         62.6          0.4
#
#    ...         1091         1092          1093          1094         1095  \
# 0  ...  DP03_0136EA  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  DP03_0137MA
# 1  ...          (X)          (X)          None          None          (X)
# 2  ...          (X)          (X)          None          None          (X)
#
#           1096          1097          1098   1099    1100
# 0  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county
# 1          (X)          None          None     36     095
# 2          (X)          None          None     36     067
#
# [3 rows x 1101 columns]

# %%
# Set the values in the first row to the columns
df03_ny.columns = df03_ny.iloc[0]

# %%
# Drop the first row
df03_ny = df03_ny.iloc[1:, :]

df03_ny.head(3)
# Out:
# 0                        NAME          GEO_ID DP03_0001E DP03_0001M  \
# 1  Schoharie County, New York  0500000US36095      26508         75
# 2   Onondaga County, New York  0500000US36067     376244        342
# 3    Clinton County, New York  0500000US36019      67919        178
#
# 0 DP03_0001PE DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ...  \
# 1       26508  -888888888      15390        382        58.1         1.5  ...
# 2      376244  -888888888     235381       1621        62.6         0.4  ...
# 3       67919  -888888888      37903        797        55.8         1.2  ...
#
# 0 DP03_0136EA DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA  \
# 1         (X)         (X)         None         None         (X)         (X)
# 2         (X)         (X)         None         None         (X)         (X)
# 3         (X)         (X)         None         None         (X)         (X)
#
# 0 DP03_0137PEA DP03_0137PMA state county
# 1         None         None    36    095
# 2         None         None    36    067
# 3         None         None    36    019
#
# [3 rows x 1101 columns]

# %%
# Display information about the dataframe.
df03_ny.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 1 to 62
# Columns: 1101 entries, NAME to county
# dtypes: object(1101)
# memory usage: 533.4+ KB

# %%
# Export the dataframe as a csv.
df03_ny.to_csv('../data/preprocessing/raw_dp03_ny.csv', index=False)

# %% [markdown]
# ## California: 06

# %%
# Set base url
url03 = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params03 = {
    'get': 'group(DP03),NAME',
    'for': 'county:*',
    'in': 'state:06',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res03 = requests.get(url03,params03)
res03
# Out:
# <Response [200]>

# %%
df03_ca = pd.DataFrame(res03.json())
df03_ca.head(3)
# Out:
#                           0               1           2           3     \
# 0                         NAME          GEO_ID  DP03_0001E  DP03_0001M
# 1      Lake County, California  0500000US06033       52331         199
# 2  Mariposa County, California  0500000US06043       15019         113
#
#           4            5           6           7            8            9     \
# 0  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M  DP03_0002PE  DP03_0002PM
# 1        52331   -888888888       26160         858         50.0          1.6
# 2        15019   -888888888        7735         395         51.5          2.5
#
#    ...         1091         1092          1093          1094         1095  \
# 0  ...  DP03_0136EA  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  DP03_0137MA
# 1  ...          (X)          (X)          None          None          (X)
# 2  ...          (X)          (X)          None          None          (X)
#
#           1096          1097          1098   1099    1100
# 0  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county
# 1          (X)          None          None     06     033
# 2          (X)          None          None     06     043
#
# [3 rows x 1101 columns]

# %%
# Set the values in the first row to the columns
df03_ca.columns = df03_ca.iloc[0]

# %%
# Drop the first row
df03_ca = df03_ca.iloc[1:, :]

df03_ca.head(3)
# Out:
# 0                         NAME          GEO_ID DP03_0001E DP03_0001M  \
# 1      Lake County, California  0500000US06033      52331        199
# 2  Mariposa County, California  0500000US06043      15019        113
# 3      Yuba County, California  0500000US06115      56589        222
#
# 0 DP03_0001PE DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ...  \
# 1       52331  -888888888      26160        858        50.0         1.6  ...
# 2       15019  -888888888       7735        395        51.5         2.5  ...
# 3       56589  -888888888      33246        972        58.7         1.7  ...
#
# 0 DP03_0136EA DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA  \
# 1         (X)         (X)         None         None         (X)         (X)
# 2         (X)         (X)         None         None         (X)         (X)
# 3         (X)         (X)         None         None         (X)         (X)
#
# 0 DP03_0137PEA DP03_0137PMA state county
# 1         None         None    06    033
# 2         None         None    06    043
# 3         None         None    06    115
#
# [3 rows x 1101 columns]

# %%
# Display information about the dataframe.
df03_ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 1 to 58
# Columns: 1101 entries, NAME to county
# dtypes: object(1101)
# memory usage: 499.0+ KB

# %%
# Export the dataframe as a csv.
df03_ca.to_csv('../data/preprocessing/raw_dp03_ca.csv', index=False)

# %% [markdown]
# ## Florida: 12

# %%
# Set base url
url03 = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params03 = {
    'get': 'group(DP03),NAME',
    'for': 'county:*',
    'in': 'state:12',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res03 = requests.get(url03,params03)
res03
# Out:
# <Response [200]>

# %%
df03_fl = pd.DataFrame(res03.json())
df03_fl.head(3)
# Out:
#                        0               1           2           3     \
# 0                      NAME          GEO_ID  DP03_0001E  DP03_0001M
# 1  Okaloosa County, Florida  0500000US12091      160704         276
# 2    Taylor County, Florida  0500000US12123       18353         161
#
#           4            5           6           7            8            9     \
# 0  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M  DP03_0002PE  DP03_0002PM
# 1       160704   -888888888      102023        1281         63.5          0.8
# 2        18353   -888888888        6918         443         37.7          2.4
#
#    ...         1091         1092          1093          1094         1095  \
# 0  ...  DP03_0136EA  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  DP03_0137MA
# 1  ...          (X)          (X)          None          None          (X)
# 2  ...          (X)          (X)          None          None          (X)
#
#           1096          1097          1098   1099    1100
# 0  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county
# 1          (X)          None          None     12     091
# 2          (X)          None          None     12     123
#
# [3 rows x 1101 columns]

# %%
# Set the values in the first row to the columns
df03_fl.columns = df03_fl.iloc[0]

# %%
# Drop the first row
df03_fl = df03_fl.iloc[1:, :]

df03_fl.head(3)
# Out:
# 0                        NAME          GEO_ID DP03_0001E DP03_0001M  \
# 1    Okaloosa County, Florida  0500000US12091     160704        276
# 2      Taylor County, Florida  0500000US12123      18353        161
# 3  Washington County, Florida  0500000US12133      20237         91
#
# 0 DP03_0001PE DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ...  \
# 1      160704  -888888888     102023       1281        63.5         0.8  ...
# 2       18353  -888888888       6918        443        37.7         2.4  ...
# 3       20237  -888888888       9358        507        46.2         2.5  ...
#
# 0 DP03_0136EA DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA  \
# 1         (X)         (X)         None         None         (X)         (X)
# 2         (X)         (X)         None         None         (X)         (X)
# 3         (X)         (X)         None         None         (X)         (X)
#
# 0 DP03_0137PEA DP03_0137PMA state county
# 1         None         None    12    091
# 2         None         None    12    123
# 3         None         None    12    133
#
# [3 rows x 1101 columns]

# %%
# Display information about the dataframe.
df03_fl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 1 to 67
# Columns: 1101 entries, NAME to county
# dtypes: object(1101)
# memory usage: 576.4+ KB

# %%
# Export the dataframe as a csv.
df03_fl.to_csv('../data/preprocessing/raw_dp03_fl.csv', index=False)

# %% [markdown]
# ## Illinois: 17

# %%
# Set base url
url03 = 'https://api.census.gov/data/2018/acs/acs5/profile?'

# Set params
params03 = {
    'get': 'group(DP03),NAME',
    'for': 'county:*',
    'in': 'state:17',
    'key': 'abaab7067d6de5d6a0216fca0b8fca4e9015a87f'
}

# Make a request and display the response code.
res03 = requests.get(url03,params03)
res03
# Out:
# <Response [200]>

# %%
df03_il = pd.DataFrame(res03.json())
df03_il.head(3)
# Out:
#                       0               1           2           3     \
# 0                     NAME          GEO_ID  DP03_0001E  DP03_0001M
# 1  Jersey County, Illinois  0500000US17083       18079          74
# 2  Putnam County, Illinois  0500000US17155        4777          27
#
#           4            5           6           7            8            9     \
# 0  DP03_0001PE  DP03_0001PM  DP03_0002E  DP03_0002M  DP03_0002PE  DP03_0002PM
# 1        18079   -888888888       11127         375         61.5          2.1
# 2         4777   -888888888        3107         117         65.0          2.4
#
#    ...         1091         1092          1093          1094         1095  \
# 0  ...  DP03_0136EA  DP03_0136MA  DP03_0136PEA  DP03_0136PMA  DP03_0137MA
# 1  ...          (X)          (X)          None          None          (X)
# 2  ...          (X)          (X)          None          None          (X)
#
#           1096          1097          1098   1099    1100
# 0  DP03_0137EA  DP03_0137PEA  DP03_0137PMA  state  county
# 1          (X)          None          None     17     083
# 2          (X)          None          None     17     155
#
# [3 rows x 1101 columns]

# %%
# Set the values in the first row to the columns
df03_il.columns = df03_il.iloc[0]

# %%
# Drop the first row
df03_il = df03_il.iloc[1:, :]

df03_il.head(3)
# Out:
# 0                      NAME          GEO_ID DP03_0001E DP03_0001M DP03_0001PE  \
# 1   Jersey County, Illinois  0500000US17083      18079         74       18079
# 2   Putnam County, Illinois  0500000US17155       4777         27        4777
# 3  De Witt County, Illinois  0500000US17039      13024         53       13024
#
# 0 DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ... DP03_0136EA  \
# 1  -888888888      11127        375        61.5         2.1  ...         (X)
# 2  -888888888       3107        117        65.0         2.4  ...         (X)
# 3  -888888888       8614        250        66.1         1.9  ...         (X)
#
# 0 DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA DP03_0137EA DP03_0137PEA  \
# 1         (X)         None         None         (X)         (X)         None
# 2         (X)         None         None         (X)         (X)         None
# 3         (X)         None         None         (X)         (X)         None
#
# 0 DP03_0137PMA state county
# 1         None    17    083
# 2         None    17    155
# 3         None    17    039
#
# [3 rows x 1101 columns]

# %%
# Display information about the dataframe.
df03_il.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 1 to 102
# Columns: 1101 entries, NAME to county
# dtypes: object(1101)
# memory usage: 877.5+ KB

# %%
# Export the dataframe as a csv.
df03_il.to_csv('../data/preprocessing/raw_dp03_il.csv', index=False)

# %% [markdown]
# ## Combining States

# %%
df03 = pd.concat([df03_tx, df03_ny, df03_ca, df03_fl, df03_il])
df03
# Out:
# 0                          NAME          GEO_ID DP03_0001E DP03_0001M  \
# 1          Austin County, Texas  0500000US48015      23354        108
# 2          Kenedy County, Texas  0500000US48261        428        122
# 3          Nueces County, Texas  0500000US48355     280990        413
# 4        Colorado County, Texas  0500000US48089      16585        107
# 5    San Patricio County, Texas  0500000US48409      50886        205
# ..                          ...             ...        ...        ...
# 98   Champaign County, Illinois  0500000US17019     174427        251
# 99        Ford County, Illinois  0500000US17053      10736         98
# 100    Kendall County, Illinois  0500000US17093      92166        424
# 101     Marion County, Illinois  0500000US17121      30162        100
# 102      Mason County, Illinois  0500000US17125      11283         55
#
# 0   DP03_0001PE DP03_0001PM DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  \
# 1         23354  -888888888      14475        413        62.0         1.8
# 2           428  -888888888        220         83        51.4        13.4
# 3        280990  -888888888     177352       1636        63.1         0.6
# 4         16585  -888888888       9832        373        59.3         2.2
# 5         50886  -888888888      30618        712        60.2         1.4
# ..          ...         ...        ...        ...         ...         ...
# 98       174427  -888888888     108838       1206        62.4         0.7
# 99        10736  -888888888       6618        184        61.6         1.8
# 100       92166  -888888888      67387       1364        73.1         1.4
# 101       30162  -888888888      18482        320        61.3         1.0
# 102       11283  -888888888       6699        207        59.4         1.8
#
# 0    ... DP03_0136EA DP03_0136MA DP03_0136PEA DP03_0136PMA DP03_0137MA  \
# 1    ...         (X)         (X)         None         None         (X)
# 2    ...         (X)         (X)         None         None         (X)
# 3    ...         (X)         (X)         None         None         (X)
# 4    ...         (X)         (X)         None         None         (X)
# 5    ...         (X)         (X)         None         None         (X)
# ..   ...         ...         ...          ...          ...         ...
# 98   ...         (X)         (X)         None         None         (X)
# 99   ...         (X)         (X)         None         None         (X)
# 100  ...         (X)         (X)         None         None         (X)
# 101  ...         (X)         (X)         None         None         (X)
# 102  ...         (X)         (X)         None         None         (X)
#
# 0   DP03_0137EA DP03_0137PEA DP03_0137PMA state county
# 1           (X)         None         None    48    015
# 2           (X)         None         None    48    261
# 3           (X)         None         None    48    355
# 4           (X)         None         None    48    089
# 5           (X)         None         None    48    409
# ..          ...          ...          ...   ...    ...
# 98          (X)         None         None    17    019
# 99          (X)         None         None    17    053
# 100         (X)         None         None    17    093
# 101         (X)         None         None    17    121
# 102         (X)         None         None    17    125
#
# [543 rows x 1101 columns]

# %%
# Export data to .csv
df03.to_csv('../data/preprocessing/raw_dp03_five_states.csv', index=False)

# %% [markdown]
# ## Pulling DP03 Headers

# %%
# Per directions in tutorial at https://www.youtube.com/watch?v=K0-ifZS0mQI&feature=emb_title&ab_channel=U.S.CensusBureau,
# downloaded table and saved csv data with overlays
# These headers correspond to the codes in the previous table

header_df03 = pd.read_csv('../data/preprocessing/acs5y2018_dp03_data_with_overlays.csv')
header_df03.head(3)
# Out:
#       GEO_ID                  NAME  \
# 0         id  Geographic Area Name
# 1  0100000US         United States
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                          257754872
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                              16354
#
#                                          DP03_0001PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                          257754872
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                (X)
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                          163276329
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                             146596
#
#                                          DP03_0002PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               63.3
#
#                                          DP03_0002PM  ...  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...  ...
# 1                                                0.1  ...
#
#                                          DP03_0135PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                9.3
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0136PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               11.3
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0137PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               25.6
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
# [2 rows x 550 columns]

# %%
# Get rid of geo ID column
header_df03 = header_df03.iloc[:, 1:]

header_df03.head(3)
# Out:
#                    NAME                                         DP03_0001E  \
# 0  Geographic Area Name  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1         United States                                          257754872
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                              16354
#
#                                          DP03_0001PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                          257754872
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                (X)
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                          163276329
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                             146596
#
#                                          DP03_0002PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
# 1                                               63.3
#
#                                          DP03_0002PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                0.1
#
#                                           DP03_0003E  ...  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  ...
# 1                                          162248196  ...
#
#                                          DP03_0135PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                                9.3
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0136PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               11.3
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
#
#                                          DP03_0137PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
# 1                                               25.6
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                0.1
#
# [2 rows x 549 columns]

# %%
# Export the dataframe as a csv.
header_df03.to_csv('../data/preprocessing/dp03_headers.csv')

# %% [markdown]
# ### Examine the columns

# %%
api_cols = list(df03.columns)

# %%
header_cols = list(header_df03.columns)

# %%
len(api_cols), len(header_cols)
# Out:
# (1101, 549)

# %%
# Examine the difference in columns
difference = set(api_cols) - set(header_cols)

print(len(difference))

list(difference)[:10]
# Out:
# 551
# ['DP03_0064EA',
#  'DP03_0046MA',
#  'DP03_0132EA',
#  'DP03_0054EA',
#  'DP03_0058PMA',
#  'DP03_0029EA',
#  'DP03_0132PEA',
#  'DP03_0113MA',
#  'DP03_0089MA',
#  'DP03_0051PMA']

# %%
# By looking some of these up in the .csv, it appears at least some are blank

# %%
# Save the null values to a new dataframe.
nan_df = pd.DataFrame(df03.isna().sum(), columns=['NaN Counts'])

# Display the entries with many NaN values.
nan_df[nan_df['NaN Counts'] > 200]
# Out:
#               NaN Counts
# 0
# DP03_0001EA          543
# DP03_0001MA          543
# DP03_0001PEA         543
# DP03_0002EA          543
# DP03_0002MA          543
# ...                  ...
# DP03_0135PEA         543
# DP03_0136PEA         543
# DP03_0136PMA         543
# DP03_0137PEA         543
# DP03_0137PMA         543
#
# [457 rows x 1 columns]

# %% [markdown]
# ## Create a dictionary of the columns and their identifiers

# %%
row_one_df = header_df03.iloc[:1, :]

row_one_df
# Out:
#                    NAME                                         DP03_0001E  \
# 0  Geographic Area Name  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
#
#                                          DP03_0001PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
#
#                                          DP03_0002PE  \
# 0  Percent Estimate!!EMPLOYMENT STATUS!!Populatio...
#
#                                          DP03_0002PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
#
#                                           DP03_0003E  ...  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...  ...
#
#                                          DP03_0135PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
#
#                                          DP03_0136PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
#
#                                          DP03_0137PE  \
# 0  Percent Estimate!!PERCENTAGE OF FAMILIES AND P...
#
#                                          DP03_0137PM
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
#
# [1 rows x 549 columns]

# %%
# Convert the row of the dataframe into a list
descriptions = row_one_df.values.tolist()

# The output is a nested list so convert it to a regular list
descriptions = descriptions[0]

# View the first five entries
descriptions[:5]
# Out:
# ['Geographic Area Name',
#  'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#  'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over',
#  'Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over',
#  'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over']

# %%
# Check the length of the headers and their descriptions
len(header_cols), len(descriptions)
# Out:
# (549, 549)

# %%
# Create a dictionary from a zipped list of the header columns and descriptions
header_dict = dict(zip(header_cols, descriptions))

# View the first five entries in the dictionary
list(header_dict.items())[:5]
# Out:
# [('NAME', 'Geographic Area Name'),
#  ('DP03_0001E', 'Estimate!!EMPLOYMENT STATUS!!Population 16 years and over'),
#  ('DP03_0001M',
#   'Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over'),
#  ('DP03_0001PE',
#   'Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over'),
#  ('DP03_0001PM',
#   'Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over')]

# %%
# Rename the colums in the original dataframe according to the dictionary
df03 = df03.rename(columns = header_dict)

# %%
# Drop columsn with NaN values
df03 = df03.dropna(axis=1)

# %%
# Display the dataframe
df03.head(3)
# Out:
# 0  Geographic Area Name          GEO_ID  \
# 1  Austin County, Texas  0500000US48015
# 2  Kenedy County, Texas  0500000US48261
# 3  Nueces County, Texas  0500000US48355
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                              23354
# 2                                                428
# 3                                             280990
#
# 0 Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                                108
# 2                                                122
# 3                                                413
#
# 0 Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                              23354
# 2                                                428
# 3                                             280990
#
# 0 Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over  \
# 1                                         -888888888
# 2                                         -888888888
# 3                                         -888888888
#
# 0 Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                              14475
# 2                                                220
# 3                                             177352
#
# 0 Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                413
# 2                                                 83
# 3                                               1636
#
# 0 Percent Estimate!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                               62.0
# 2                                               51.4
# 3                                               63.1
#
# 0 Percent Margin of Error!!EMPLOYMENT STATUS!!Population 16 years and over!!In labor force  \
# 1                                                1.8
# 2                                               13.4
# 3                                                0.6
#
# 0  ... DP03_0134EA DP03_0134MA DP03_0135EA DP03_0135MA DP03_0136EA  \
# 1  ...         (X)         (X)         (X)         (X)         (X)
# 2  ...         (X)         (X)         (X)         (X)         (X)
# 3  ...         (X)         (X)         (X)         (X)         (X)
#
# 0 DP03_0136MA DP03_0137MA DP03_0137EA state county
# 1         (X)         (X)         (X)    48    015
# 2         (X)         (X)         (X)    48    261
# 3         (X)         (X)         (X)    48    355
#
# [3 rows x 644 columns]

# %%
df03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 1 to 102
# Columns: 644 entries, Geographic Area Name to county
# dtypes: object(644)
# memory usage: 2.7+ MB

# %%
# Export the dataframe as a csv.
df03.to_csv('../data/preprocessing/raw_dp03_with_headers_five_states.csv', index=False)
