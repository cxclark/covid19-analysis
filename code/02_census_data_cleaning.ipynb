# %% [markdown]
# ## Contents
# - [Importing and Cleaning DP05 Data](#Importing-and-Cleaning-DP05-Data)
# - [Create 'SEX AND AGE' Dataframe](#Create-'SEX-AND-AGE'-Dataframe)
# - [Create 'RACE' Dataframe](#Create-'RACE'-Dataframe)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Importing and Cleaning DP05 Data

# %%
# Read in data with heads as dataframe, setting the geo name to the idex.
dp05 = pd.read_csv('../data/preprocessing/tx_dp05_data_with_headers.csv', index_col=0)
dp05.head(3)
# Out:
#                       Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# Geographic Area Name
# Austin County, Texas                                                0.6
# Kenedy County, Texas                                               20.5
# Nueces County, Texas                                                0.1
#
#                       Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                               87.0
# Kenedy County, Texas                                               34.7
# Nueces County, Texas                                               79.3
#
#                       Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                                1.9
# Kenedy County, Texas                                               38.9
# Nueces County, Texas                                                0.3
#
#                       Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                         -888888888
# Kenedy County, Texas                                         -888888888
# Nueces County, Texas                                         -888888888
#
#                       Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                         -888888888
# Kenedy County, Texas                                         -888888888
# Nueces County, Texas                                         -888888888
#
#                       Estimate!!RACE!!Total population  \
# Geographic Area Name
# Austin County, Texas                             29565
# Kenedy County, Texas                               595
# Nueces County, Texas                            360486
#
#                       Margin of Error!!RACE!!Total population  \
# Geographic Area Name
# Austin County, Texas                               -555555555
# Kenedy County, Texas                                      181
# Nueces County, Texas                               -555555555
#
#                       Percent Estimate!!RACE!!Total population  \
# Geographic Area Name
# Austin County, Texas                                     29565
# Kenedy County, Texas                                       595
# Nueces County, Texas                                    360486
#
#                       Percent Margin of Error!!RACE!!Total population  \
# Geographic Area Name
# Austin County, Texas                                       -888888888
# Kenedy County, Texas                                       -888888888
# Nueces County, Texas                                       -888888888
#
#                       Estimate!!RACE!!Total population!!One race  ...  \
# Geographic Area Name                                              ...
# Austin County, Texas                                       29004  ...
# Kenedy County, Texas                                         595  ...
# Nueces County, Texas                                      354655  ...
#
#                       DP05_0004PMA  DP05_0004PEA  DP05_0018PMA  DP05_0018PEA  \
# Geographic Area Name
# Austin County, Texas           (X)           (X)           (X)           (X)
# Kenedy County, Texas           (X)           (X)           (X)           (X)
# Nueces County, Texas           (X)           (X)           (X)           (X)
#
#                       DP05_0025PMA  DP05_0028PMA  DP05_0028PEA  DP05_0029PMA  \
# Geographic Area Name
# Austin County, Texas           (X)           (X)           (X)           (X)
# Kenedy County, Texas           (X)           (X)           (X)           (X)
# Nueces County, Texas           (X)           (X)           (X)           (X)
#
#                       state  county
# Geographic Area Name
# Austin County, Texas     48      15
# Kenedy County, Texas     48     261
# Nueces County, Texas     48     355
#
# [3 rows x 377 columns]

# %%
# Replace !! in column titles with empty space.
dp05.columns = dp05.columns.str.replace('!!', ' ')

# %%
# Drop the state and county number columns.
dp05 = dp05.drop(columns= ['state', 'county'])

# %%
# Display the first few rows of the dataframe
dp05.head(3)
# Out:
#                       Percent Margin of Error SEX AND AGE Total population 65 years and over Female  \
# Geographic Area Name
# Austin County, Texas                                                0.6
# Kenedy County, Texas                                               20.5
# Nueces County, Texas                                                0.1
#
#                       Estimate SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                               87.0
# Kenedy County, Texas                                               34.7
# Nueces County, Texas                                               79.3
#
#                       Margin of Error SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                                1.9
# Kenedy County, Texas                                               38.9
# Nueces County, Texas                                                0.3
#
#                       Percent Estimate SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                         -888888888
# Kenedy County, Texas                                         -888888888
# Nueces County, Texas                                         -888888888
#
#                       Percent Margin of Error SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                         -888888888
# Kenedy County, Texas                                         -888888888
# Nueces County, Texas                                         -888888888
#
#                       Estimate RACE Total population  \
# Geographic Area Name
# Austin County, Texas                           29565
# Kenedy County, Texas                             595
# Nueces County, Texas                          360486
#
#                       Margin of Error RACE Total population  \
# Geographic Area Name
# Austin County, Texas                             -555555555
# Kenedy County, Texas                                    181
# Nueces County, Texas                             -555555555
#
#                       Percent Estimate RACE Total population  \
# Geographic Area Name
# Austin County, Texas                                   29565
# Kenedy County, Texas                                     595
# Nueces County, Texas                                  360486
#
#                       Percent Margin of Error RACE Total population  \
# Geographic Area Name
# Austin County, Texas                                     -888888888
# Kenedy County, Texas                                     -888888888
# Nueces County, Texas                                     -888888888
#
#                       Estimate RACE Total population One race  ...  \
# Geographic Area Name                                           ...
# Austin County, Texas                                    29004  ...
# Kenedy County, Texas                                      595  ...
# Nueces County, Texas                                   354655  ...
#
#                       Geographic Area Name.1  DP05_0001PMA  DP05_0004PMA  \
# Geographic Area Name
# Austin County, Texas    Austin County, Texas           (X)           (X)
# Kenedy County, Texas    Kenedy County, Texas           (X)           (X)
# Nueces County, Texas    Nueces County, Texas           (X)           (X)
#
#                       DP05_0004PEA  DP05_0018PMA  DP05_0018PEA  DP05_0025PMA  \
# Geographic Area Name
# Austin County, Texas           (X)           (X)           (X)           (X)
# Kenedy County, Texas           (X)           (X)           (X)           (X)
# Nueces County, Texas           (X)           (X)           (X)           (X)
#
#                       DP05_0028PMA  DP05_0028PEA  DP05_0029PMA
# Geographic Area Name
# Austin County, Texas           (X)           (X)           (X)
# Kenedy County, Texas           (X)           (X)           (X)
# Nueces County, Texas           (X)           (X)           (X)
#
# [3 rows x 375 columns]

# %% [markdown]
# ## Replace -888888888, -555555555, AND (X) with NaN
#
# -888888888, or '(X)' means that the estimate is not applicable or not available.
# -555555555, or '*****' entry in the margin of error column indicates that the estimate is controlled. A statistical test for sampling variability is not appropriate.

# %%
dp05 = dp05.replace([-888888888, -555555555, '(X)'], np.nan)

# %% [markdown]
# ## Drop Margin of Error Columns

# %%
# Drop columns that contain 'Margin' in the name.
# https://stackoverflow.com/questions/406230/regular-expression-to-match-a-line-that-doesnt-contain-a-word
dp05 = dp05.filter(regex='^((?!Margin).)*$', axis=1)

# %% [markdown]
# # Create 'SEX AND AGE' Dataframe

# %%
# Extract the columns that have SEX AND AGE in the title
# and sae to a new dataframe.
dp05_sex_age = dp05.filter(regex = '(SEX AND AGE)', axis=1)
dp05_sex_age.head(3)
# Out:
#                       Estimate SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                               87.0
# Kenedy County, Texas                                               34.7
# Nueces County, Texas                                               79.3
#
#                       Percent Estimate SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                                NaN
# Kenedy County, Texas                                                NaN
# Nueces County, Texas                                                NaN
#
#                       Estimate SEX AND AGE Total population  \
# Geographic Area Name
# Austin County, Texas                                  29565
# Kenedy County, Texas                                    595
# Nueces County, Texas                                 360486
#
#                       Percent Estimate SEX AND AGE Total population  \
# Geographic Area Name
# Austin County, Texas                                          29565
# Kenedy County, Texas                                            595
# Nueces County, Texas                                         360486
#
#                       Estimate SEX AND AGE Total population Male  \
# Geographic Area Name
# Austin County, Texas                                       14684
# Kenedy County, Texas                                         286
# Nueces County, Texas                                      178020
#
#                       Percent Estimate SEX AND AGE Total population Male  \
# Geographic Area Name
# Austin County, Texas                                               49.7
# Kenedy County, Texas                                               48.1
# Nueces County, Texas                                               49.4
#
#                       Estimate SEX AND AGE Total population Female  \
# Geographic Area Name
# Austin County, Texas                                         14881
# Kenedy County, Texas                                           309
# Nueces County, Texas                                        182466
#
#                       Percent Estimate SEX AND AGE Total population Female  \
# Geographic Area Name
# Austin County, Texas                                               50.3
# Kenedy County, Texas                                               51.9
# Nueces County, Texas                                               50.6
#
#                       Estimate SEX AND AGE Total population Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                               98.7
# Kenedy County, Texas                                               92.6
# Nueces County, Texas                                               97.6
#
#                       Percent Estimate SEX AND AGE Total population Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                                NaN
# Kenedy County, Texas                                                NaN
# Nueces County, Texas                                                NaN
#
#                       ...  \
# Geographic Area Name  ...
# Austin County, Texas  ...
# Kenedy County, Texas  ...
# Nueces County, Texas  ...
#
#                       Estimate SEX AND AGE Total population 18 years and over Female  \
# Geographic Area Name
# Austin County, Texas                                              11353
# Kenedy County, Texas                                                238
# Nueces County, Texas                                             138458
#
#                       Percent Estimate SEX AND AGE Total population 18 years and over Female  \
# Geographic Area Name
# Austin County, Texas                                               50.5
# Kenedy County, Texas                                               55.6
# Nueces County, Texas                                               51.2
#
#                       Estimate SEX AND AGE Total population 18 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                               97.8
# Kenedy County, Texas                                               79.8
# Nueces County, Texas                                               95.4
#
#                       Percent Estimate SEX AND AGE Total population 18 years and over Sex ratio (males per 100 females)  \
# Geographic Area Name
# Austin County, Texas                                                NaN
# Kenedy County, Texas                                                NaN
# Nueces County, Texas                                                NaN
#
#                       Estimate SEX AND AGE Total population 65 years and over.1  \
# Geographic Area Name
# Austin County, Texas                                               5394
# Kenedy County, Texas                                                136
# Nueces County, Texas                                              49345
#
#                       Percent Estimate SEX AND AGE Total population 65 years and over.1  \
# Geographic Area Name
# Austin County, Texas                                               5394
# Kenedy County, Texas                                                136
# Nueces County, Texas                                              49345
#
#                       Estimate SEX AND AGE Total population 65 years and over Male  \
# Geographic Area Name
# Austin County, Texas                                               2509
# Kenedy County, Texas                                                 35
# Nueces County, Texas                                              21822
#
#                       Percent Estimate SEX AND AGE Total population 65 years and over Male  \
# Geographic Area Name
# Austin County, Texas                                               46.5
# Kenedy County, Texas                                               25.7
# Nueces County, Texas                                               44.2
#
#                       Estimate SEX AND AGE Total population 65 years and over Female  \
# Geographic Area Name
# Austin County, Texas                                               2885
# Kenedy County, Texas                                                101
# Nueces County, Texas                                              27523
#
#                       Percent Estimate SEX AND AGE Total population 65 years and over Female
# Geographic Area Name
# Austin County, Texas                                               53.5
# Kenedy County, Texas                                               74.3
# Nueces County, Texas                                               55.8
#
# [3 rows x 64 columns]

# %%
# Drop the columns that have NaN values.
dp05_sex_age = dp05_sex_age.loc[:, (dp05_sex_age.isna().sum() < 1)]

# %%
# Display information about the SEX and AGE dataframe
dp05_sex_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, Austin County, Texas to Falls County, Texas
# Data columns (total 60 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Estimate SEX AND AGE Total population 65 years and over Sex ratio (males per 100 females)  254 non-null    float64
#  1   Estimate SEX AND AGE Total population                                                      254 non-null    int64
#  2   Percent Estimate SEX AND AGE Total population                                              254 non-null    int64
#  3   Estimate SEX AND AGE Total population Male                                                 254 non-null    int64
#  4   Percent Estimate SEX AND AGE Total population Male                                         254 non-null    float64
#  5   Estimate SEX AND AGE Total population Female                                               254 non-null    int64
#  6   Percent Estimate SEX AND AGE Total population Female                                       254 non-null    float64
#  7   Estimate SEX AND AGE Total population Sex ratio (males per 100 females)                    254 non-null    float64
#  8   Estimate SEX AND AGE Total population Under 5 years                                        254 non-null    int64
#  9   Percent Estimate SEX AND AGE Total population Under 5 years                                254 non-null    float64
#  10  Estimate SEX AND AGE Total population 5 to 9 years                                         254 non-null    int64
#  11  Percent Estimate SEX AND AGE Total population 5 to 9 years                                 254 non-null    float64
#  12  Estimate SEX AND AGE Total population 10 to 14 years                                       254 non-null    int64
#  13  Percent Estimate SEX AND AGE Total population 10 to 14 years                               254 non-null    float64
#  14  Estimate SEX AND AGE Total population 15 to 19 years                                       254 non-null    int64
#  15  Percent Estimate SEX AND AGE Total population 15 to 19 years                               254 non-null    float64
#  16  Estimate SEX AND AGE Total population 20 to 24 years                                       254 non-null    int64
#  17  Percent Estimate SEX AND AGE Total population 20 to 24 years                               254 non-null    float64
#  18  Estimate SEX AND AGE Total population 25 to 34 years                                       254 non-null    int64
#  19  Percent Estimate SEX AND AGE Total population 25 to 34 years                               254 non-null    float64
#  20  Estimate SEX AND AGE Total population 35 to 44 years                                       254 non-null    int64
#  21  Percent Estimate SEX AND AGE Total population 35 to 44 years                               254 non-null    float64
#  22  Estimate SEX AND AGE Total population 45 to 54 years                                       254 non-null    int64
#  23  Percent Estimate SEX AND AGE Total population 45 to 54 years                               254 non-null    float64
#  24  Estimate SEX AND AGE Total population 55 to 59 years                                       254 non-null    int64
#  25  Percent Estimate SEX AND AGE Total population 55 to 59 years                               254 non-null    float64
#  26  Estimate SEX AND AGE Total population 60 to 64 years                                       254 non-null    int64
#  27  Percent Estimate SEX AND AGE Total population 60 to 64 years                               254 non-null    float64
#  28  Estimate SEX AND AGE Total population 65 to 74 years                                       254 non-null    int64
#  29  Percent Estimate SEX AND AGE Total population 65 to 74 years                               254 non-null    float64
#  30  Estimate SEX AND AGE Total population 75 to 84 years                                       254 non-null    int64
#  31  Percent Estimate SEX AND AGE Total population 75 to 84 years                               254 non-null    float64
#  32  Estimate SEX AND AGE Total population 85 years and over                                    254 non-null    int64
#  33  Percent Estimate SEX AND AGE Total population 85 years and over                            254 non-null    float64
#  34  Estimate SEX AND AGE Total population Median age (years)                                   254 non-null    float64
#  35  Estimate SEX AND AGE Total population Under 18 years                                       254 non-null    int64
#  36  Percent Estimate SEX AND AGE Total population Under 18 years                               254 non-null    float64
#  37  Estimate SEX AND AGE Total population 16 years and over                                    254 non-null    int64
#  38  Percent Estimate SEX AND AGE Total population 16 years and over                            254 non-null    float64
#  39  Estimate SEX AND AGE Total population 18 years and over                                    254 non-null    int64
#  40  Percent Estimate SEX AND AGE Total population 18 years and over                            254 non-null    float64
#  41  Estimate SEX AND AGE Total population 21 years and over                                    254 non-null    int64
#  42  Percent Estimate SEX AND AGE Total population 21 years and over                            254 non-null    float64
#  43  Estimate SEX AND AGE Total population 62 years and over                                    254 non-null    int64
#  44  Percent Estimate SEX AND AGE Total population 62 years and over                            254 non-null    float64
#  45  Estimate SEX AND AGE Total population 65 years and over                                    254 non-null    int64
#  46  Percent Estimate SEX AND AGE Total population 65 years and over                            254 non-null    float64
#  47  Estimate SEX AND AGE Total population 18 years and over.1                                  254 non-null    int64
#  48  Percent Estimate SEX AND AGE Total population 18 years and over.1                          254 non-null    int64
#  49  Estimate SEX AND AGE Total population 18 years and over Male                               254 non-null    int64
#  50  Percent Estimate SEX AND AGE Total population 18 years and over Male                       254 non-null    float64
#  51  Estimate SEX AND AGE Total population 18 years and over Female                             254 non-null    int64
#  52  Percent Estimate SEX AND AGE Total population 18 years and over Female                     254 non-null    float64
#  53  Estimate SEX AND AGE Total population 18 years and over Sex ratio (males per 100 females)  254 non-null    float64
#  54  Estimate SEX AND AGE Total population 65 years and over.1                                  254 non-null    int64
#  55  Percent Estimate SEX AND AGE Total population 65 years and over.1                          254 non-null    int64
#  56  Estimate SEX AND AGE Total population 65 years and over Male                               254 non-null    int64
#  57  Percent Estimate SEX AND AGE Total population 65 years and over Male                       254 non-null    float64
#  58  Estimate SEX AND AGE Total population 65 years and over Female                             254 non-null    int64
#  59  Percent Estimate SEX AND AGE Total population 65 years and over Female                     254 non-null    float64
# dtypes: float64(29), int64(31)
# memory usage: 121.0+ KB

# %%
# These are the columns to be used in the analysis.
columns_sex_age = [
    'Estimate SEX AND AGE Total population',
    'Estimate SEX AND AGE Total population Male',
    'Estimate SEX AND AGE Total population Female',
    'Estimate SEX AND AGE Total population Under 5 years',
    'Estimate SEX AND AGE Total population 5 to 9 years',
    'Estimate SEX AND AGE Total population 10 to 14 years',
    'Estimate SEX AND AGE Total population 15 to 19 years',
    'Estimate SEX AND AGE Total population 20 to 24 years',
    'Estimate SEX AND AGE Total population 25 to 34 years',
    'Estimate SEX AND AGE Total population 35 to 44 years',
    'Estimate SEX AND AGE Total population 45 to 54 years',
    'Estimate SEX AND AGE Total population 55 to 59 years',
    'Estimate SEX AND AGE Total population 60 to 64 years',
    'Estimate SEX AND AGE Total population 65 to 74 years',
    'Estimate SEX AND AGE Total population 75 to 84 years',
    'Estimate SEX AND AGE Total population 85 years and over',
    'Estimate SEX AND AGE Total population Median age (years)',
]

# %%
# Extract the important columns for gender and age analysis.
dp05_sex_age = dp05_sex_age[columns_sex_age]

# %%
# Display the dataframe
dp05_sex_age.head(3)
# Out:
#                       Estimate SEX AND AGE Total population  \
# Geographic Area Name
# Austin County, Texas                                  29565
# Kenedy County, Texas                                    595
# Nueces County, Texas                                 360486
#
#                       Estimate SEX AND AGE Total population Male  \
# Geographic Area Name
# Austin County, Texas                                       14684
# Kenedy County, Texas                                         286
# Nueces County, Texas                                      178020
#
#                       Estimate SEX AND AGE Total population Female  \
# Geographic Area Name
# Austin County, Texas                                         14881
# Kenedy County, Texas                                           309
# Nueces County, Texas                                        182466
#
#                       Estimate SEX AND AGE Total population Under 5 years  \
# Geographic Area Name
# Austin County, Texas                                               1780
# Kenedy County, Texas                                                 85
# Nueces County, Texas                                              24665
#
#                       Estimate SEX AND AGE Total population 5 to 9 years  \
# Geographic Area Name
# Austin County, Texas                                               1960
# Kenedy County, Texas                                                 37
# Nueces County, Texas                                              25055
#
#                       Estimate SEX AND AGE Total population 10 to 14 years  \
# Geographic Area Name
# Austin County, Texas                                               2118
# Kenedy County, Texas                                                 40
# Nueces County, Texas                                              24806
#
#                       Estimate SEX AND AGE Total population 15 to 19 years  \
# Geographic Area Name
# Austin County, Texas                                               1861
# Kenedy County, Texas                                                 10
# Nueces County, Texas                                              25524
#
#                       Estimate SEX AND AGE Total population 20 to 24 years  \
# Geographic Area Name
# Austin County, Texas                                               1712
# Kenedy County, Texas                                                 10
# Nueces County, Texas                                              26397
#
#                       Estimate SEX AND AGE Total population 25 to 34 years  \
# Geographic Area Name
# Austin County, Texas                                               3339
# Kenedy County, Texas                                                 95
# Nueces County, Texas                                              52547
#
#                       Estimate SEX AND AGE Total population 35 to 44 years  \
# Geographic Area Name
# Austin County, Texas                                               3275
# Kenedy County, Texas                                                 47
# Nueces County, Texas                                              45030
#
#                       Estimate SEX AND AGE Total population 45 to 54 years  \
# Geographic Area Name
# Austin County, Texas                                               3821
# Kenedy County, Texas                                                 75
# Nueces County, Texas                                              43503
#
#                       Estimate SEX AND AGE Total population 55 to 59 years  \
# Geographic Area Name
# Austin County, Texas                                               2327
# Kenedy County, Texas                                                 51
# Nueces County, Texas                                              22563
#
#                       Estimate SEX AND AGE Total population 60 to 64 years  \
# Geographic Area Name
# Austin County, Texas                                               1978
# Kenedy County, Texas                                                  9
# Nueces County, Texas                                              21051
#
#                       Estimate SEX AND AGE Total population 65 to 74 years  \
# Geographic Area Name
# Austin County, Texas                                               3243
# Kenedy County, Texas                                                 85
# Nueces County, Texas                                              28881
#
#                       Estimate SEX AND AGE Total population 75 to 84 years  \
# Geographic Area Name
# Austin County, Texas                                               1532
# Kenedy County, Texas                                                 29
# Nueces County, Texas                                              15165
#
#                       Estimate SEX AND AGE Total population 85 years and over  \
# Geographic Area Name
# Austin County, Texas                                                619
# Kenedy County, Texas                                                 22
# Nueces County, Texas                                               5299
#
#                       Estimate SEX AND AGE Total population Median age (years)
# Geographic Area Name
# Austin County, Texas                                               40.7
# Kenedy County, Texas                                               39.5
# Nueces County, Texas                                               35.3

# %%
# Clean up column names.
dp05_sex_age.columns = dp05_sex_age.columns.str.lower().str.replace('estimate ', '').str.replace('sex and age', 'sex_age')

# %%
# Clean up column names.
dp05_sex_age.columns = dp05_sex_age.columns.str.replace('total population', 'pop').str.replace(' years', '').str.replace(' ', '_')

# %%
# Display columns.
dp05_sex_age.columns
# Out:
# Index(['sex_age_pop', 'sex_age_pop_male', 'sex_age_pop_female',
#        'sex_age_pop_under_5', 'sex_age_pop_5_to_9', 'sex_age_pop_10_to_14',
#        'sex_age_pop_15_to_19', 'sex_age_pop_20_to_24', 'sex_age_pop_25_to_34',
#        'sex_age_pop_35_to_44', 'sex_age_pop_45_to_54', 'sex_age_pop_55_to_59',
#        'sex_age_pop_60_to_64', 'sex_age_pop_65_to_74', 'sex_age_pop_75_to_84',
#        'sex_age_pop_85_and_over', 'sex_age_pop_median_age_(years)'],
#       dtype='object')

# %%
# Rename the median age column for the function.
dp05_sex_age = dp05_sex_age.rename(columns={'sex_age_pop_median_age_(years)': 'sex_age_median_age_in_years'})

# %%
# Export the cleaned county data for sex and age by percent.
dp05_sex_age.to_csv('../data/preprocessing/tx_dp05_sex_age_cleaned.csv')

# %% [markdown]
# # Create 'RACE' Dataframe

# %%
# Extract the columns that don't have SEX AND AGE in the title
# and save to a new dataframe.
dp05_race = dp05.filter(regex='(RACE)', axis=1)
dp05_race.head(3)
# Out:
#                       Estimate RACE Total population  \
# Geographic Area Name
# Austin County, Texas                           29565
# Kenedy County, Texas                             595
# Nueces County, Texas                          360486
#
#                       Percent Estimate RACE Total population  \
# Geographic Area Name
# Austin County, Texas                                   29565
# Kenedy County, Texas                                     595
# Nueces County, Texas                                  360486
#
#                       Estimate RACE Total population One race  \
# Geographic Area Name
# Austin County, Texas                                    29004
# Kenedy County, Texas                                      595
# Nueces County, Texas                                   354655
#
#                       Percent Estimate RACE Total population One race  \
# Geographic Area Name
# Austin County, Texas                                             98.1
# Kenedy County, Texas                                            100.0
# Nueces County, Texas                                             98.4
#
#                       Estimate RACE Total population Two or more races  \
# Geographic Area Name
# Austin County, Texas                                               561
# Kenedy County, Texas                                                 0
# Nueces County, Texas                                              5831
#
#                       Percent Estimate RACE Total population Two or more races  \
# Geographic Area Name
# Austin County, Texas                                                1.9
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                1.6
#
#                       Estimate RACE Total population One race.1  \
# Geographic Area Name
# Austin County, Texas                                      29004
# Kenedy County, Texas                                        595
# Nueces County, Texas                                     354655
#
#                       Percent Estimate RACE Total population One race.1  \
# Geographic Area Name
# Austin County, Texas                                               98.1
# Kenedy County, Texas                                              100.0
# Nueces County, Texas                                               98.4
#
#                       Estimate RACE Total population One race White  \
# Geographic Area Name
# Austin County, Texas                                          23810
# Kenedy County, Texas                                            573
# Nueces County, Texas                                         324198
#
#                       Percent Estimate RACE Total population One race White  \
# Geographic Area Name
# Austin County, Texas                                               80.5
# Kenedy County, Texas                                               96.3
# Nueces County, Texas                                               89.9
#
#                       ...  \
# Geographic Area Name  ...
# Austin County, Texas  ...
# Kenedy County, Texas  ...
# Nueces County, Texas  ...
#
#                       Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone  \
# Geographic Area Name
# Austin County, Texas                                                  0
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                                242
#
#                       Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone  \
# Geographic Area Name
# Austin County, Texas                                                0.0
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                0.1
#
#                       Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone  \
# Geographic Area Name
# Austin County, Texas                                                 52
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                                226
#
#                       Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone  \
# Geographic Area Name
# Austin County, Texas                                                0.2
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                0.1
#
#                       Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races  \
# Geographic Area Name
# Austin County, Texas                                                456
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                               2780
#
#                       Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races  \
# Geographic Area Name
# Austin County, Texas                                                1.5
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                0.8
#
#                       Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races including Some other race  \
# Geographic Area Name
# Austin County, Texas                                                  0
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                                145
#
#                       Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races including Some other race  \
# Geographic Area Name
# Austin County, Texas                                                0.0
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                0.0
#
#                       Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races excluding Some other race, and Three or more races  \
# Geographic Area Name
# Austin County, Texas                                                456
# Kenedy County, Texas                                                  0
# Nueces County, Texas                                               2635
#
#                       Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races excluding Some other race, and Three or more races
# Geographic Area Name
# Austin County, Texas                                                1.5
# Kenedy County, Texas                                                0.0
# Nueces County, Texas                                                0.7
#
# [3 rows x 92 columns]

# %%
# Drop the columns that have NaN values.
dp05_race = dp05_race.loc[:, (dp05_race.isna().sum() < 1)]

# %%
# Display information about the dataframe.
dp05_race.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, Austin County, Texas to Falls County, Texas
# Data columns (total 92 columns):
#  #   Column                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                               --------------  -----
#  0   Estimate RACE Total population                                                                                                                                       254 non-null    int64
#  1   Percent Estimate RACE Total population                                                                                                                               254 non-null    int64
#  2   Estimate RACE Total population One race                                                                                                                              254 non-null    int64
#  3   Percent Estimate RACE Total population One race                                                                                                                      254 non-null    float64
#  4   Estimate RACE Total population Two or more races                                                                                                                     254 non-null    int64
#  5   Percent Estimate RACE Total population Two or more races                                                                                                             254 non-null    float64
#  6   Estimate RACE Total population One race.1                                                                                                                            254 non-null    int64
#  7   Percent Estimate RACE Total population One race.1                                                                                                                    254 non-null    float64
#  8   Estimate RACE Total population One race White                                                                                                                        254 non-null    int64
#  9   Percent Estimate RACE Total population One race White                                                                                                                254 non-null    float64
#  10  Estimate RACE Total population One race Black or African American                                                                                                    254 non-null    int64
#  11  Percent Estimate RACE Total population One race Black or African American                                                                                            254 non-null    float64
#  12  Estimate RACE Total population One race American Indian and Alaska Native                                                                                            254 non-null    int64
#  13  Percent Estimate RACE Total population One race American Indian and Alaska Native                                                                                    254 non-null    float64
#  14  Estimate RACE Total population One race American Indian and Alaska Native Cherokee tribal grouping                                                                   254 non-null    int64
#  15  Percent Estimate RACE Total population One race American Indian and Alaska Native Cherokee tribal grouping                                                           254 non-null    float64
#  16  Estimate RACE Total population One race American Indian and Alaska Native Chippewa tribal grouping                                                                   254 non-null    int64
#  17  Percent Estimate RACE Total population One race American Indian and Alaska Native Chippewa tribal grouping                                                           254 non-null    float64
#  18  Estimate RACE Total population One race American Indian and Alaska Native Navajo tribal grouping                                                                     254 non-null    int64
#  19  Percent Estimate RACE Total population One race American Indian and Alaska Native Navajo tribal grouping                                                             254 non-null    float64
#  20  Estimate RACE Total population One race American Indian and Alaska Native Sioux tribal grouping                                                                      254 non-null    int64
#  21  Percent Estimate RACE Total population One race American Indian and Alaska Native Sioux tribal grouping                                                              254 non-null    float64
#  22  Estimate RACE Total population One race Asian                                                                                                                        254 non-null    int64
#  23  Percent Estimate RACE Total population One race Asian                                                                                                                254 non-null    float64
#  24  Estimate RACE Total population One race Asian Asian Indian                                                                                                           254 non-null    int64
#  25  Percent Estimate RACE Total population One race Asian Asian Indian                                                                                                   254 non-null    float64
#  26  Estimate RACE Total population One race Asian Chinese                                                                                                                254 non-null    int64
#  27  Percent Estimate RACE Total population One race Asian Chinese                                                                                                        254 non-null    float64
#  28  Estimate RACE Total population One race Asian Filipino                                                                                                               254 non-null    int64
#  29  Percent Estimate RACE Total population One race Asian Filipino                                                                                                       254 non-null    float64
#  30  Estimate RACE Total population One race Asian Japanese                                                                                                               254 non-null    int64
#  31  Percent Estimate RACE Total population One race Asian Japanese                                                                                                       254 non-null    float64
#  32  Estimate RACE Total population One race Asian Korean                                                                                                                 254 non-null    int64
#  33  Percent Estimate RACE Total population One race Asian Korean                                                                                                         254 non-null    float64
#  34  Estimate RACE Total population One race Asian Vietnamese                                                                                                             254 non-null    int64
#  35  Percent Estimate RACE Total population One race Asian Vietnamese                                                                                                     254 non-null    float64
#  36  Estimate RACE Total population One race Asian Other Asian                                                                                                            254 non-null    int64
#  37  Percent Estimate RACE Total population One race Asian Other Asian                                                                                                    254 non-null    float64
#  38  Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander                                                                                   254 non-null    int64
#  39  Percent Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander                                                                           254 non-null    float64
#  40  Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Native Hawaiian                                                                   254 non-null    int64
#  41  Percent Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Native Hawaiian                                                           254 non-null    float64
#  42  Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Guamanian or Chamorro                                                             254 non-null    int64
#  43  Percent Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Guamanian or Chamorro                                                     254 non-null    float64
#  44  Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Samoan                                                                            254 non-null    int64
#  45  Percent Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Samoan                                                                    254 non-null    float64
#  46  Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Other Pacific Islander                                                            254 non-null    int64
#  47  Percent Estimate RACE Total population One race Native Hawaiian and Other Pacific Islander Other Pacific Islander                                                    254 non-null    float64
#  48  Estimate RACE Total population One race Some other race                                                                                                              254 non-null    int64
#  49  Percent Estimate RACE Total population One race Some other race                                                                                                      254 non-null    float64
#  50  Estimate RACE Total population Two or more races.1                                                                                                                   254 non-null    int64
#  51  Percent Estimate RACE Total population Two or more races.1                                                                                                           254 non-null    float64
#  52  Estimate RACE Total population Two or more races White and Black or African American                                                                                 254 non-null    int64
#  53  Percent Estimate RACE Total population Two or more races White and Black or African American                                                                         254 non-null    float64
#  54  Estimate RACE Total population Two or more races White and American Indian and Alaska Native                                                                         254 non-null    int64
#  55  Percent Estimate RACE Total population Two or more races White and American Indian and Alaska Native                                                                 254 non-null    float64
#  56  Estimate RACE Total population Two or more races White and Asian                                                                                                     254 non-null    int64
#  57  Percent Estimate RACE Total population Two or more races White and Asian                                                                                             254 non-null    float64
#  58  Estimate RACE Total population Two or more races Black or African American and American Indian and Alaska Native                                                     254 non-null    int64
#  59  Percent Estimate RACE Total population Two or more races Black or African American and American Indian and Alaska Native                                             254 non-null    float64
#  60  Estimate HISPANIC OR LATINO AND RACE Total population                                                                                                                254 non-null    int64
#  61  Percent Estimate HISPANIC OR LATINO AND RACE Total population                                                                                                        254 non-null    int64
#  62  Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race)                                                                               254 non-null    int64
#  63  Percent Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race)                                                                       254 non-null    float64
#  64  Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Mexican                                                                       254 non-null    int64
#  65  Percent Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Mexican                                                               254 non-null    float64
#  66  Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Puerto Rican                                                                  254 non-null    int64
#  67  Percent Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Puerto Rican                                                          254 non-null    float64
#  68  Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Cuban                                                                         254 non-null    int64
#  69  Percent Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Cuban                                                                 254 non-null    float64
#  70  Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Other Hispanic or Latino                                                      254 non-null    int64
#  71  Percent Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race) Other Hispanic or Latino                                              254 non-null    float64
#  72  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino                                                                                         254 non-null    int64
#  73  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino                                                                                 254 non-null    float64
#  74  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino White alone                                                                             254 non-null    int64
#  75  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino White alone                                                                     254 non-null    float64
#  76  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Black or African American alone                                                         254 non-null    int64
#  77  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Black or African American alone                                                 254 non-null    float64
#  78  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino American Indian and Alaska Native alone                                                 254 non-null    int64
#  79  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino American Indian and Alaska Native alone                                         254 non-null    float64
#  80  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Asian alone                                                                             254 non-null    int64
#  81  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Asian alone                                                                     254 non-null    float64
#  82  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone                                        254 non-null    int64
#  83  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone                                254 non-null    float64
#  84  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone                                                                   254 non-null    int64
#  85  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone                                                           254 non-null    float64
#  86  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races                                                                       254 non-null    int64
#  87  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races                                                               254 non-null    float64
#  88  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races including Some other race                                   254 non-null    int64
#  89  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races including Some other race                           254 non-null    float64
#  90  Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races excluding Some other race, and Three or more races          254 non-null    int64
#  91  Percent Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races Two races excluding Some other race, and Three or more races  254 non-null    float64
# dtypes: float64(44), int64(48)
# memory usage: 184.5+ KB

# %%
# Export the cleaned data for race
dp05_race.to_csv('../data/preprocessing/tx_dp05_race_cleaned.csv')

# %%
# The race columns are broken down into two basic parts, one witout hispanic, and one with. 
# The hispanic section appears to be more accurate.

columns_non_hispanic = [
    'Estimate RACE Total population',
    'Estimate RACE Total population One race White',
    'Estimate RACE Total population One race Black or African American',
    'Estimate RACE Total population One race American Indian and Alaska Native',
    'Estimate RACE Total population One race Asian',
    'Estimate RACE Total population One race Some other race',
    'Estimate RACE Total population Two or more races.1'
]

# This grouping seems to be better
columns_hispanic = [
    'Estimate RACE Total population',
    'Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race)',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino White alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Black or African American alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino American Indian and Alaska Native alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Asian alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone',
    'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races'
]

# %%
# Extract the important columns for analysis.
dp05_race = dp05_race[columns_hispanic]

# %%
dp05_race.columns
# Out:
# Index(['Estimate RACE Total population',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Hispanic or Latino (of any race)',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino White alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Black or African American alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino American Indian and Alaska Native alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Asian alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Native Hawaiian and Other Pacific Islander alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Some other race alone',
#        'Estimate HISPANIC OR LATINO AND RACE Total population Not Hispanic or Latino Two or more races'],
#       dtype='object')

# %%
# Clean up column names.
dp05_race.columns = dp05_race.columns.str.lower().str.replace('estimate hispanic or latino and race total population', 'race pop').str.replace('not hispanic or latino ', '')

# %%
# Clean up column names.
dp05_race.columns = dp05_race.columns.str.replace('estimate race total population', 'race pop').str.replace(' ', '_')

# %%
# Display columns.
dp05_race.columns
# Out:
# Index(['race_pop', 'race_pop_hispanic_or_latino_(of_any_race)',
#        'race_pop_white_alone', 'race_pop_black_or_african_american_alone',
#        'race_pop_american_indian_and_alaska_native_alone',
#        'race_pop_asian_alone',
#        'race_pop_native_hawaiian_and_other_pacific_islander_alone',
#        'race_pop_some_other_race_alone', 'race_pop_two_or_more_races'],
#       dtype='object')

# %%
# Export the cleaned county data for sex and age by percent.
dp05_race.to_csv('../data/preprocessing/tx_dp05_race_cleaned.csv')
